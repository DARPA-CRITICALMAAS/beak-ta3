# %% [markdown]
# <p style="font-size:35px; text-align:center; font-weight:bold">CMAAS run SOM clustering method</p>
# <p style="font-size:17px; text-align:left">Ina Storch 06-11-2023 </p>
# <p style="font-size:17px; text-align:left">Note: This notebook is designed to run SOM using preprocessed data gained from the datacube from: Lawley et al., 2021. </p>
# <p style="font-size:17px; text-align:left">Reference: Lawley, C.J.M., McCafferty, A.E., Graham, G.E., Gadd, M.G., Huston, D.L., Kelley, K.D., Paradis, S., Peter, J.M., and Czarnota, K., 2021. Datasets to support prospectivity modelling for sediment-hosted Zn-Pb mineral systems; Geological Survey of Canada, Open File 8836, 1 .zip file. https://doi.org/10.4095/329203</p>

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">1) Import libraries, define SOM arguments</p>

# %%
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
import pickle

import beak.methods.som.argsSOM as asom

args = asom.Args()

#base_path = "d:/Programmieren/00_Repositories/CMAAS"
base_path = "d:/projekte/cmaas/repository"

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">2) Provide input file(s).
#
# Input data can eighter be in LRN file format (a table with X, Y, Z and one line with the values for each data layer) or geoTIF file format. Choose one.
#
# When you run a Docker container, you need to specify which directories or paths from your local machine should be mounted into the container since Docker containers are isolated environments, and by default, they can only access files within their own filesystem or volumes.
#
# Alternatively, copy your input data to beak-ta3\src\beak\data. In case of GeoTIF input files, you can create subfolders and collect all TIF files that you want to use for SOM in there. In the following code cell you can provide a file path and a patterns (like "*.tif") for files within that specific folder that you want to use for SOM.
#
# If input file format is LRN, skip the next code cell and provide the file name (including file path) with args.input_file. LRN files should not contain nan values since so far noData handeling is implemented for GeoTIF input only.

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">Either: Data input in geoTiff format:
#
# List geoTiff files, separated by komma: ["path/name1.tiff","path/name2.tiff"] </br>
#
# Here an option is provided how to compose such a list: provide a file path and one or more file patterns (or a list of file names) to select all files matching this pattern inside the specified folder. The file patterns can also include subfolder specifications and * to select all files within this subfolder ('subfolder/*.tif') .

# %%
#--------------- Option 1: specify data path and file patterns 
#import sys
#if sys.version_info < (3, 9):
#    from importlib_resources import files
#else:
#    from importlib.resources import files

#BASE_PATH = (files("beak.data") / "LAWLEY22-EXPORT" / "EPSG_3857_RES_5000" / "CLIPPED_USC")

#PATH_NUMERICAL = BASE_PATH / "NUMERICAL_SCALED_MINMAX" / "*.tif"
#PATH_CATEGORICAL = BASE_PATH / "CATEGORICAL" / "*" /"*.tif"

#PATH_NUMERICAL = BASE_PATH / "NUMERICAL_SCALED_MINMAX" / "Magnetic_LongWavelength_HGM.tif"
#PATH_CATEGORICAL = BASE_PATH / "CATEGORICAL" / "Geology_Lithology_Majority_Igneous_Intrusive_Felsic.tif"

#file_patterns = [str(PATH_NUMERICAL), str(PATH_CATEGORICAL)]


#args.input_file = args.create_list_from_pattern("", file_patterns)

#--------------- Option 2: load a list of GeoTIF files from TXT file 
# Specify the file path
file_path = base_path + "/beak-ta3/experiments/mvt_nat/som/results/input_file_list.txt"
# optional:
#file_path_label = base_path + "/beak-ta3/experiments/mvt_nat/som/results/label_file_list.txt"


args.input_file = args.create_list_from_file(file_path)

#---------------
args.geotiff_input=args.input_file      # geotiff_input files, separated by komma, to write GeoTIF out (only first line is used to get the geotransform and projection information to set output GeoFIT geotransform and projection)
# Out:
# Number of files added: 7
# Files:
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\ISOGRAVITY-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\MagRTP.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Mag_AnalyticSignal_cog.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Moho.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\LAB.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MAGNETOTELLURICS-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\CONUS_MT2023_9km_cog.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MAGNETOTELLURICS-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\CONUS_MT2023_15km_cog.tif

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">Or: Data input in LRN format (data table):
#
# Specify file path and name!

# %%
#args.input_file="/methods/methods/som/data/input/SOM_grav_mag.lrn"

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">3) Specify parameter for SOM.

# %%
     
args.output_folder = base_path + "/beak-ta3/experiments/mvt_nat/som/results" # Folder to save som dictionary and cluster dictionary
args.output_file_somspace = args.output_folder+"/result_som.txt"   # DO NOT CHANGE! Text file that will contain calculated values: som_x som_y b_data1 b_data2 b_dataN umatrix cluster in geospace.

args.som_x = 50                # X dimension of generated SOM
args.som_y = 50               # Y dimension of generated SOM
args.epochs = 10               # Number of epochs to run

# Additional optional parameters:
args.outgeofile= args.output_folder+"/result_geo.txt"             # DO NOT CHANGE!
args.output_file_geospace=args.outgeofile   # Text file that will contain calculated values: {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN in geospace.

args.kmeans="true"          # Run k-means clustering (true, false)
args.kmeans_init = 5           # Number of initializations
args.kmeans_min = 20            # Minimum number of k-mean clusters
args.kmeans_max = 50           # Maximum number of k-mean clusters

args.neighborhood = 'gaussian'     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = 'toroid'            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = 'linear'      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = 'linear'       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = 'random'     # Type of SOM initialization (random, pca)
args.gridtype = 'rectangular'      # Type of SOM grid (hexagonal, rectangular)

args.label = False                  # Whether data contains label column, True or False
args.label_geotiff_file = args.output_folder + "/input_file_list.txt"      # geotiff_input file (None)

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">4) Run SOM
#
# Before running SOM - clean up existing files and move them to a subfolder.

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

# move or remove existing SOM output files from previous runs into subfolder
#mts.move_som_results(args.output_folder, "old_results")
mts.remove_som_results(args.output_folder)

# run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
#     Execution time: 0.5491018295288086 seconds
# Run SOM
#     Execution time: 471.5806736946106 seconds
# Clustering progress:
# 0.00%
# 9.52%
# 19.05%
# 28.57%
# 38.10%
# 47.62%
# 57.14%
# 66.67%
# 76.19%
# 85.71%
# 95.24%
# 100% Clustering completed.
#     Execution time: 12.732309103012085 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 40.66460967063904 seconds
# Save SOM space results
#     Execution time: 1.1030206680297852 seconds
# Save SOM object to file
#     Execution time: 0.008305788040161133 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_US_IsostaticGravity_WGS84
#           b_MagRTP
#           b_Mag_AnalyticSignal_cog
#           b_Moho
#           b_LAB
#           b_CONUS_MT2023_9km_cog
#           b_CONUS_MT2023_15km_cog
#     Execution time: 12.555562257766724 seconds
# Count cluster hit count
#         Cluster hit count: 37 - 47792
#         Cluster hit count: 36 - 19702
#         Cluster hit count: 35 - 6313
#         Cluster hit count: 34 - 25551
#         Cluster hit count: 33 - 19462
#         Cluster hit count: 32 - 50426
#         Cluster hit count: 31 - 18746
#         Cluster hit count: 30 - 7040
#         Cluster hit count: 29 - 44088
#         Cluster hit count: 28 - 10517
#         Cluster hit count: 27 - 45183
#         Cluster hit count: 26 - 101908
#         Cluster hit count: 25 - 14618
#         Cluster hit count: 24 - 34163
#         Cluster hit count: 23 - 50152
#         Cluster hit count: 22 - 27361
#         Cluster hit count: 21 - 37260
#         Cluster hit count: 20 - 16276
#         Cluster hit count: 19 - 1411
#         Cluster hit count: 18 - 52378
#         Cluster hit count: 17 - 27472
#         Cluster hit count: 16 - 22360
#         Cluster hit count: 15 - 42768
#         Cluster hit count: 14 - 44956
#         Cluster hit count: 13 - 49566
#         Cluster hit count: 12 - 22157
#         Cluster hit count: 11 - 28590
#         Cluster hit count: 10 - 53795
#         Cluster hit count: 9 - 15299
#         Cluster hit count: 8 - 47845
#         Cluster hit count: 7 - 69928
#         Cluster hit count: 6 - 55114
#         Cluster hit count: 5 - 18693
#         Cluster hit count: 4 - 35837
#         Cluster hit count: 3 - 30649
#         Cluster hit count: 2 - 14225
#         Cluster hit count: 1 - 21975
#         Cluster hit count: 0 - 55308
#     Execution time: 25.34366774559021 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)
# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">5) Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile= args.output_file_somspace   # som calculation somspace output text file
argsP.som_x= args.som_x         # som x dimension
argsP.som_y= args.som_y         # som y dimension
argsP.input_file= args.input_file   # Input file(*.lrn)
argsP.dir= args.output_folder            # Input file(*.lrn) or directory where som.dictionary was safet to (/output/som.dictionary)
argsP.grid_type= 'rectangular' # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw='true'       # whether to draw all plots, or only those required for clustering (true: draw all. false:draw only for clustering).
argsP.outgeofile=args.output_file_geospace     # som geospace results txt file
argsP.dataType='grid'       # Data type (scatter or grid)
argsP.noDataValue='-9999'    # noData value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.06456136703491211 seconds
#         Read geo data execution time: 5.287089824676514 seconds
#     Execution time: 5.373536586761475 seconds
# Plot geo space results
#     geospace plot no. 2 from 9
# d:\projekte\cmaas\repository\beak-ta3\src\beak\methods\som\plot_som_results.py:274: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 9 from 9
#     q-error plot
#     Execution time: 33.589820861816406 seconds
# Plot Cluster result SOM space
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Execution time: 2.3479628562927246 seconds
# Plot SOM space results
#     somspace plot no. 7 from 7
#     Execution time: 6.276836156845093 seconds
# Plot Boxplots
#     boxplot no. 7 from 7
#     Execution time: 7.710057258605957 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

tabs = [image.split('_')[-2] for image in labels]

print("List of figures:")
print(labels)
#print(tabs)

# Plot the images
#ipyplot.plot_images(images, max_images=50, img_width=250)
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
# List of figures:
# ['geoplot_1.png', 'geoplot_2.png', 'geoplot_3.png', 'geoplot_4.png', 'geoplot_5.png', 'geoplot_6.png', 'geoplot_7.png', 'geoplot_8.png', 'geoplot_9.png', 'somplot_1.png', 'somplot_10.png', 'somplot_2.png', 'somplot_3.png', 'somplot_4.png', 'somplot_5.png', 'somplot_6.png', 'somplot_7.png', 'somplot_8.png', 'somplot_9.png', 'boxplot_1.png', 'boxplot_2.png', 'boxplot_3.png', 'boxplot_4.png', 'boxplot_5.png', 'boxplot_6.png', 'boxplot_7.png', 'db_score.png', 'cluster_hit_count.png']
#     <style>
#         #ipyplot-html-viewer-toggle-gX4ytd5iXEw5pRFPZtHYPB {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-gX4ytd5iXEw5pRFPZtHYPB {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-gX4ytd5iXEw5pRFPZtHYPB {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-gX4ytd5iXEw5pRFPZtHYPB:checked ~ #ipyplot-html-viewer-textarea-gX4ytd5iXEw5pRFPZtHYPB {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-gX4ytd5iXEw5pRFPZtHYPB:checked + #ipyplot-html-viewer-label-gX4ytd5iXEw5pRFPZtHYPB:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-gX4ytd5iXEw5pRFPZtHYPB">
#         <label id="ipyplot-html-viewer-label-gX4ytd5iXEw5pRFPZtHYPB" for="ipyplot-html-viewer-toggle-gX4ytd5iXEw5pRFPZtHYPB">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-gX4ytd5iXEw5pRFPZtHYPB" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM {
#                 display: none;
#             }
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM + label.ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM:checked + label.ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM ~ .tab {
#                 display: none
#             }
#     #tabWBjT9pftQYJQeZAvtJTwo3:checked ~ .tab.contentWBjT9pftQYJQeZAvtJTwo3,#tabhVNv2VZGyBHUE3GffQGUxz:checked ~ .tab.contenthVNv2VZGyBHUE3GffQGUxz,#tabg3tzf6VdoPe9kSJP3Ztwx7:checked ~ .tab.contentg3tzf6VdoPe9kSJP3Ztwx7,#tabnLUefhqh88TvPqcNmSCmTF:checked ~ .tab.contentnLUefhqh88TvPqcNmSCmTF,#tabADe98DqHDDxeEVth4oaKCm:checked ~ .tab.contentADe98DqHDDxeEVth4oaKCm{ display: block; }</style><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabWBjT9pftQYJQeZAvtJTwo3" checked /><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabWBjT9pftQYJQeZAvtJTwo3">boxplot</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabhVNv2VZGyBHUE3GffQGUxz"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabhVNv2VZGyBHUE3GffQGUxz">db</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabg3tzf6VdoPe9kSJP3Ztwx7"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabg3tzf6VdoPe9kSJP3Ztwx7">geoplot</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabnLUefhqh88TvPqcNmSCmTF"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabnLUefhqh88TvPqcNmSCmTF">hit</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabADe98DqHDDxeEVth4oaKCm"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabADe98DqHDDxeEVth4oaKCm">somplot</label><div class="tab contentWBjT9pftQYJQeZAvtJTwo3">
#         <style>
#         #ipyplot-imgs-container-div-FY6DbSmbjCTLSMymRXZDEN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FY6DbSmbjCTLSMymRXZDEN">
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-FM3NAnvJKqKYNsZmPaLxX3" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_1.png</h4><img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-FM3NAnvJKqKYNsZmPaLxX3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-hEGcpSPu6NgJW824STUFkJ" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_2.png</h4><img src="results\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-hEGcpSPu6NgJW824STUFkJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-ATMMRsJmHPSa2v5Ne53LDd" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left:
# <div>
#         <style>
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM {
#                 display: none;
#             }
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM + label.ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM:checked + label.ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM ~ .tab {
#                 display: none
#             }
#     #tabWBjT9pftQYJQeZAvtJTwo3:checked ~ .tab.contentWBjT9pftQYJQeZAvtJTwo3,#tabhVNv2VZGyBHUE3GffQGUxz:checked ~ .tab.contenthVNv2VZGyBHUE3GffQGUxz,#tabg3tzf6VdoPe9kSJP3Ztwx7:checked ~ .tab.contentg3tzf6VdoPe9kSJP3Ztwx7,#tabnLUefhqh88TvPqcNmSCmTF:checked ~ .tab.contentnLUefhqh88TvPqcNmSCmTF,#tabADe98DqHDDxeEVth4oaKCm:checked ~ .tab.contentADe98DqHDDxeEVth4oaKCm{ display: block; }</style><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabWBjT9pftQYJQeZAvtJTwo3" checked /><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabWBjT9pftQYJQeZAvtJTwo3">boxplot</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabhVNv2VZGyBHUE3GffQGUxz"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabhVNv2VZGyBHUE3GffQGUxz">db</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabg3tzf6VdoPe9kSJP3Ztwx7"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabg3tzf6VdoPe9kSJP3Ztwx7">geoplot</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabnLUefhqh88TvPqcNmSCmTF"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabnLUefhqh88TvPqcNmSCmTF">hit</label><input class="ipyplot-tab-a7JZo9Tq8arJVMmV9XiZxM" type="radio" name="tabs-a7JZo9Tq8arJVMmV9XiZxM" id="tabADe98DqHDDxeEVth4oaKCm"/><label class="ipyplot-tab-label-a7JZo9Tq8arJVMmV9XiZxM" for="tabADe98DqHDDxeEVth4oaKCm">somplot</label><div class="tab contentWBjT9pftQYJQeZAvtJTwo3">
#         <style>
#         #ipyplot-imgs-container-div-FY6DbSmbjCTLSMymRXZDEN {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FY6DbSmbjCTLSMymRXZDEN">
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-FM3NAnvJKqKYNsZmPaLxX3" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_1.png</h4><img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-FM3NAnvJKqKYNsZmPaLxX3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-hEGcpSPu6NgJW824STUFkJ" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_2.png</h4><img src="results\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-hEGcpSPu6NgJW824STUFkJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-ATMMRsJmHPSa2v5Ne53LDd" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_3.png</h4><img src="results\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-ATMMRsJmHPSa2v5Ne53LDd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-UNk3EcVMHpqDXpjb2849Rw" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_4.png</h4><img src="results\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-UNk3EcVMHpqDXpjb2849Rw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FY6DbSmbjCTLSMymRXZDEN">
#         <div id="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN-Bf75u8ss2ne2dphiC9TT3b" class="ipyplot-content-div-FY6DbSmbjCTLSMymRXZDEN">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wr
#     <style>
#         #ipyplot-html-viewer-toggle-noD5VftMChBSdbmiNSMWt4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-noD5VftMChBSdbmiNSMWt4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-noD5VftMChBSdbmiNSMWt4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-noD5VftMChBSdbmiNSMWt4:checked ~ #ipyplot-html-viewer-textarea-noD5VftMChBSdbmiNSMWt4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-noD5VftMChBSdbmiNSMWt4:checked + #ipyplot-html-viewer-label-noD5VftMChBSdbmiNSMWt4:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-noD5VftMChBSdbmiNSMWt4">
#         <label id="ipyplot-html-viewer-label-noD5VftMChBSdbmiNSMWt4" for="ipyplot-html-viewer-toggle-noD5VftMChBSdbmiNSMWt4">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-noD5VftMChBSdbmiNSMWt4" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-kXC9Tm3SoH9mV8yRisWswn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kXC9Tm3SoH9mV8yRisWswn">
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-KsNeqU8pqr8U7FY3iEYXtD" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-KsNeqU8pqr8U7FY3iEYXtD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-7XTniRKwZfS6VvZhjdU4LV" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="results\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-7XTniRKwZfS6VvZhjdU4LV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-UvXkm6eMJW3zzGsAaYrqy7" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="results\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-UvXkm6eMJW3zzGsAaYrqy7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-oQT3yLXcRgFxZz5tLVhHR4" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="results\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-oQT3yLXcRgFxZz5tLVhHR4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-ibw22W3o6P5X53THzcqgi9" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_5.png</h4>
#             <img src="results\plots\boxplot_5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-ibw22W3o6P5X53THzcqgi9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-Ki8RJohwM8cGp9U4RrMB8t" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_6.png</h4>
#             <img src="results\plots\boxplot_6.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-Ki8RJohwM8cGp9U4RrMB8t">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-M74Q3LoWRHmGLE9eTanBfB" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_7.png</h4>
#             <img src="results\plots\boxplot_7.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-M74Q3LoWRHmGLE9eTanBfB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3S
#         <style>
#         #ipyplot-imgs-container-div-kXC9Tm3SoH9mV8yRisWswn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-kXC9Tm3SoH9mV8yRisWswn">
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-KsNeqU8pqr8U7FY3iEYXtD" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-KsNeqU8pqr8U7FY3iEYXtD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-7XTniRKwZfS6VvZhjdU4LV" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="results\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-7XTniRKwZfS6VvZhjdU4LV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-UvXkm6eMJW3zzGsAaYrqy7" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="results\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-UvXkm6eMJW3zzGsAaYrqy7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-oQT3yLXcRgFxZz5tLVhHR4" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="results\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-oQT3yLXcRgFxZz5tLVhHR4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-ibw22W3o6P5X53THzcqgi9" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_5.png</h4>
#             <img src="results\plots\boxplot_5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-ibw22W3o6P5X53THzcqgi9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-Ki8RJohwM8cGp9U4RrMB8t" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_6.png</h4>
#             <img src="results\plots\boxplot_6.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-Ki8RJohwM8cGp9U4RrMB8t">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-M74Q3LoWRHmGLE9eTanBfB" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_7.png</h4>
#             <img src="results\plots\boxplot_7.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-M74Q3LoWRHmGLE9eTanBfB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-gdKkq46WR5qXoTT45cXsNJ" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="results\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-gdKkq46WR5qXoTT45cXsNJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-3zQk42XbVsTCkPKui6yVUk" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="results\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-3zQk42XbVsTCkPKui6yVUk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-kXC9Tm3SoH9mV8yRisWswn">
#         <div id="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn-XVECvyiGWXjtok6CNBpfqi" class="ipyplot-content-div-kXC9Tm3SoH9mV8yRisWswn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="results\plots\geoplot_1.png"/>
#             <a href="#!">
