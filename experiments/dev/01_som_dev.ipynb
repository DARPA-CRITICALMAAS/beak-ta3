# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import magmatic_nickel_nat
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "TEST_RUN_SOM"
model = magmatic_nickel_nat.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "EPSG_4326_RES_0_025"
BASE_EXTENT = "CLIPPED_USC"

# Choose data path
PATH_MCCAFFERTY =  BASE_PATH / "MCCAFFERTY23" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "GEOPHYSICS_SCALED_STD"
PATH_ISOGRAVITY = BASE_PATH / "GEOPHYSICS_ISOGRAVITY" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_MAGNETOTELLURIC = BASE_PATH / "GEOPHYSICS_MAGNETOTELLURICS" / "PROCESSED" / "CONUS_2023" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_ULTRAMAFICS = BASE_PATH / "GEOLOGY_US_ULTRAMAFICS" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED"
PATH_LAWLEY_NUMERICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "NUMERICAL_SCALED_STANDARD"
PATH_LAWLEY_CATEGORICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "CATEGORICAL"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "MAGMATIC_NICKEL_NAT" / "MAGMATIC_NICKEL_TA2_EPSG_4326_RES_0_025_CLIPPED_USC.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_MAGNETOTELLURIC, PATH_ISOGRAVITY,
             PATH_MCCAFFERTY, PATH_LAWLEY_NUMERICAL,
             PATH_ULTRAMAFICS, PATH_LAWLEY_CATEGORICAL],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 4 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 6 folders, 43 subfolders and 837 files.
#
# Searching for corresponding files...
# Found 'US_IsostaticGravity_WGS84' in 1 file(s).
# Found 'CONUS_MT2023_9km_cog' in 1 file(s).
# Found 'MagRTP' in 1 file(s).
# Found 'Mag_AnalyticSignal_cog' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 4

# %%
# Replace Mag Analytical Signal STD with LOG version
LOG_MOD = True

if LOG_MOD is True:
    for i, path in enumerate(file_list):
        if "Mag_AnalyticSignal_cog.tif" in str(path):
            print(f"{path} found at index {i}.")
            file_list[i] = str(file_list[i]).replace("GEOPHYSICS_SCALED_STD", "GEOPHYSICS_SCALED_LOG")
            file_list[i] = Path(file_list[i])
            break
# Out:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Mag_AnalyticSignal_cog.tif found at index 3.

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 30                    # X dimension of generated SOM
args.som_y = 30                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 45               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = False                 # Whether data contains label column, True or False

# %%
# Set model name and folder
#MODEL_NAME = "SOM_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_NAME = "TEST"
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME
check_path(MODEL_FOLDER)
# Out:
# WindowsPath('d:/Programmieren/00_Repositories/CMAAS/beak-ta3/experiments/dev/models/TEST')

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 4
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_MAGNETOTELLURICS\PROCESSED\CONUS_2023\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\CONUS_MT2023_9km_cog.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\MagRTP.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif
# Number of files added: 1
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\TRAINING_LABELS\MAGMATIC_NICKEL_NAT\MAGMATIC_NICKEL_TA2_EPSG_4326_RES_0_025_CLIPPED_USC.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
# Warning: Geotransform of d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif does not match with d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
#     Execution time: 0.15352392196655273 seconds
# Run SOM
#     Execution time: 17.249600648880005 seconds
# Clustering progress:
#   File "c:\Users\storch\AppData\Local\miniconda3\envs\beak-ta3\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# 0.00%
# 10.00%
# 20.00%
# 30.00%
# 40.00%
# 50.00%
# 60.00%
# 70.00%
# 80.00%
# 90.00%
# 100% Clustering completed.
#     Execution time: 2.7958056926727295 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 18.56386113166809 seconds
# Save SOM space results
#     Execution time: 0.7102611064910889 seconds
# Save SOM object to file
#     Execution time: 0.0 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_US_IsostaticGravity_WGS84
#           b_CONUS_MT2023_9km_cog
#           b_MagRTP
#           b_Mag_AnalyticSignal_cog
#     Execution time: 5.083322525024414 seconds
# Count cluster hit count
#         Cluster hit count: 46 - 44284
#         Cluster hit count: 45 - 15419
#         Cluster hit count: 44 - 10350
#         Cluster hit count: 43 - 15182
#         Cluster hit count: 42 - 13993
#         Cluster hit count: 41 - 41327
#         Cluster hit count: 40 - 25686
#         Cluster hit count: 39 - 29051
#         Cluster hit count: 38 - 28867
#         Cluster hit count: 37 - 24721
#         Cluster hit count: 36 - 51406
#         Cluster hit count: 35 - 6278
#         Cluster hit count: 34 - 14062
#         Cluster hit count: 33 - 41452
#         Cluster hit count: 32 - 37043
#         Cluster hit count: 31 - 12461
#         Cluster hit count: 30 - 17726
#         Cluster hit count: 29 - 17759
#         Cluster hit count: 28 - 17502
#         Cluster hit count: 27 - 24043
#         Cluster hit count: 26 - 28824
#         Cluster hit count: 25 - 38424
#         Cluster hit count: 24 - 14415
#         Cluster hit count: 23 - 75761
#         Cluster hit count: 22 - 3799
#         Cluster hit count: 21 - 27788
#         Cluster hit count: 20 - 51168
#         Cluster hit count: 19 - 43171
#         Cluster hit count: 18 - 33657
#         Cluster hit count: 17 - 13525
#         Cluster hit count: 16 - 4578
#         Cluster hit count: 15 - 9322
#         Cluster hit count: 14 - 15385
#         Cluster hit count: 13 - 45770
#         Cluster hit count: 12 - 27163
#         Cluster hit count: 11 - 17606
#         Cluster hit count: 10 - 29627
#         Cluster hit count: 9 - 29089
#         Cluster hit count: 8 - 42698
#         Cluster hit count: 7 - 48771
#         Cluster hit count: 6 - 35191
#         Cluster hit count: 5 - 25938
#         Cluster hit count: 4 - 6087
#         Cluster hit count: 3 - 20241
#         Cluster hit count: 2 - 24696
#         Cluster hit count: 1 - 31255
#         Cluster hit count: 0 - 58499
#     Execution time: 23.952681303024292 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
#import beak.methods.som.argsSOM as asom
#from pathlib import Path
#
#args = asom.Args()
#
#args.output_folder = str(Path.cwd() / "models" / "TEST" /"exports")
#file_path = args.output_folder + "/../input_file_list.txt"
#args.input_file = args.create_list_from_file(file_path)
#args.output_file_somspace = args.output_folder + "/result_som.txt"
#args.som_x = 30
#args.som_y = 30
#args.output_file_geospace = args.output_folder + "/result_geo.txt"

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.007986068725585938 seconds
#         Read geo data execution time: 2.6624393463134766 seconds
#     Execution time: 2.674424886703491 seconds
# Plot geo space results
#     geospace plot no. 2 from 6
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\methods\som\plot_som_results.py:383: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 6 from 6
#     q-error plot
#     Execution time: 13.165262937545776 seconds
# Plot Cluster result SOM space
#     Plot Davies Bouldin index
#     Plot cluster hit count
# Plot SOM space results
#     somspace plot no. 4 from 4
#     Execution time: 2.2602648735046387 seconds
# Plot Boxplots
#     boxplot no. 4 from 4
#     Execution time: 3.18343448638916 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-WM55JoPB59Xi3WBM4NmKav {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WM55JoPB59Xi3WBM4NmKav {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WM55JoPB59Xi3WBM4NmKav {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WM55JoPB59Xi3WBM4NmKav:checked ~ #ipyplot-html-viewer-textarea-WM55JoPB59Xi3WBM4NmKav {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WM55JoPB59Xi3WBM4NmKav:checked + #ipyplot-html-viewer-label-WM55JoPB59Xi3WBM4NmKav:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-WM55JoPB59Xi3WBM4NmKav">
#         <label id="ipyplot-html-viewer-label-WM55JoPB59Xi3WBM4NmKav" for="ipyplot-html-viewer-toggle-WM55JoPB59Xi3WBM4NmKav">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-WM55JoPB59Xi3WBM4NmKav" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH {
#                 display: none;
#             }
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH + label.ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH:checked + label.ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH ~ .tab {
#                 display: none
#             }
#     #tabUqXfGD2LdQSp9hpJcuB8qB:checked ~ .tab.contentUqXfGD2LdQSp9hpJcuB8qB,#tabQxSYskvp8rFyPgPNg4wEud:checked ~ .tab.contentQxSYskvp8rFyPgPNg4wEud,#tabPdJwiZJaUUXMcFMLStFK45:checked ~ .tab.contentPdJwiZJaUUXMcFMLStFK45,#tabV7AoaLzEkZRsaxKB2TMxCB:checked ~ .tab.contentV7AoaLzEkZRsaxKB2TMxCB,#tabcS9ppVFR7SQ9UkpJE4P7Yp:checked ~ .tab.contentcS9ppVFR7SQ9UkpJE4P7Yp{ display: block; }</style><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabUqXfGD2LdQSp9hpJcuB8qB" checked /><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabUqXfGD2LdQSp9hpJcuB8qB">boxplot</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabQxSYskvp8rFyPgPNg4wEud"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabQxSYskvp8rFyPgPNg4wEud">db</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabPdJwiZJaUUXMcFMLStFK45"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabPdJwiZJaUUXMcFMLStFK45">geoplot</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabV7AoaLzEkZRsaxKB2TMxCB"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabV7AoaLzEkZRsaxKB2TMxCB">hit</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabcS9ppVFR7SQ9UkpJE4P7Yp"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabcS9ppVFR7SQ9UkpJE4P7Yp">somplot</label><div class="tab contentUqXfGD2LdQSp9hpJcuB8qB">
#         <style>
#         #ipyplot-imgs-container-div-LE9tK5zB3Xywgha2tXStDp {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LE9tK5zB3Xywgha2tXStDp">
#     <div class="ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp">
#         <div id="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-JabQvSxNiuZJiDvBjfEnFP" class="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_1.png</h4><img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-JabQvSxNiuZJiDvBjfEnFP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp">
#         <div id="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-TGE8TVBfTc79kHLFdAqGjm" class="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_2.png</h4><img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-TGE8TVBfTc79kHLFdAqGjm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp">
#         <div id="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-XFNPvhRx8CeJ3SU8cKnRVZ" class="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
# <div>
#         <style>
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH {
#                 display: none;
#             }
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH + label.ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH:checked + label.ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-GhPghnpESTLRQnKW7EAYEH ~ .tab {
#                 display: none
#             }
#     #tabUqXfGD2LdQSp9hpJcuB8qB:checked ~ .tab.contentUqXfGD2LdQSp9hpJcuB8qB,#tabQxSYskvp8rFyPgPNg4wEud:checked ~ .tab.contentQxSYskvp8rFyPgPNg4wEud,#tabPdJwiZJaUUXMcFMLStFK45:checked ~ .tab.contentPdJwiZJaUUXMcFMLStFK45,#tabV7AoaLzEkZRsaxKB2TMxCB:checked ~ .tab.contentV7AoaLzEkZRsaxKB2TMxCB,#tabcS9ppVFR7SQ9UkpJE4P7Yp:checked ~ .tab.contentcS9ppVFR7SQ9UkpJE4P7Yp{ display: block; }</style><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabUqXfGD2LdQSp9hpJcuB8qB" checked /><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabUqXfGD2LdQSp9hpJcuB8qB">boxplot</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabQxSYskvp8rFyPgPNg4wEud"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabQxSYskvp8rFyPgPNg4wEud">db</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabPdJwiZJaUUXMcFMLStFK45"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabPdJwiZJaUUXMcFMLStFK45">geoplot</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabV7AoaLzEkZRsaxKB2TMxCB"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabV7AoaLzEkZRsaxKB2TMxCB">hit</label><input class="ipyplot-tab-GhPghnpESTLRQnKW7EAYEH" type="radio" name="tabs-GhPghnpESTLRQnKW7EAYEH" id="tabcS9ppVFR7SQ9UkpJE4P7Yp"/><label class="ipyplot-tab-label-GhPghnpESTLRQnKW7EAYEH" for="tabcS9ppVFR7SQ9UkpJE4P7Yp">somplot</label><div class="tab contentUqXfGD2LdQSp9hpJcuB8qB">
#         <style>
#         #ipyplot-imgs-container-div-LE9tK5zB3Xywgha2tXStDp {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LE9tK5zB3Xywgha2tXStDp">
#     <div class="ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp">
#         <div id="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-JabQvSxNiuZJiDvBjfEnFP" class="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_1.png</h4><img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-JabQvSxNiuZJiDvBjfEnFP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp">
#         <div id="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-TGE8TVBfTc79kHLFdAqGjm" class="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_2.png</h4><img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-TGE8TVBfTc79kHLFdAqGjm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp">
#         <div id="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-XFNPvhRx8CeJ3SU8cKnRVZ" class="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_3.png</h4><img src="models\TEST\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-XFNPvhRx8CeJ3SU8cKnRVZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LE9tK5zB3Xywgha2tXStDp">
#         <div id="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-iACN9TKeuyiCqWpVX7wwbq" class="ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_4.png</h4><img src="models\TEST\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LE9tK5zB3Xywgha2tXStDp-iACN9TKeuyiCqWpVX7wwbq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentQxSYskvp8rFyPgPNg4wEud">
#         <style>
#         #ipyplot-imgs-container-div-j9yBZavdchihssxRkCApSq {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#     <style>
#         #ipyplot-html-viewer-toggle-eWHzEutxnvWn5h4pwQQgEw {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eWHzEutxnvWn5h4pwQQgEw {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eWHzEutxnvWn5h4pwQQgEw {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eWHzEutxnvWn5h4pwQQgEw:checked ~ #ipyplot-html-viewer-textarea-eWHzEutxnvWn5h4pwQQgEw {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eWHzEutxnvWn5h4pwQQgEw:checked + #ipyplot-html-viewer-label-eWHzEutxnvWn5h4pwQQgEw:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-eWHzEutxnvWn5h4pwQQgEw">
#         <label id="ipyplot-html-viewer-label-eWHzEutxnvWn5h4pwQQgEw" for="ipyplot-html-viewer-toggle-eWHzEutxnvWn5h4pwQQgEw">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-eWHzEutxnvWn5h4pwQQgEw" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-J3iTfmUNMrpPsDHi8nx9zZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-J3iTfmUNMrpPsDHi8nx9zZ">
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-jfLbAmUubaHLHj2xRcADCr" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-jfLbAmUubaHLHj2xRcADCr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-SXFbmpQdVzjPgMctBnA8mL" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-SXFbmpQdVzjPgMctBnA8mL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-LYx7ne63m2JA5H3KhChb3E" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-LYx7ne63m2JA5H3KhChb3E">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-VBySmFanB7yngc4dUvewYM" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-VBySmFanB7yngc4dUvewYM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-8tuQSur3HTUteMMhzQz8pn" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\TEST\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-8tuQSur3HTUteMMhzQz8pn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-a4Di7JatKuenAQH5HUsR5P" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\TEST\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-a4Di7JatKuenAQH5HUsR5P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-No7wTdQCHDdjaVZdVpmGy5" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-No7wTdQCHDdjaVZdVpmGy5">
#                 <span class="ipyplot-img-expand"/
#         <style>
#         #ipyplot-imgs-container-div-J3iTfmUNMrpPsDHi8nx9zZ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-J3iTfmUNMrpPsDHi8nx9zZ">
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-jfLbAmUubaHLHj2xRcADCr" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-jfLbAmUubaHLHj2xRcADCr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-SXFbmpQdVzjPgMctBnA8mL" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-SXFbmpQdVzjPgMctBnA8mL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-LYx7ne63m2JA5H3KhChb3E" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-LYx7ne63m2JA5H3KhChb3E">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-VBySmFanB7yngc4dUvewYM" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-VBySmFanB7yngc4dUvewYM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-8tuQSur3HTUteMMhzQz8pn" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\TEST\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-8tuQSur3HTUteMMhzQz8pn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-a4Di7JatKuenAQH5HUsR5P" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\TEST\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-a4Di7JatKuenAQH5HUsR5P">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-No7wTdQCHDdjaVZdVpmGy5" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-No7wTdQCHDdjaVZdVpmGy5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-6hPcZhBtktRWhnoVy9XpxH" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_2.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-6hPcZhBtktRWhnoVy9XpxH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-Nt8mDNX8XryrhhuU8LEG36" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_3.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-Nt8mDNX8XryrhhuU8LEG36">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-J3iTfmUNMrpPsDHi8nx9zZ">
#         <div id="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ-VSqbG399zAu46EijVirDFA" class="ipyplot-content-div-J3iTfmUNMrpPsDHi8nx9zZ">
#             <h4 style="font-size: 12px; word-wrap: break-word;
