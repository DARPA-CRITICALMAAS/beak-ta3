# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import magmatic_nickel_nat
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "TEST_RUN_SOM"
model = magmatic_nickel_nat.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "EPSG_4326_RES_0_025"
BASE_EXTENT = "CLIPPED_USC"

# Choose data path
PATH_MCCAFFERTY =  BASE_PATH / "MCCAFFERTY23" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "GEOPHYSICS_SCALED_STD"
PATH_ISOGRAVITY = BASE_PATH / "GEOPHYSICS_ISOGRAVITY" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_MAGNETOTELLURIC = BASE_PATH / "GEOPHYSICS_MAGNETOTELLURICS" / "PROCESSED" / "CONUS_2023" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_ULTRAMAFICS = BASE_PATH / "GEOLOGY_US_ULTRAMAFICS" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED"
PATH_LAWLEY_NUMERICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "NUMERICAL_SCALED_STANDARD"
PATH_LAWLEY_CATEGORICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "CATEGORICAL"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "MAGMATIC_NICKEL_NAT" / "MAGMATIC_NICKEL_TA2_EPSG_4326_RES_0_025_CLIPPED_USC.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_MAGNETOTELLURIC, PATH_ISOGRAVITY,
             PATH_MCCAFFERTY, PATH_LAWLEY_NUMERICAL,
             PATH_ULTRAMAFICS, PATH_LAWLEY_CATEGORICAL],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 2 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 6 folders, 43 subfolders and 837 files.
#
# Searching for corresponding files...
# Found 'US_IsostaticGravity_WGS84' in 1 file(s).
# Found 'Mag_AnalyticSignal_cog' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 2

# %%
# Replace Mag Analytical Signal STD with LOG version
LOG_MOD = True

if LOG_MOD is True:
    for i, path in enumerate(file_list):
        if "Mag_AnalyticSignal_cog.tif" in str(path):
            print(f"{path} found at index {i}.")
            file_list[i] = str(file_list[i]).replace("GEOPHYSICS_SCALED_STD", "GEOPHYSICS_SCALED_LOG")
            file_list[i] = Path(file_list[i])
            break
# Out:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Mag_AnalyticSignal_cog.tif found at index 1.

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 30                    # X dimension of generated SOM
args.som_y = 30                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 45               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
#MODEL_NAME = "SOM_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_NAME = "TEST"
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME
check_path(MODEL_FOLDER)
# Out:
# WindowsPath('d:/Programmieren/00_Repositories/CMAAS/beak-ta3/experiments/dev/models/TEST')

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 2
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif
# Number of files added: 1
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\TRAINING_LABELS\MAGMATIC_NICKEL_NAT\MAGMATIC_NICKEL_TA2_EPSG_4326_RES_0_025_CLIPPED_USC.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)

#from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
#nxtsomcore = NxtSomCore()
#inputFileArray=args.geotiff_input.split(",")    
#nxtsomcore.write_geotiff_out(args.output_folder, args.output_file_geospace, args.output_file_somspace, inputFileArray[0], args.label)
# Out:
# Load data
# Warning: Geotransform of d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif does not match with d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
#     Execution time: 0.09998607635498047 seconds
# Run SOM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 with warnings.catch_warnings():
#       9     warnings.simplefilter("ignore")
# ---> 10     dnsr.run_SOM(args)
#      12 #from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
#      13 #nxtsomcore = NxtSomCore()
#      14 #inputFileArray=args.geotiff_input.split(",")
#      15 #nxtsomcore.write_geotiff_out(args.output_folder, args.output_file_geospace, args.output_file_somspace, inputFileArray[0], args.label)
#
# File d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\methods\som\do_nextsomcore_save_results.py:34, in run_SOM(args)
#      32 print('Run SOM')
#      33 start_time = time.time()
# ---> 34 som = nxtsomcore.train(
#      35     header['data'],
#      36     args.som_x,
#      37     args.som_y,
#      38     args.epochs,
#      39     kerneltype=0,
#      40     verbose=1,
#      41     neighborhood=args.neighborhood,
#      42     std_coeff=args.std_coeff,
#      43     maptype=args.maptype,
#      44     radiuscooling=args.radiuscooling,
#      45     scalecooling=args.scalecooling,
#      46     initialization=args.initialization,
#      47     initialcodebook=args.initialcodebook,
#      48     gridtype=args.gridtype
#      49     )
#      50 end_time = time.time()
#      51 print(f"    Execution time: {end_time - start_time} seconds")
#
# File d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\methods\som\nextsomcore\nextsomcore.py:71, in NxtSomCore.train(self, data, som_x, som_y, epochs, **kwargs)
#      50         """Train the map and return results as a dict.
#      51
#      52         Args:
#    (...)
#      59             dict: Dictionary holding SOM results, umatrix and meta data like number of columns and rows.
#      60         """
#      62         self.som = somoclu.Somoclu(som_x, som_y,
#      63             kerneltype = kwargs.pop("kerneltype", 0),
#      64   			verbose = kwargs.pop("verbose", 2),
#    (...)
#      69             initialization=kwargs.pop("initialization", 'random'),
#      70             gridtype=kwargs.pop("gridtype","rectangular" ) )
# ---> 71         self.som.train(data, epochs,
#      72 			radius0 = kwargs.pop("radius0", 0),
#      73 			radiusN = kwargs.pop("radiusN", 1),
#      74 			radiuscooling = kwargs.pop("radiuscooling", "linear"),
#      75 			scale0 = kwargs.pop("scale0", 0.1),
#      76 			scaleN = kwargs.pop("scaleN", 0.01),
#      77 			scalecooling = kwargs.pop("scalecooling", "linear"))
#      78         return {
#      79             'codebook': self.som.codebook.copy(),
#      80             'bmus': self.som.bmus.copy(),
#    (...)
#      84             'n_dim': self.som.n_dim,
#      85             'clusters': None}
#
# File c:\Users\storch\AppData\Local\miniconda3\envs\beak-ta3\lib\site-packages\somoclu\train.py:236, in Somoclu.train(self, data, epochs, radius0, radiusN, radiuscooling, scale0, scaleN, scalecooling)
#     234 self.umatrix.shape = (self._n_rows * self._n_columns, )
#     235 self.bmus.shape = (self.n_vectors * 2, )
# --> 236 wrap_train(np.ravel(self._data), epochs, self._n_columns, self._n_rows,
#     237            self.n_dim, self.n_vectors, radius0, radiusN,
#     238            radiuscooling, scale0, scaleN, scalecooling,
#     239            self._kernel_type, self._map_type, self._grid_type,
#     240            self._compact_support, self._neighborhood == "gaussian",
#     241            self._std_coeff, self._verbose, self.codebook, self.bmus,
#     242            self.umatrix, self._vect_distance)
#     243 self.umatrix.shape = (self._n_rows, self._n_columns)
#     244 self.bmus.shape = (self.n_vectors, 2)
#
# KeyboardInterrupt:

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
#import beak.methods.som.argsSOM as asom
#from pathlib import Path
#
#args = asom.Args()
#
#args.output_folder = str(Path.cwd() / "models" / "TEST" /"exports")
#file_path = args.output_folder + "/../input_file_list.txt"
#args.input_file = args.create_list_from_file(file_path)
#args.output_file_somspace = args.output_folder + "/result_som.txt"
#args.som_x = 30
#args.som_y = 30
#args.output_file_geospace = args.output_folder + "/result_geo.txt"

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.0 seconds
#         Read geo data execution time: 1.8691494464874268 seconds
#         Read label annotation data
#     Execution time: 4.791425943374634 seconds
# Plot geo space results
#     geospace plot no. 2 from 4
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\methods\som\plot_som_results.py:284: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 4 from 4
#     q-error plot
#     Execution time: 9.166852951049805 seconds
# Plot Cluster result SOM space
#     Plot Davies Bouldin index
#     Plot cluster hit count
# Plot SOM space results
#     somspace plot no. 2 from 2
#     Execution time: 1.7503578662872314 seconds
# Plot Boxplots
#     boxplot no. 2 from 2
#     Execution time: 1.5884051322937012 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-mC36DQEt6vcUbT6fNzF9Sj {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mC36DQEt6vcUbT6fNzF9Sj {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mC36DQEt6vcUbT6fNzF9Sj {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mC36DQEt6vcUbT6fNzF9Sj:checked ~ #ipyplot-html-viewer-textarea-mC36DQEt6vcUbT6fNzF9Sj {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mC36DQEt6vcUbT6fNzF9Sj:checked + #ipyplot-html-viewer-label-mC36DQEt6vcUbT6fNzF9Sj:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-mC36DQEt6vcUbT6fNzF9Sj">
#         <label id="ipyplot-html-viewer-label-mC36DQEt6vcUbT6fNzF9Sj" for="ipyplot-html-viewer-toggle-mC36DQEt6vcUbT6fNzF9Sj">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-mC36DQEt6vcUbT6fNzF9Sj" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r {
#                 display: none;
#             }
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r + label.ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r:checked + label.ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r ~ .tab {
#                 display: none
#             }
#     #tabGVgk3Q5jxXK7a6tfMFQ9Np:checked ~ .tab.contentGVgk3Q5jxXK7a6tfMFQ9Np,#tab7c85cz8KaMSmqf2XqnmwF3:checked ~ .tab.content7c85cz8KaMSmqf2XqnmwF3,#tabHFDyafCUzu78eUdh9gBacQ:checked ~ .tab.contentHFDyafCUzu78eUdh9gBacQ,#tab2yjt8Y4tWrLgfAhdQauYgZ:checked ~ .tab.content2yjt8Y4tWrLgfAhdQauYgZ,#tabRyAUt5tzACKvboYsGTgem9:checked ~ .tab.contentRyAUt5tzACKvboYsGTgem9{ display: block; }</style><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tabGVgk3Q5jxXK7a6tfMFQ9Np" checked /><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tabGVgk3Q5jxXK7a6tfMFQ9Np">boxplot</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tab7c85cz8KaMSmqf2XqnmwF3"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tab7c85cz8KaMSmqf2XqnmwF3">db</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tabHFDyafCUzu78eUdh9gBacQ"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tabHFDyafCUzu78eUdh9gBacQ">geoplot</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tab2yjt8Y4tWrLgfAhdQauYgZ"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tab2yjt8Y4tWrLgfAhdQauYgZ">hit</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tabRyAUt5tzACKvboYsGTgem9"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tabRyAUt5tzACKvboYsGTgem9">somplot</label><div class="tab contentGVgk3Q5jxXK7a6tfMFQ9Np">
#         <style>
#         #ipyplot-imgs-container-div-jvfbf5Cm9PFsaCRvyNn89E {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jvfbf5Cm9PFsaCRvyNn89E {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jvfbf5Cm9PFsaCRvyNn89E">
#     <div class="ipyplot-placeholder-div-jvfbf5Cm9PFsaCRvyNn89E">
#         <div id="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-n9TsXUVspPXmbAER7GDiZ9" class="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_1.png</h4><img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-n9TsXUVspPXmbAER7GDiZ9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvfbf5Cm9PFsaCRvyNn89E">
#         <div id="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-5TpfuRipbZ8bAy7moMW6Gi" class="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_2.png</h4><img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-5TpfuRipbZ8bAy7moMW6Gi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab content7c85cz8KaMSmqf2XqnmwF3">
#         <style>
#         #ipyplot-imgs-container-div-iXKVh6mcog5BmdCScBGHu2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
# <div>
#         <style>
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r {
#                 display: none;
#             }
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r + label.ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r:checked + label.ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r ~ .tab {
#                 display: none
#             }
#     #tabGVgk3Q5jxXK7a6tfMFQ9Np:checked ~ .tab.contentGVgk3Q5jxXK7a6tfMFQ9Np,#tab7c85cz8KaMSmqf2XqnmwF3:checked ~ .tab.content7c85cz8KaMSmqf2XqnmwF3,#tabHFDyafCUzu78eUdh9gBacQ:checked ~ .tab.contentHFDyafCUzu78eUdh9gBacQ,#tab2yjt8Y4tWrLgfAhdQauYgZ:checked ~ .tab.content2yjt8Y4tWrLgfAhdQauYgZ,#tabRyAUt5tzACKvboYsGTgem9:checked ~ .tab.contentRyAUt5tzACKvboYsGTgem9{ display: block; }</style><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tabGVgk3Q5jxXK7a6tfMFQ9Np" checked /><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tabGVgk3Q5jxXK7a6tfMFQ9Np">boxplot</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tab7c85cz8KaMSmqf2XqnmwF3"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tab7c85cz8KaMSmqf2XqnmwF3">db</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tabHFDyafCUzu78eUdh9gBacQ"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tabHFDyafCUzu78eUdh9gBacQ">geoplot</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tab2yjt8Y4tWrLgfAhdQauYgZ"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tab2yjt8Y4tWrLgfAhdQauYgZ">hit</label><input class="ipyplot-tab-XcCT2QvxgWYbp86zLSmy2r" type="radio" name="tabs-XcCT2QvxgWYbp86zLSmy2r" id="tabRyAUt5tzACKvboYsGTgem9"/><label class="ipyplot-tab-label-XcCT2QvxgWYbp86zLSmy2r" for="tabRyAUt5tzACKvboYsGTgem9">somplot</label><div class="tab contentGVgk3Q5jxXK7a6tfMFQ9Np">
#         <style>
#         #ipyplot-imgs-container-div-jvfbf5Cm9PFsaCRvyNn89E {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jvfbf5Cm9PFsaCRvyNn89E {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jvfbf5Cm9PFsaCRvyNn89E">
#     <div class="ipyplot-placeholder-div-jvfbf5Cm9PFsaCRvyNn89E">
#         <div id="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-n9TsXUVspPXmbAER7GDiZ9" class="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_1.png</h4><img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-n9TsXUVspPXmbAER7GDiZ9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jvfbf5Cm9PFsaCRvyNn89E">
#         <div id="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-5TpfuRipbZ8bAy7moMW6Gi" class="ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\TEST\exports\plots\boxplot_2.png</h4><img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jvfbf5Cm9PFsaCRvyNn89E-5TpfuRipbZ8bAy7moMW6Gi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab content7c85cz8KaMSmqf2XqnmwF3">
#         <style>
#         #ipyplot-imgs-container-div-iXKVh6mcog5BmdCScBGHu2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-iXKVh6mcog5BmdCScBGHu2 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-iXKVh6mcog5BmdCScBGHu2]:target span.ipyplot-img-close {
#     <style>
#         #ipyplot-html-viewer-toggle-MAAK99wSRKcGWXHHuUGvxr {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-MAAK99wSRKcGWXHHuUGvxr {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-MAAK99wSRKcGWXHHuUGvxr {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-MAAK99wSRKcGWXHHuUGvxr:checked ~ #ipyplot-html-viewer-textarea-MAAK99wSRKcGWXHHuUGvxr {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-MAAK99wSRKcGWXHHuUGvxr:checked + #ipyplot-html-viewer-label-MAAK99wSRKcGWXHHuUGvxr:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-MAAK99wSRKcGWXHHuUGvxr">
#         <label id="ipyplot-html-viewer-label-MAAK99wSRKcGWXHHuUGvxr" for="ipyplot-html-viewer-toggle-MAAK99wSRKcGWXHHuUGvxr">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-MAAK99wSRKcGWXHHuUGvxr" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-S3yupFb24Kwr8gfbH5djKD {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-S3yupFb24Kwr8gfbH5djKD">
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-76Lns9gdLuqaU2Krpk3apM" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-76Lns9gdLuqaU2Krpk3apM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-BXmYzJV5ZEa3wN8iYDXRXo" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-BXmYzJV5ZEa3wN8iYDXRXo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-nsrLpfg3DpMpeYFHD9teT8" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\TEST\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-nsrLpfg3DpMpeYFHD9teT8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-PPB3HZ7PSAfne9WVhcdap5" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\TEST\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-PPB3HZ7PSAfne9WVhcdap5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-dhjYDA9uC7SE9zsbqybhBW" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-dhjYDA9uC7SE9zsbqybhBW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-ErPT2hX9aicryTfSPVjBbC" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_2.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-ErPT2hX9aicryTfSPVjBbC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-XhugSyCEdRK3reZg2Aqmyh" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_3.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-XhugSyCEdRK3reZg2Aqmyh">
#                 <span class="ipyplot-img-expand"/
#         <style>
#         #ipyplot-imgs-container-div-S3yupFb24Kwr8gfbH5djKD {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-S3yupFb24Kwr8gfbH5djKD">
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-76Lns9gdLuqaU2Krpk3apM" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-76Lns9gdLuqaU2Krpk3apM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-BXmYzJV5ZEa3wN8iYDXRXo" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\TEST\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-BXmYzJV5ZEa3wN8iYDXRXo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-nsrLpfg3DpMpeYFHD9teT8" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\TEST\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-nsrLpfg3DpMpeYFHD9teT8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-PPB3HZ7PSAfne9WVhcdap5" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\TEST\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-PPB3HZ7PSAfne9WVhcdap5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-dhjYDA9uC7SE9zsbqybhBW" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-dhjYDA9uC7SE9zsbqybhBW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-ErPT2hX9aicryTfSPVjBbC" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_2.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-ErPT2hX9aicryTfSPVjBbC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-XhugSyCEdRK3reZg2Aqmyh" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_3.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-XhugSyCEdRK3reZg2Aqmyh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-aigWA8Cpa4c4xaXYPie96V" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_4.png</h4>
#             <img src="models\TEST\exports\plots\geoplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-aigWA8Cpa4c4xaXYPie96V">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-nWc2vwXdGmnVcGX8wgVLqR" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;">somplot_1.png</h4>
#             <img src="models\TEST\exports\plots\somplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-nWc2vwXdGmnVcGX8wgVLqR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-S3yupFb24Kwr8gfbH5djKD">
#         <div id="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD-WQ9Adv9c4Tn32yEryanHXM" class="ipyplot-content-div-S3yupFb24Kwr8gfbH5djKD">
#             <h4 style="font-size: 12px; word-wrap: break-word;
