# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import magmatic_nickel_nat
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "TEST_RUN_SOM"
model = magmatic_nickel_nat.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "EPSG_4326_RES_0_025"
BASE_EXTENT = "CLIPPED_USC"

# Choose data path
PATH_MCCAFFERTY =  BASE_PATH / "MCCAFFERTY23" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "GEOPHYSICS_SCALED_STD"
PATH_ISOGRAVITY = BASE_PATH / "GEOPHYSICS_ISOGRAVITY" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_MAGNETOTELLURIC = BASE_PATH / "GEOPHYSICS_MAGNETOTELLURICS" / "PROCESSED" / "CONUS_2023" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_ULTRAMAFICS = BASE_PATH / "GEOLOGY_US_ULTRAMAFICS" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED"
PATH_LAWLEY_NUMERICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "NUMERICAL_SCALED_STANDARD"
PATH_LAWLEY_CATEGORICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "CATEGORICAL"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "MAGMATIC_NICKEL_NAT" / "MAGMATIC_NICKEL_TA2_EPSG_4326_RES_0_025_CLIPPED_USC.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_MAGNETOTELLURIC, PATH_ISOGRAVITY,
             PATH_MCCAFFERTY, PATH_LAWLEY_NUMERICAL,
             PATH_ULTRAMAFICS, PATH_LAWLEY_CATEGORICAL],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 4 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 6 folders, 43 subfolders and 837 files.
#
# Searching for corresponding files...
# Found 'US_IsostaticGravity_WGS84' in 1 file(s).
# Found 'CONUS_MT2023_9km_cog' in 1 file(s).
# Found 'MagRTP' in 1 file(s).
# Found 'Mag_AnalyticSignal_cog' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 4

# %%
# Replace Mag Analytical Signal STD with LOG version
LOG_MOD = True

if LOG_MOD is True:
    for i, path in enumerate(file_list):
        if "Mag_AnalyticSignal_cog.tif" in str(path):
            print(f"{path} found at index {i}.")
            file_list[i] = str(file_list[i]).replace("GEOPHYSICS_SCALED_STD", "GEOPHYSICS_SCALED_LOG")
            file_list[i] = Path(file_list[i])
            break
# Out:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Mag_AnalyticSignal_cog.tif found at index 3.

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 30                    # X dimension of generated SOM
args.som_y = 30                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 45               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
#MODEL_NAME = "SOM_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_NAME = "TEST"
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME
check_path(MODEL_FOLDER)
# Out:
# WindowsPath('d:/Programmieren/00_Repositories/CMAAS/beak-ta3/experiments/dev/models/SOM_F4_X30_Y30_CMAX50_20240314-151713')

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 4
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_MAGNETOTELLURICS\PROCESSED\CONUS_2023\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\CONUS_MT2023_9km_cog.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\MagRTP.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif
# Number of files added: 1
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\TRAINING_LABELS\MAGMATIC_NICKEL_NAT\MAGMATIC_NICKEL_TA2_EPSG_4326_RES_0_025_CLIPPED_USC.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
# Warning: Geotransform of d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif does not match with d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
#     Execution time: 0.18108677864074707 seconds
# Run SOM
#     Execution time: 17.586972951889038 seconds
# Clustering progress:
#   File "c:\Users\storch\AppData\Local\miniconda3\envs\beak-ta3\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# 0.00%
# 10.00%
# 20.00%
# 30.00%
# 40.00%
# 50.00%
# 60.00%
# 70.00%
# 80.00%
# 90.00%
# 100% Clustering completed.
#     Execution time: 2.6891698837280273 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 24.20596218109131 seconds
# Save SOM space results
#     Execution time: 0.7990729808807373 seconds
# Save SOM object to file
#     Execution time: 0.0 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_US_IsostaticGravity_WGS84
#           b_CONUS_MT2023_9km_cog
#           b_MagRTP
#           b_Mag_AnalyticSignal_cog
#     Execution time: 5.633349418640137 seconds
# Count cluster hit count
#         Cluster hit count: 47 - 30981
#         Cluster hit count: 46 - 33866
#         Cluster hit count: 45 - 12451
#         Cluster hit count: 44 - 11621
#         Cluster hit count: 43 - 28124
#         Cluster hit count: 42 - 25235
#         Cluster hit count: 41 - 20987
#         Cluster hit count: 40 - 43891
#         Cluster hit count: 39 - 17748
#         Cluster hit count: 38 - 40514
#         Cluster hit count: 37 - 35697
#         Cluster hit count: 36 - 20050
#         Cluster hit count: 35 - 50735
#         Cluster hit count: 34 - 34390
#         Cluster hit count: 33 - 15004
#         Cluster hit count: 32 - 19267
#         Cluster hit count: 31 - 25924
#         Cluster hit count: 30 - 8502
#         Cluster hit count: 29 - 26996
#         Cluster hit count: 28 - 17576
#         Cluster hit count: 27 - 26784
#         Cluster hit count: 26 - 31800
#         Cluster hit count: 25 - 13921
#         Cluster hit count: 24 - 13634
#         Cluster hit count: 23 - 39093
#         Cluster hit count: 22 - 15402
#         Cluster hit count: 21 - 13602
#         Cluster hit count: 20 - 29417
#         Cluster hit count: 19 - 17954
#         Cluster hit count: 18 - 33138
#         Cluster hit count: 17 - 16874
#         Cluster hit count: 16 - 16260
#         Cluster hit count: 15 - 29062
#         Cluster hit count: 14 - 42835
#         Cluster hit count: 13 - 8153
#         Cluster hit count: 12 - 29419
#         Cluster hit count: 11 - 46432
#         Cluster hit count: 10 - 19542
#         Cluster hit count: 9 - 17237
#         Cluster hit count: 8 - 51100
#         Cluster hit count: 7 - 35852
#         Cluster hit count: 6 - 56235
#         Cluster hit count: 5 - 39094
#         Cluster hit count: 4 - 37870
#         Cluster hit count: 3 - 15791
#         Cluster hit count: 2 - 15951
#         Cluster hit count: 1 - 22349
#         Cluster hit count: 0 - 36700
#     Execution time: 26.517303228378296 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsSOM as asom
from pathlib import Path

args = asom.Args()

args.output_folder = str(Path.cwd() / "models" / "TEST" /"exports")
file_path = args.output_folder + "/../input_file_list.txt"
args.input_file = args.create_list_from_file(file_path)
args.output_file_somspace = args.output_folder + "/result_som.txt"
args.som_x = 30
args.som_y = 30
args.output_file_geospace = args.output_folder + "/result_geo.txt"
# Out:
# Number of files added: 4
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\GEOPHYSICS_MAGNETOTELLURICS\PROCESSED\CONUS_2023\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\CONUS_MT2023_9km_cog.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\MagRTP.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = False                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.016803741455078125 seconds
#         Read geo data execution time: 2.7665321826934814 seconds
#     Execution time: 12.495200157165527 seconds
# Plot geo space results
#     Execution time: 1.8213210105895996 seconds
# Plot Cluster result SOM space
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Write som labels to file
#     Execution time: 2.9851555824279785 seconds
# Plot SOM space results
#     Execution time: 1.2983226776123047 seconds
# Plot Boxplots
#     boxplot no. 4 from 4
#     Execution time: 3.1821558475494385 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-HLRshSi4sVfqADbUjtiyEm {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-HLRshSi4sVfqADbUjtiyEm {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-HLRshSi4sVfqADbUjtiyEm {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-HLRshSi4sVfqADbUjtiyEm:checked ~ #ipyplot-html-viewer-textarea-HLRshSi4sVfqADbUjtiyEm {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-HLRshSi4sVfqADbUjtiyEm:checked + #ipyplot-html-viewer-label-HLRshSi4sVfqADbUjtiyEm:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-HLRshSi4sVfqADbUjtiyEm">
#         <label id="ipyplot-html-viewer-label-HLRshSi4sVfqADbUjtiyEm" for="ipyplot-html-viewer-toggle-HLRshSi4sVfqADbUjtiyEm">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-HLRshSi4sVfqADbUjtiyEm" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx {
#                 display: none;
#             }
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx + label.ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx:checked + label.ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx ~ .tab {
#                 display: none
#             }
#     #tabJuKQsiERykhHeX7wbBrFKY:checked ~ .tab.contentJuKQsiERykhHeX7wbBrFKY,#tabmw6qBJtFb2pUApxstqqBfP:checked ~ .tab.contentmw6qBJtFb2pUApxstqqBfP,#tabKRJ8hCExHHSMJupG9Z87M5:checked ~ .tab.contentKRJ8hCExHHSMJupG9Z87M5,#taboBjr4v4bitgfgxcWwCThXV:checked ~ .tab.contentoBjr4v4bitgfgxcWwCThXV,#tabdgUN7VHxTmXMXK2Cvc5idm:checked ~ .tab.contentdgUN7VHxTmXMXK2Cvc5idm{ display: block; }</style><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabJuKQsiERykhHeX7wbBrFKY" checked /><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabJuKQsiERykhHeX7wbBrFKY">boxplot</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabmw6qBJtFb2pUApxstqqBfP"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabmw6qBJtFb2pUApxstqqBfP">db</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabKRJ8hCExHHSMJupG9Z87M5"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabKRJ8hCExHHSMJupG9Z87M5">geoplot</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="taboBjr4v4bitgfgxcWwCThXV"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="taboBjr4v4bitgfgxcWwCThXV">hit</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabdgUN7VHxTmXMXK2Cvc5idm"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabdgUN7VHxTmXMXK2Cvc5idm">somplot</label><div class="tab contentJuKQsiERykhHeX7wbBrFKY">
#         <style>
#         #ipyplot-imgs-container-div-WdkinWwVk5KdCyLTfnsqGm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WdkinWwVk5KdCyLTfnsqGm">
#     <div class="ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm">
#         <div id="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-c86Swqgpjhci7Exq7QLHET" class="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_1.png</h4><img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-c86Swqgpjhci7Exq7QLHET">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm">
#         <div id="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-NEc7Zrt49Etd76KP9kEcaq" class="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_2.png</h4><img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-NEc7Zrt49Etd76KP9kEcaq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm">
#         <div id="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-KF7Qe3jy95jbHgwprBC
# <div>
#         <style>
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx {
#                 display: none;
#             }
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx + label.ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx:checked + label.ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-M8xk3dbWKeihKcjTYknGpx ~ .tab {
#                 display: none
#             }
#     #tabJuKQsiERykhHeX7wbBrFKY:checked ~ .tab.contentJuKQsiERykhHeX7wbBrFKY,#tabmw6qBJtFb2pUApxstqqBfP:checked ~ .tab.contentmw6qBJtFb2pUApxstqqBfP,#tabKRJ8hCExHHSMJupG9Z87M5:checked ~ .tab.contentKRJ8hCExHHSMJupG9Z87M5,#taboBjr4v4bitgfgxcWwCThXV:checked ~ .tab.contentoBjr4v4bitgfgxcWwCThXV,#tabdgUN7VHxTmXMXK2Cvc5idm:checked ~ .tab.contentdgUN7VHxTmXMXK2Cvc5idm{ display: block; }</style><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabJuKQsiERykhHeX7wbBrFKY" checked /><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabJuKQsiERykhHeX7wbBrFKY">boxplot</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabmw6qBJtFb2pUApxstqqBfP"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabmw6qBJtFb2pUApxstqqBfP">db</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabKRJ8hCExHHSMJupG9Z87M5"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabKRJ8hCExHHSMJupG9Z87M5">geoplot</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="taboBjr4v4bitgfgxcWwCThXV"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="taboBjr4v4bitgfgxcWwCThXV">hit</label><input class="ipyplot-tab-M8xk3dbWKeihKcjTYknGpx" type="radio" name="tabs-M8xk3dbWKeihKcjTYknGpx" id="tabdgUN7VHxTmXMXK2Cvc5idm"/><label class="ipyplot-tab-label-M8xk3dbWKeihKcjTYknGpx" for="tabdgUN7VHxTmXMXK2Cvc5idm">somplot</label><div class="tab contentJuKQsiERykhHeX7wbBrFKY">
#         <style>
#         #ipyplot-imgs-container-div-WdkinWwVk5KdCyLTfnsqGm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WdkinWwVk5KdCyLTfnsqGm">
#     <div class="ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm">
#         <div id="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-c86Swqgpjhci7Exq7QLHET" class="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_1.png</h4><img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-c86Swqgpjhci7Exq7QLHET">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm">
#         <div id="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-NEc7Zrt49Etd76KP9kEcaq" class="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_2.png</h4><img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-NEc7Zrt49Etd76KP9kEcaq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm">
#         <div id="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-KF7Qe3jy95jbHgwprBCMzv" class="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_3.png</h4><img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-KF7Qe3jy95jbHgwprBCMzv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WdkinWwVk5KdCyLTfnsqGm">
#         <div id="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-GY8dmAfcJW2Vu2USKsJWzh" class="ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_4.png</h4><img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WdkinWwVk5KdCyLTfnsqGm-GY8dmAfcJW2Vu2USKsJWzh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div>
#     <style>
#         #ipyplot-html-viewer-toggle-SP56ZfAFZ4DZfscPtgUGgF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-SP56ZfAFZ4DZfscPtgUGgF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-SP56ZfAFZ4DZfscPtgUGgF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-SP56ZfAFZ4DZfscPtgUGgF:checked ~ #ipyplot-html-viewer-textarea-SP56ZfAFZ4DZfscPtgUGgF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-SP56ZfAFZ4DZfscPtgUGgF:checked + #ipyplot-html-viewer-label-SP56ZfAFZ4DZfscPtgUGgF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-SP56ZfAFZ4DZfscPtgUGgF">
#         <label id="ipyplot-html-viewer-label-SP56ZfAFZ4DZfscPtgUGgF" for="ipyplot-html-viewer-toggle-SP56ZfAFZ4DZfscPtgUGgF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-SP56ZfAFZ4DZfscPtgUGgF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-8uEBr5cJDJTPDC6H5wW3H2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2 {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8uEBr5cJDJTPDC6H5wW3H2">
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-JAMmaMuwvhjjUcPaJLfSQW" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-JAMmaMuwvhjjUcPaJLfSQW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-3LyyozKPPGGXkhbBqDw2yf" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-3LyyozKPPGGXkhbBqDw2yf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-Q7TbSVjdcqX8nCX9nonAo5" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-Q7TbSVjdcqX8nCX9nonAo5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-LuVqF7rguErX3e3iv22mjd" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-LuVqF7rguErX3e3iv22mjd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-2C6LapLTva8cLKWvxenvQP" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-2C6LapLTva8cLKWvxenvQP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-ceccMKVqWaTimyVJmMmjiv" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-ceccMKVqWaTimyVJmMmjiv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-NgfaJS755PoqbTYGKQcFjR" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\geoplot_1.png"/>
#         <style>
#         #ipyplot-imgs-container-div-8uEBr5cJDJTPDC6H5wW3H2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2 {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8uEBr5cJDJTPDC6H5wW3H2">
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-JAMmaMuwvhjjUcPaJLfSQW" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-JAMmaMuwvhjjUcPaJLfSQW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-3LyyozKPPGGXkhbBqDw2yf" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-3LyyozKPPGGXkhbBqDw2yf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-Q7TbSVjdcqX8nCX9nonAo5" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-Q7TbSVjdcqX8nCX9nonAo5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-LuVqF7rguErX3e3iv22mjd" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-LuVqF7rguErX3e3iv22mjd">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-2C6LapLTva8cLKWvxenvQP" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-2C6LapLTva8cLKWvxenvQP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-ceccMKVqWaTimyVJmMmjiv" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-ceccMKVqWaTimyVJmMmjiv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-NgfaJS755PoqbTYGKQcFjR" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\geoplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-NgfaJS755PoqbTYGKQcFjR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-EHA3ije9pmLAY66t8eFQKx" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_2.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\geoplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-EHA3ije9pmLAY66t8eFQKx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8uEBr5cJDJTPDC6H5wW3H2">
#         <div id="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-d5LwdZsuaaNEXYXPq9hJqT" class="ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_3.png</h4>
#             <img src="models\SOM_F4_X30_Y30_CMAX50_20240314-151713\exports\plots\geoplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8uEBr5cJDJTPDC6H5wW3H2-d5LwdZsuaaNEXYXPq9hJqT">
#                 <span class="ipyplot-img-expand"/>
#             </
