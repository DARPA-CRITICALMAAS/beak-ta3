# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import tungsten_skarn_alaska_ytu
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "FEATURE_FOX"
model = tungsten_skarn_alaska_ytu.models[MODEL]

BASE_PATH = files("beak.data")

# Choose data path
PATH_STD_DATA = BASE_PATH / "PROCESSED" / "regional_32606_100_alaska_ytu_tungsten_skarn" / "unified_scaled_std"
PATH_LOG_DATA = BASE_PATH / "PROCESSED" / "regional_32606_100_alaska_ytu_tungsten_skarn" / "unified_scaled_log"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "TUNGSTEN_SKARN_YTU" / "EPSG_32606_RES_100_ALASKA_YTU_MSR3.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_STD_DATA, PATH_LOG_DATA],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 21 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 2 folders, 10 subfolders and 37 files.
#
# Searching for corresponding files...
# Found 'LAB' in 1 file(s).
# Found 'LAB_HGM' in 1 file(s).
# Found 'LAB_Worms_Proximity' in 1 file(s).
# Found 'Moho' in 1 file(s).
# Found 'SatelliteGravity_ShapeIndex' in 1 file(s).
# Found 'Gravity_Up30km_HGM' in 1 file(s).
# Found 'DeepGravitySources_Worms_Proximity' in 1 file(s).
# Found 'Gravity' in 1 file(s).
# Found 'Gravity_HGM' in 1 file(s).
# Found 'Mag_RTP_YTU' in 1 file(s).
# Found 'Mag_RTP_HGM_YTU' in 1 file(s).
# Found 'Mag_RTP_HGM_DeepSources' in 1 file(s).
# Found 'DeepMagSources_Worms_Proximity' in 1 file(s).
# Found 'NAMrad_K' in 1 file(s).
# Found 'NAMrad_Th' in 1 file(s).
# Found 'NAMrad_U' in 1 file(s).
# Found 'Stream_HUC_AGG_W_Q50_Log' in 1 file(s).
# Found 'Stream_HUC_AGG_Sn_Q50_Log' in 1 file(s).
# Found 'Stream_HUC_AGG_Mo_Q50_Log' in 1 file(s).
# Found 'Geol_AGDB_Dist_Carbonate' in 1 file(s).
# Found 'Geol_AGDB_Dist_Plutonic' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 21

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 50                    # X dimension of generated SOM
args.som_y = 50                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 20               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
MODEL_NAME = "SOM_" + MODEL + "_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME

print(MODEL_FOLDER)
# Out:
# s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\local\experiments\tungsten_skarn_ytu\som\models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
check_path(MODEL_FOLDER)

# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.
#args.label_geotiff_file = args.output_folder + "/" + "input_file_list.txt"           # GeoTiff_input file (None)

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 21
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\seismic\LAB.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\seismic\LAB_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\seismic\LAB_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\seismic\Moho.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\gravity\SatelliteGravity_ShapeIndex.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\gravity\Gravity_Up30km_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\gravity\DeepGravitySources_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\gravity\Gravity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\gravity\Gravity_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\magnetic\Mag_RTP_YTU.tif
# ...
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\geology\distance\Geol_AGDB_Dist_Plutonic.tif
# Number of files added: 1
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\TRAINING_LABELS\TUNGSTEN_SKARN_YTU\EPSG_32606_RES_100_ALASKA_YTU_MSR3.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
# Warning: Projection of s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_log\stream_sediments\Stream_HUC_AGG_W_Q50_Log.tif does not match with s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\seismic\LAB.tif
# Warning: Projection of s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_log\stream_sediments\Stream_HUC_AGG_Sn_Q50_Log.tif does not match with s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\seismic\LAB.tif
# Warning: Projection of s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_log\stream_sediments\Stream_HUC_AGG_Mo_Q50_Log.tif does not match with s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_32606_100_alaska_ytu_tungsten_skarn\unified_scaled_std\seismic\LAB.tif
#     Execution time: 8.584598541259766 seconds
# Run SOM
#     Execution time: 226.11393427848816 seconds
# Clustering progress:
# 0.00%
# 9.68%
# 19.35%
# 29.03%
# 38.71%
# 48.39%
# 58.06%
# 67.74%
# 77.42%
# 87.10%
# 96.77%
# 100% Clustering completed.
#     Execution time: 21.250012159347534 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 314.2452721595764 seconds
# Save SOM space results
#     Execution time: 3.815336227416992 seconds
# Save SOM object to file
#     Execution time: 0.030367136001586914 seconds
# Do label analysis and write to file
#     Execution time: 25.143874406814575 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_LAB
#           b_LAB_HGM
#           b_LAB_Worms_Proximity
#           b_Moho
#           b_SatelliteGravity_ShapeIndex
#           b_Gravity_Up30km_HGM
#           b_DeepGravitySources_Worms_Proximity
#           b_Gravity
#           b_Gravity_HGM
#           b_Mag_RTP_YTU
#           b_Mag_RTP_HGM_YTU
#           b_Mag_RTP_HGM_DeepSources
#           b_DeepMagSources_Worms_Proximity
#           b_NAMrad_K
#           b_NAMrad_Th
#           b_NAMrad_U
#           b_Stream_HUC_AGG_W_Q50_Log
#           b_Stream_HUC_AGG_Sn_Q50_Log
#           b_Stream_HUC_AGG_Mo_Q50_Log
#           b_Geol_AGDB_Dist_Carbonate
#           b_Geol_AGDB_Dist_Plutonic
#           q_error
#           BMU_BMU_label_count
#           BMU_cluster_label_count
#     Execution time: 227.09984278678894 seconds
# Count cluster hit count
#     Execution time: 115.63326048851013 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.05514049530029297 seconds
#         Read geo data execution time: 72.18482613563538 seconds
#         Read label annotation data
#     Execution time: 95.22657823562622 seconds
# Plot geo space results
#     geospace plot no. 2 from 23
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\methods\som\plot_som_results.py:283: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 23 from 23
#     q-error plot
#     Execution time: 432.37986421585083 seconds
# Plot Cluster result SOM space
#     Draw som cluster plot
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Plot cluster label count
#     Execution time: 2.007889986038208 seconds
# Plot SOM space results
#     somspace plot no. 21 from 21
#     Execution time: 12.846769094467163 seconds
# Plot Boxplots
#     boxplot no. 21 from 21
#     Execution time: 19.53405475616455 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hCaLFanw7RiJpsdo2HViZD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hCaLFanw7RiJpsdo2HViZD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hCaLFanw7RiJpsdo2HViZD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hCaLFanw7RiJpsdo2HViZD:checked ~ #ipyplot-html-viewer-textarea-hCaLFanw7RiJpsdo2HViZD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hCaLFanw7RiJpsdo2HViZD:checked + #ipyplot-html-viewer-label-hCaLFanw7RiJpsdo2HViZD:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-hCaLFanw7RiJpsdo2HViZD">
#         <label id="ipyplot-html-viewer-label-hCaLFanw7RiJpsdo2HViZD" for="ipyplot-html-viewer-toggle-hCaLFanw7RiJpsdo2HViZD">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-hCaLFanw7RiJpsdo2HViZD" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x {
#                 display: none;
#             }
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x + label.ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x:checked + label.ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x ~ .tab {
#                 display: none
#             }
#     #tabEr4TNHPrURXTFJbWSDTRUb:checked ~ .tab.contentEr4TNHPrURXTFJbWSDTRUb,#tab39T9GxQuX3gVU9U8XjZUJT:checked ~ .tab.content39T9GxQuX3gVU9U8XjZUJT,#tabbKndBkjN8gTXVtwLfRpbwx:checked ~ .tab.contentbKndBkjN8gTXVtwLfRpbwx,#tabTYucGteHa5HvmFXanymbSi:checked ~ .tab.contentTYucGteHa5HvmFXanymbSi,#tabmu3zpDuwUNzqTjEBH7bro2:checked ~ .tab.contentmu3zpDuwUNzqTjEBH7bro2,#tabfdXDLdwQW2YboPsrcbvC67:checked ~ .tab.contentfdXDLdwQW2YboPsrcbvC67{ display: block; }</style><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabEr4TNHPrURXTFJbWSDTRUb" checked /><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabEr4TNHPrURXTFJbWSDTRUb">boxplot</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tab39T9GxQuX3gVU9U8XjZUJT"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tab39T9GxQuX3gVU9U8XjZUJT">db</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabbKndBkjN8gTXVtwLfRpbwx"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabbKndBkjN8gTXVtwLfRpbwx">geoplot</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabTYucGteHa5HvmFXanymbSi"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabTYucGteHa5HvmFXanymbSi">hit</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabmu3zpDuwUNzqTjEBH7bro2"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabmu3zpDuwUNzqTjEBH7bro2">label</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabfdXDLdwQW2YboPsrcbvC67"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabfdXDLdwQW2YboPsrcbvC67">somplot</label><div class="tab contentEr4TNHPrURXTFJbWSDTRUb">
#         <style>
#         #ipyplot-imgs-container-div-gRmWPPuyvvQB8mKE792Jcm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gRmWPPuyvvQB8mKE792Jcm">
#     <div class="ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm">
#         <div id="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-4gQTBH4eVfvWudpUnvfYXx" class="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_1.png</h4><img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-4gQTBH4eVfvWudpUnvfYXx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm">
#         <div id="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-CSKgdqvVv6DRd6eBR97WEs" class="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_10.png</h4><img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-cl
# <div>
#         <style>
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x {
#                 display: none;
#             }
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x + label.ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x:checked + label.ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x ~ .tab {
#                 display: none
#             }
#     #tabEr4TNHPrURXTFJbWSDTRUb:checked ~ .tab.contentEr4TNHPrURXTFJbWSDTRUb,#tab39T9GxQuX3gVU9U8XjZUJT:checked ~ .tab.content39T9GxQuX3gVU9U8XjZUJT,#tabbKndBkjN8gTXVtwLfRpbwx:checked ~ .tab.contentbKndBkjN8gTXVtwLfRpbwx,#tabTYucGteHa5HvmFXanymbSi:checked ~ .tab.contentTYucGteHa5HvmFXanymbSi,#tabmu3zpDuwUNzqTjEBH7bro2:checked ~ .tab.contentmu3zpDuwUNzqTjEBH7bro2,#tabfdXDLdwQW2YboPsrcbvC67:checked ~ .tab.contentfdXDLdwQW2YboPsrcbvC67{ display: block; }</style><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabEr4TNHPrURXTFJbWSDTRUb" checked /><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabEr4TNHPrURXTFJbWSDTRUb">boxplot</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tab39T9GxQuX3gVU9U8XjZUJT"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tab39T9GxQuX3gVU9U8XjZUJT">db</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabbKndBkjN8gTXVtwLfRpbwx"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabbKndBkjN8gTXVtwLfRpbwx">geoplot</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabTYucGteHa5HvmFXanymbSi"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabTYucGteHa5HvmFXanymbSi">hit</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabmu3zpDuwUNzqTjEBH7bro2"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabmu3zpDuwUNzqTjEBH7bro2">label</label><input class="ipyplot-tab-UqwPrfzTnfG3ZSUhdNUd6x" type="radio" name="tabs-UqwPrfzTnfG3ZSUhdNUd6x" id="tabfdXDLdwQW2YboPsrcbvC67"/><label class="ipyplot-tab-label-UqwPrfzTnfG3ZSUhdNUd6x" for="tabfdXDLdwQW2YboPsrcbvC67">somplot</label><div class="tab contentEr4TNHPrURXTFJbWSDTRUb">
#         <style>
#         #ipyplot-imgs-container-div-gRmWPPuyvvQB8mKE792Jcm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gRmWPPuyvvQB8mKE792Jcm">
#     <div class="ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm">
#         <div id="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-4gQTBH4eVfvWudpUnvfYXx" class="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_1.png</h4><img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-4gQTBH4eVfvWudpUnvfYXx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm">
#         <div id="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-CSKgdqvVv6DRd6eBR97WEs" class="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_10.png</h4><img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-CSKgdqvVv6DRd6eBR97WEs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm">
#         <div id="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-46oWE2ckSqdhjXv58vHt5b" class="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_11.png</h4><img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-46oWE2ckSqdhjXv58vHt5b">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gRmWPPuyvvQB8mKE792Jcm">
#         <div id="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm-jobPJaQbWyYjxeeHmTRFfZ" class="ipyplot-content-div-gRmWPPuyvvQB8mKE792Jcm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots
#     <style>
#         #ipyplot-html-viewer-toggle-NGFwXgKjnTzvGwtufj5HbB {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NGFwXgKjnTzvGwtufj5HbB {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NGFwXgKjnTzvGwtufj5HbB {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NGFwXgKjnTzvGwtufj5HbB:checked ~ #ipyplot-html-viewer-textarea-NGFwXgKjnTzvGwtufj5HbB {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NGFwXgKjnTzvGwtufj5HbB:checked + #ipyplot-html-viewer-label-NGFwXgKjnTzvGwtufj5HbB:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-NGFwXgKjnTzvGwtufj5HbB">
#         <label id="ipyplot-html-viewer-label-NGFwXgKjnTzvGwtufj5HbB" for="ipyplot-html-viewer-toggle-NGFwXgKjnTzvGwtufj5HbB">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-NGFwXgKjnTzvGwtufj5HbB" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-EZxfgZTa89sNxBBmYnBERn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EZxfgZTa89sNxBBmYnBERn">
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-MBRZx374Hjyty49urZY8xu" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-MBRZx374Hjyty49urZY8xu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-E6499dvgWVZL9nJTwKLPCr" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-E6499dvgWVZL9nJTwKLPCr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-m5y3h5k72HFqZ9hLVTeCWW" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-m5y3h5k72HFqZ9hLVTeCWW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-8sgvoPATMzVQqhWctwYCyg" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-8sgvoPATMzVQqhWctwYCyg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-DtmX2mj9MQECrLXYWG7NaG" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-DtmX2mj9MQECrLXYWG7NaG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-9g3XCzWUf5nztbw7k7PyAx" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_14.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-9g3XCzWUf5nztbw7k7PyAx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-HtxUUiZvz4tXbVjgg6axVT" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_15.png</h4>
#             <img src="mo
#         <style>
#         #ipyplot-imgs-container-div-EZxfgZTa89sNxBBmYnBERn {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-EZxfgZTa89sNxBBmYnBERn">
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-MBRZx374Hjyty49urZY8xu" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-MBRZx374Hjyty49urZY8xu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-E6499dvgWVZL9nJTwKLPCr" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-E6499dvgWVZL9nJTwKLPCr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-m5y3h5k72HFqZ9hLVTeCWW" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-m5y3h5k72HFqZ9hLVTeCWW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-8sgvoPATMzVQqhWctwYCyg" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-8sgvoPATMzVQqhWctwYCyg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-DtmX2mj9MQECrLXYWG7NaG" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-DtmX2mj9MQECrLXYWG7NaG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-9g3XCzWUf5nztbw7k7PyAx" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_14.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-9g3XCzWUf5nztbw7k7PyAx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-HtxUUiZvz4tXbVjgg6axVT" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_15.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_15.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-HtxUUiZvz4tXbVjgg6axVT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-QCLu27FyGmUAwVcA8xAzWb" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_16.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_16.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-QCLu27FyGmUAwVcA8xAzWb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-EZxfgZTa89sNxBBmYnBERn">
#         <div id="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn-XwzJcR5dxgxpVnUjruLGGE" class="ipyplot-content-div-EZxfgZTa89sNxBBmYnBERn">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_17.png</h4>
#             <img src="models\SOM_FEATURE_FOX_F21_X50_Y50_CMAX50_20240503-175501\exports\plots\boxplot_17.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-conten
