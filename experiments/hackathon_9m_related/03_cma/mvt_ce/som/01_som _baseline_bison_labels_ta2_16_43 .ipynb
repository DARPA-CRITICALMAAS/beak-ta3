# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import mvt_reg
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "BASELINE_BISON"
model = mvt_reg.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "102008_500"
BASE_EXTENT = "US_CONT"

# Choose data path
PATH_STD_DATA = BASE_PATH / "PROCESSED" / f"regional_{BASE_SPATIAL}_mvt_ce" / "unified_scaled_std"
PATH_LOG_DATA = BASE_PATH / "PROCESSED" / f"regional_{BASE_SPATIAL}_mvt_ce" / "unified_scaled_log"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "MVT_REG_CEUS" / "EPSG_102008_RES_500_MVT_CE_LAWLEY22_HEX.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_STD_DATA, PATH_LOG_DATA],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 15 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 2 folders, 11 subfolders and 70 files.
#
# Searching for corresponding files...
# Found 'CEUS_MAG_TMAG_AAS_CEUSSSC_R0_Log' in 1 file(s).
# Found 'CEUS_MAG_DRTP_TDR_CEUSSSC_R0' in 1 file(s).
# Found 'CEUS_MAG_DRTP_HD_TDR_CEUSSSC_R0' in 1 file(s).
# Found 'CEUS_MAG_DRTP_CEUSSSC_R0' in 1 file(s).
# Found 'Mag_RTP_HGM_DeepSources' in 1 file(s).
# Found 'DeepMagSources_Worms_Proximity' in 1 file(s).
# Found 'CEUS_GRAV_RI_HD_1VD_CEUSSSC_R0' in 1 file(s).
# Found 'CEUS_GRAV_RI_HD_CEUSSSC_R0' in 1 file(s).
# Found 'CEUS_GRAV_Isostatic_CEUSSSC_R0' in 1 file(s).
# Found 'CEUS_GRAV_RI_CEUSSSC_R0' in 1 file(s).
# Found 'CEUS_GRAV_RI_1VD_CEUSSSC_R0' in 1 file(s).
# Found 'LAB' in 1 file(s).
# Found 'LAB_HGM' in 1 file(s).
# Found 'LAB_Worms_Proximity' in 1 file(s).
# Found 'Moho' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 15

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 40                    # X dimension of generated SOM
args.som_y = 40                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 20               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
MODEL_NAME = "SOM_" + MODEL + "_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL / MODEL_NAME

print(MODEL_FOLDER)
# Out:
# d:\Programmieren\00_Repositories\CMAAS\beak-ta3\experiments\hackathon_9m_related\03_cma\mvt_ce\som\models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
check_path(MODEL_FOLDER)

# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.
#args.label_geotiff_file = args.output_folder + "/" + "input_file_list.txt"           # GeoTiff_input file (None)

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 15
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_log\geophysics\magnetic\CEUS_MAG_TMAG_AAS_CEUSSSC_R0_Log.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\magnetic\CEUS_MAG_DRTP_TDR_CEUSSSC_R0.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\magnetic\CEUS_MAG_DRTP_HD_TDR_CEUSSSC_R0.TIF
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\magnetic\CEUS_MAG_DRTP_CEUSSSC_R0.TIF
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\magnetic\Mag_RTP_HGM_DeepSources.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\magnetic\DeepMagSources_Worms_Proximity.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\gravity\CEUS_GRAV_RI_HD_1VD_CEUSSSC_R0.TIF
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\gravity\CEUS_GRAV_RI_HD_CEUSSSC_R0.TIF
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\gravity\CEUS_GRAV_Isostatic_CEUSSSC_R0.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\gravity\CEUS_GRAV_RI_CEUSSSC_R0.tif
# ...
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_mvt_ce\unified_scaled_std\geophysics\seismic\Moho.tif
# Number of files added: 1
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\TRAINING_LABELS\MVT_REG_CEUS\EPSG_102008_RES_500_MVT_CE_LAWLEY22_HEX.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
#     Execution time: 2.6395089626312256 seconds
# Run SOM
#     Execution time: 247.66077995300293 seconds
# Clustering progress:
#   File "c:\Users\storch\AppData\Local\miniconda3\envs\beak-ta3\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# 0.00%
# 9.68%
# 19.35%
# 29.03%
# 38.71%
# 48.39%
# 58.06%
# 67.74%
# 77.42%
# 87.10%
# 96.77%
# 100% Clustering completed.
#     Execution time: 15.206770420074463 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 128.8962562084198 seconds
# Save SOM space results
#     Execution time: 3.5426862239837646 seconds
# Save SOM object to file
#     Execution time: 0.3743300437927246 seconds
# Do label analysis and write to file
#     Execution time: 138.97393226623535 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_CEUS_MAG_TMAG_AAS_CEUSSSC_R0_Log
#           b_CEUS_MAG_DRTP_TDR_CEUSSSC_R0
#           b_CEUS_MAG_DRTP_HD_TDR_CEUSSSC_R0
#           b_CEUS_MAG_DRTP_CEUSSSC_R0
#           b_Mag_RTP_HGM_DeepSources
#           b_DeepMagSources_Worms_Proximity
#           b_CEUS_GRAV_RI_HD_1VD_CEUSSSC_R0
#           b_CEUS_GRAV_RI_HD_CEUSSSC_R0
#           b_CEUS_GRAV_Isostatic_CEUSSSC_R0
#           b_CEUS_GRAV_RI_CEUSSSC_R0
#           b_CEUS_GRAV_RI_1VD_CEUSSSC_R0
#           b_LAB
#           b_LAB_HGM
#           b_LAB_Worms_Proximity
#           b_Moho
#           q_error
#           BMU_ID
#           BMU_BMU_label_count
#           BMU_cluster_label_count
#     Execution time: 86.73781561851501 seconds
# Count cluster hit count
#     Execution time: 122.50520181655884 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.027004003524780273 seconds
#         Read geo data execution time: 32.43868398666382 seconds
#         Read label annotation data
#     Execution time: 148.79923486709595 seconds
# Plot geo space results
#     geospace plot no. 2 from 17
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\methods\som\plot_som_results.py:291: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 17 from 17
#     q-error plot
#     Execution time: 118.66439890861511 seconds
# Plot Cluster result SOM space
#     Draw som cluster plot
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Plot cluster label count
#     Execution time: 1.7580804824829102 seconds
# Plot SOM space results
#     somspace plot no. 15 from 15
#     Execution time: 11.897457361221313 seconds
# Plot Boxplots
#     boxplot no. 15 from 15
#     Execution time: 13.191108703613281 seconds
# Move figures geoplot_*.png to d:\Programmieren\00_Repositories\CMAAS\beak-ta3\experiments\hackathon_9m_related\03_cma\mvt_ce\som\models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658/exports/plots/
# Move figures somplot_*.png to d:\Programmieren\00_Repositories\CMAAS\beak-ta3\experiments\hackathon_9m_related\03_cma\mvt_ce\som\models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658/exports/plots/
# Move figures boxplot_*.png to d:\Programmieren\00_Repositories\CMAAS\beak-ta3\experiments\hackathon_9m_related\03_cma\mvt_ce\som\models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658/exports/plots/
# Move figures db_score.png to d:\Programmieren\00_Repositories\CMAAS\beak-ta3\experiments\hackathon_9m_related\03_cma\mvt_ce\som\models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658/exports/plots/
# Move figures cluster*_count.png to d:\Programmieren\00_Repositories\CMAAS\beak-ta3\experiments\hackathon_9m_related\03_cma\mvt_ce\som\models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658/exports/plots/
# Move figures bmu_id_mesh.png to d:\Programmieren\00_Repositories\CMAAS\beak-ta3\experiments\hackathon_9m_related\03_cma\mvt_ce\som\models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658/exports/plots/

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-BhjrqCptiF7zCB9eFsUkTF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-BhjrqCptiF7zCB9eFsUkTF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-BhjrqCptiF7zCB9eFsUkTF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-BhjrqCptiF7zCB9eFsUkTF:checked ~ #ipyplot-html-viewer-textarea-BhjrqCptiF7zCB9eFsUkTF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-BhjrqCptiF7zCB9eFsUkTF:checked + #ipyplot-html-viewer-label-BhjrqCptiF7zCB9eFsUkTF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-BhjrqCptiF7zCB9eFsUkTF">
#         <label id="ipyplot-html-viewer-label-BhjrqCptiF7zCB9eFsUkTF" for="ipyplot-html-viewer-toggle-BhjrqCptiF7zCB9eFsUkTF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-BhjrqCptiF7zCB9eFsUkTF" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes {
#                 display: none;
#             }
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes + label.ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes:checked + label.ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes ~ .tab {
#                 display: none
#             }
#     #tabnmmfeicfuwXDPHpfwaZM8s:checked ~ .tab.contentnmmfeicfuwXDPHpfwaZM8s,#tabdCZPJXvUKcdQfHqAaKtzwu:checked ~ .tab.contentdCZPJXvUKcdQfHqAaKtzwu,#tabZ4s2o6hXJLgJ9YMsorXFNg:checked ~ .tab.contentZ4s2o6hXJLgJ9YMsorXFNg,#tab7Qt6Rqm8s8RZzrfEAFsQtN:checked ~ .tab.content7Qt6Rqm8s8RZzrfEAFsQtN,#tab7tsMfc67aVPAc6VZkys9LP:checked ~ .tab.content7tsMfc67aVPAc6VZkys9LP,#tabUPzK5LDsSpqF32krCwa9KK:checked ~ .tab.contentUPzK5LDsSpqF32krCwa9KK,#tabPB94NAnmVe7THk2bYZsxiQ:checked ~ .tab.contentPB94NAnmVe7THk2bYZsxiQ{ display: block; }</style><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabnmmfeicfuwXDPHpfwaZM8s" checked /><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabnmmfeicfuwXDPHpfwaZM8s">boxplot</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabdCZPJXvUKcdQfHqAaKtzwu"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabdCZPJXvUKcdQfHqAaKtzwu">db</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabZ4s2o6hXJLgJ9YMsorXFNg"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabZ4s2o6hXJLgJ9YMsorXFNg">geoplot</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tab7Qt6Rqm8s8RZzrfEAFsQtN"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tab7Qt6Rqm8s8RZzrfEAFsQtN">hit</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tab7tsMfc67aVPAc6VZkys9LP"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tab7tsMfc67aVPAc6VZkys9LP">id</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabUPzK5LDsSpqF32krCwa9KK"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabUPzK5LDsSpqF32krCwa9KK">label</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabPB94NAnmVe7THk2bYZsxiQ"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabPB94NAnmVe7THk2bYZsxiQ">somplot</label><div class="tab contentnmmfeicfuwXDPHpfwaZM8s">
#         <style>
#         #ipyplot-imgs-container-div-FqxxWkXkL74xhgodmr2nkt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FqxxWkXkL74xhgodmr2nkt">
#     <div class="ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt">
#         <div id="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-AtNNF5pNHUqR5L9fw8qoNs" class="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_1.png</h4><img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-AtNNF5pNHUqR5L9fw8qoNs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt">
#         <div id="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-4Kz7Hd3gvJSGYqSVKKsHhF" class="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%;
# <div>
#         <style>
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes {
#                 display: none;
#             }
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes + label.ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes:checked + label.ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-dvyJJJJMkggYCzsZWQqQes ~ .tab {
#                 display: none
#             }
#     #tabnmmfeicfuwXDPHpfwaZM8s:checked ~ .tab.contentnmmfeicfuwXDPHpfwaZM8s,#tabdCZPJXvUKcdQfHqAaKtzwu:checked ~ .tab.contentdCZPJXvUKcdQfHqAaKtzwu,#tabZ4s2o6hXJLgJ9YMsorXFNg:checked ~ .tab.contentZ4s2o6hXJLgJ9YMsorXFNg,#tab7Qt6Rqm8s8RZzrfEAFsQtN:checked ~ .tab.content7Qt6Rqm8s8RZzrfEAFsQtN,#tab7tsMfc67aVPAc6VZkys9LP:checked ~ .tab.content7tsMfc67aVPAc6VZkys9LP,#tabUPzK5LDsSpqF32krCwa9KK:checked ~ .tab.contentUPzK5LDsSpqF32krCwa9KK,#tabPB94NAnmVe7THk2bYZsxiQ:checked ~ .tab.contentPB94NAnmVe7THk2bYZsxiQ{ display: block; }</style><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabnmmfeicfuwXDPHpfwaZM8s" checked /><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabnmmfeicfuwXDPHpfwaZM8s">boxplot</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabdCZPJXvUKcdQfHqAaKtzwu"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabdCZPJXvUKcdQfHqAaKtzwu">db</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabZ4s2o6hXJLgJ9YMsorXFNg"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabZ4s2o6hXJLgJ9YMsorXFNg">geoplot</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tab7Qt6Rqm8s8RZzrfEAFsQtN"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tab7Qt6Rqm8s8RZzrfEAFsQtN">hit</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tab7tsMfc67aVPAc6VZkys9LP"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tab7tsMfc67aVPAc6VZkys9LP">id</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabUPzK5LDsSpqF32krCwa9KK"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabUPzK5LDsSpqF32krCwa9KK">label</label><input class="ipyplot-tab-dvyJJJJMkggYCzsZWQqQes" type="radio" name="tabs-dvyJJJJMkggYCzsZWQqQes" id="tabPB94NAnmVe7THk2bYZsxiQ"/><label class="ipyplot-tab-label-dvyJJJJMkggYCzsZWQqQes" for="tabPB94NAnmVe7THk2bYZsxiQ">somplot</label><div class="tab contentnmmfeicfuwXDPHpfwaZM8s">
#         <style>
#         #ipyplot-imgs-container-div-FqxxWkXkL74xhgodmr2nkt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FqxxWkXkL74xhgodmr2nkt">
#     <div class="ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt">
#         <div id="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-AtNNF5pNHUqR5L9fw8qoNs" class="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_1.png</h4><img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-AtNNF5pNHUqR5L9fw8qoNs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt">
#         <div id="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-4Kz7Hd3gvJSGYqSVKKsHhF" class="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_10.png</h4><img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-4Kz7Hd3gvJSGYqSVKKsHhF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt">
#         <div id="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-MgbykhtH7XZmnk3DEMPTxj" class="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_11.png</h4><img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-MgbykhtH7XZmnk3DEMPTxj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FqxxWkXkL74xhgodmr2nkt">
#         <div id="ipyplot-content-div-FqxxWkXkL74xhgodmr2nkt-kLQMGgP7LgSNnEJ7Vp6TDC" class="ipyplo
#     <style>
#         #ipyplot-html-viewer-toggle-c8gccjstPLf598PbYdAnGp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-c8gccjstPLf598PbYdAnGp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-c8gccjstPLf598PbYdAnGp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-c8gccjstPLf598PbYdAnGp:checked ~ #ipyplot-html-viewer-textarea-c8gccjstPLf598PbYdAnGp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-c8gccjstPLf598PbYdAnGp:checked + #ipyplot-html-viewer-label-c8gccjstPLf598PbYdAnGp:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-c8gccjstPLf598PbYdAnGp">
#         <label id="ipyplot-html-viewer-label-c8gccjstPLf598PbYdAnGp" for="ipyplot-html-viewer-toggle-c8gccjstPLf598PbYdAnGp">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-c8gccjstPLf598PbYdAnGp" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-gyeh6bmczxyy6mzJBJYZuY {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gyeh6bmczxyy6mzJBJYZuY">
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-5HTw4p4GmTBMvEXnQtvrev" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bmu_id_mesh.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\bmu_id_mesh.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-5HTw4p4GmTBMvEXnQtvrev">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-a4eq5MjdpAhiS8vGLfVu4K" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-a4eq5MjdpAhiS8vGLfVu4K">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BYDsgq55h4qCLctBXUpRuq" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BYDsgq55h4qCLctBXUpRuq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-2ye3YdxKFZzvsoUvoWUV6E" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-2ye3YdxKFZzvsoUvoWUV6E">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BoNYeQHp87xg9B9N5FDDon" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BoNYeQHp87xg9B9N5FDDon">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-Mzetn5sTeWi2DzDpMKguga" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-Mzetn5sTeWi2DzDpMKguga">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-WPQtaiwKPXTeRucooA68tj" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#         <style>
#         #ipyplot-imgs-container-div-gyeh6bmczxyy6mzJBJYZuY {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gyeh6bmczxyy6mzJBJYZuY">
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-5HTw4p4GmTBMvEXnQtvrev" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bmu_id_mesh.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\bmu_id_mesh.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-5HTw4p4GmTBMvEXnQtvrev">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-a4eq5MjdpAhiS8vGLfVu4K" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-a4eq5MjdpAhiS8vGLfVu4K">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BYDsgq55h4qCLctBXUpRuq" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BYDsgq55h4qCLctBXUpRuq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-2ye3YdxKFZzvsoUvoWUV6E" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-2ye3YdxKFZzvsoUvoWUV6E">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BoNYeQHp87xg9B9N5FDDon" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-BoNYeQHp87xg9B9N5FDDon">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-Mzetn5sTeWi2DzDpMKguga" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-Mzetn5sTeWi2DzDpMKguga">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-WPQtaiwKPXTeRucooA68tj" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_14.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-WPQtaiwKPXTeRucooA68tj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-eYpLakjvTSEf44CnLnCsan" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_15.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_15.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-eYpLakjvTSEf44CnLnCsan">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gyeh6bmczxyy6mzJBJYZuY">
#         <div id="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY-aBCxtWDwmU6JUqB73rTXEF" class="ipyplot-content-div-gyeh6bmczxyy6mzJBJYZuY">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\SOM_BASELINE_BISON_F15_X40_Y40_CMAX50_20240514-230658\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
