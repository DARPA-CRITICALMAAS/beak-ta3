# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import porphyry_copper_nat
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "BASELINE_BISON"
model = porphyry_copper_nat.models[MODEL]

BASE_PATH = files("beak.data")

# Choose data path
PATH_STD_DATA = BASE_PATH / "PROCESSED" / "national_4326_0_025_us_cont" / "unified_scaled_std"
PATH_LOG_DATA = BASE_PATH / "PROCESSED" / "national_4326_0_025_us_cont" / "unified_scaled_log"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "PORPHYRY_COPPER_NAT" / "EPSG_4326_RES_0_025_US_CONT_PCUDEPPRO.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_STD_DATA, PATH_LOG_DATA],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 18 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 2 folders, 14 subfolders and 34 files.
#
# Searching for corresponding files...
# Found 'LAB' in 1 file(s).
# Found 'LAB_HGM' in 1 file(s).
# Found 'LAB_Worms_Proximity' in 1 file(s).
# Found 'Moho' in 1 file(s).
# Found 'SatelliteGravity_ShapeIndex' in 1 file(s).
# Found 'Gravity_Up30km_HGM' in 1 file(s).
# Found 'DeepGravitySources_Worms_Proximity' in 1 file(s).
# Found 'IsostaticGravity' in 1 file(s).
# Found 'Mag_RTP' in 1 file(s).
# Found 'Mag_LogAnalyticSignal' in 1 file(s).
# Found 'Mag_RTP_HGM_DeepSources' in 1 file(s).
# Found 'DeepMagSources_Worms_Proximity' in 1 file(s).
# Found 'CONUS_MT2023_9km' in 1 file(s).
# Found 'CONUS_MT2023_15km' in 1 file(s).
# Found 'CONUS_MT2023_30km' in 1 file(s).
# Found 'NAMrad_K' in 1 file(s).
# Found 'NAMrad_Th' in 1 file(s).
# Found 'NAMrad_U' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 18

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 50                    # X dimension of generated SOM
args.som_y = 50                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 20               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
MODEL_NAME = "SOM_" + MODEL + "_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME

print(MODEL_FOLDER)
# Out:
# s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\porphyry_copper_nat\som\models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
check_path(MODEL_FOLDER)

# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.
#args.label_geotiff_file = args.output_folder + "/" + "input_file_list.txt"           # GeoTiff_input file (None)

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 18
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\LAB.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\LAB_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\LAB_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\Moho.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\gravity\SatelliteGravity_ShapeIndex.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\gravity\Gravity_Up30km_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\gravity\DeepGravitySources_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\gravity\IsostaticGravity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\magnetic\Mag_RTP.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_log\geophysics\magnetic\Mag_LogAnalyticSignal.tif
# ...
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\radiometric\NAMrad_U.tif
# Number of files added: 1
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\TRAINING_LABELS\PORPHYRY_COPPER_NAT\EPSG_4326_RES_0_025_US_CONT_PCUDEPPRO.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
# Warning: Geotransform of s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\LAB_Worms_Proximity.tif does not match with s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\LAB.tif
# Warning: Geotransform of s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\gravity\DeepGravitySources_Worms_Proximity.tif does not match with s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\LAB.tif
# Warning: Geotransform of s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\magnetic\DeepMagSources_Worms_Proximity.tif does not match with s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_4326_0_025_us_cont\unified_scaled_std\geophysics\seismic\LAB.tif
#     Execution time: 1.23490309715271 seconds
# Run SOM
#     Execution time: 58.58315682411194 seconds
# Save SOM object to file
#     Execution time: 0.0 seconds
# Clustering progress:
# 0.00%
# 9.68%
# 19.35%
# 29.03%
# 38.71%
# 48.39%
# 58.06%
# 67.74%
# 77.42%
# 87.10%
# 96.77%
# 100% Clustering completed.
#     Execution time: 22.24938702583313 seconds
# Save SOM space results
#     Execution time: 1.1676886081695557 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 48.005579471588135 seconds
# Do label analysis and write to file
#     Execution time: 19.014230966567993 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_LAB
#           b_LAB_HGM
#           b_LAB_Worms_Proximity
#           b_Moho
#           b_SatelliteGravity_ShapeIndex
#           b_Gravity_Up30km_HGM
#           b_DeepGravitySources_Worms_Proximity
#           b_IsostaticGravity
#           b_Mag_RTP
#           b_Mag_LogAnalyticSignal
#           b_Mag_RTP_HGM_DeepSources
#           b_DeepMagSources_Worms_Proximity
#           b_CONUS_MT2023_9km
#           b_CONUS_MT2023_15km
#           b_CONUS_MT2023_30km
#           b_NAMrad_K
#           b_NAMrad_Th
#           b_NAMrad_U
#           q_error
#           BMU_ID
#           BMU_BMU_label_count
#           BMU_cluster_label_count
#     Execution time: 25.703871965408325 seconds
# Count cluster hit count
#     Execution time: 37.14800405502319 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.05882096290588379 seconds
#         Read geo data execution time: 9.519032716751099 seconds
#         Read label annotation data
#     Execution time: 26.430052518844604 seconds
# Plot geo space results
#     geospace plot no. 2 from 20
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\methods\som\plot_som_results.py:291: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 20 from 20
#     q-error plot
#     Execution time: 51.40507245063782 seconds
# Plot Cluster result SOM space
#     Draw som cluster plot
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Plot cluster label count
#     Execution time: 1.8694016933441162 seconds
# Plot SOM space results
#     somspace plot no. 18 from 18
#     Execution time: 13.394118547439575 seconds
# Move figures geoplot_*.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\porphyry_copper_nat\som\models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918/exports/plots/
# Move figures somplot_*.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\porphyry_copper_nat\som\models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918/exports/plots/
# Move figures boxplot_*.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\porphyry_copper_nat\som\models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918/exports/plots/
# Move figures db_score.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\porphyry_copper_nat\som\models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918/exports/plots/
# Move figures cluster*_count.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\porphyry_copper_nat\som\models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918/exports/plots/
# Move figures bmu_id_mesh.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\porphyry_copper_nat\som\models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918/exports/plots/

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-iRWZJa5cchbWjs7bvycX5K {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-iRWZJa5cchbWjs7bvycX5K {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-iRWZJa5cchbWjs7bvycX5K {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-iRWZJa5cchbWjs7bvycX5K:checked ~ #ipyplot-html-viewer-textarea-iRWZJa5cchbWjs7bvycX5K {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-iRWZJa5cchbWjs7bvycX5K:checked + #ipyplot-html-viewer-label-iRWZJa5cchbWjs7bvycX5K:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-iRWZJa5cchbWjs7bvycX5K">
#         <label id="ipyplot-html-viewer-label-iRWZJa5cchbWjs7bvycX5K" for="ipyplot-html-viewer-toggle-iRWZJa5cchbWjs7bvycX5K">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-iRWZJa5cchbWjs7bvycX5K" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ {
#                 display: none;
#             }
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ + label.ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ:checked + label.ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ ~ .tab {
#                 display: none
#             }
#     #tabApS6Hea5nVRBtWhw9aDbdd:checked ~ .tab.contentApS6Hea5nVRBtWhw9aDbdd,#tabdyoEzeMZTtSgjuU64qhFsx:checked ~ .tab.contentdyoEzeMZTtSgjuU64qhFsx,#tabXHBEJY6e2Hc5eQSE5M8nbz:checked ~ .tab.contentXHBEJY6e2Hc5eQSE5M8nbz,#tabEjtiMMMQvJaMBmbxWeUhvc:checked ~ .tab.contentEjtiMMMQvJaMBmbxWeUhvc,#tabjx2XegTggWePPYnekSPifV:checked ~ .tab.contentjx2XegTggWePPYnekSPifV,#tabizCwV9oBqJyVqHych7p3kM:checked ~ .tab.contentizCwV9oBqJyVqHych7p3kM{ display: block; }</style><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabApS6Hea5nVRBtWhw9aDbdd" checked /><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabApS6Hea5nVRBtWhw9aDbdd">db</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabdyoEzeMZTtSgjuU64qhFsx"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabdyoEzeMZTtSgjuU64qhFsx">geoplot</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabXHBEJY6e2Hc5eQSE5M8nbz"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabXHBEJY6e2Hc5eQSE5M8nbz">hit</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabEjtiMMMQvJaMBmbxWeUhvc"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabEjtiMMMQvJaMBmbxWeUhvc">id</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabjx2XegTggWePPYnekSPifV"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabjx2XegTggWePPYnekSPifV">label</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabizCwV9oBqJyVqHych7p3kM"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabizCwV9oBqJyVqHych7p3kM">somplot</label><div class="tab contentApS6Hea5nVRBtWhw9aDbdd">
#         <style>
#         #ipyplot-imgs-container-div-ko4aERFMsrQQUfRNNaj5un {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ko4aERFMsrQQUfRNNaj5un {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ko4aERFMsrQQUfRNNaj5un">
#     <div class="ipyplot-placeholder-div-ko4aERFMsrQQUfRNNaj5un">
#         <div id="ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un-Yxr6zbxtpeLkKvrV2fcrvV" class="ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918\exports\plots\db_score.png</h4><img src="models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un-Yxr6zbxtpeLkKvrV2fcrvV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentdyoEzeMZTtSgjuU64qhFsx">
#         <style>
#         #ipyplot-imgs-container-div-dbnBiZxvMAjb9wafhGaX8Z {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dbnBiZxvMAjb9wafhGaX8Z {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             verti
# <div>
#         <style>
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ {
#                 display: none;
#             }
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ + label.ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ:checked + label.ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ ~ .tab {
#                 display: none
#             }
#     #tabApS6Hea5nVRBtWhw9aDbdd:checked ~ .tab.contentApS6Hea5nVRBtWhw9aDbdd,#tabdyoEzeMZTtSgjuU64qhFsx:checked ~ .tab.contentdyoEzeMZTtSgjuU64qhFsx,#tabXHBEJY6e2Hc5eQSE5M8nbz:checked ~ .tab.contentXHBEJY6e2Hc5eQSE5M8nbz,#tabEjtiMMMQvJaMBmbxWeUhvc:checked ~ .tab.contentEjtiMMMQvJaMBmbxWeUhvc,#tabjx2XegTggWePPYnekSPifV:checked ~ .tab.contentjx2XegTggWePPYnekSPifV,#tabizCwV9oBqJyVqHych7p3kM:checked ~ .tab.contentizCwV9oBqJyVqHych7p3kM{ display: block; }</style><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabApS6Hea5nVRBtWhw9aDbdd" checked /><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabApS6Hea5nVRBtWhw9aDbdd">db</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabdyoEzeMZTtSgjuU64qhFsx"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabdyoEzeMZTtSgjuU64qhFsx">geoplot</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabXHBEJY6e2Hc5eQSE5M8nbz"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabXHBEJY6e2Hc5eQSE5M8nbz">hit</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabEjtiMMMQvJaMBmbxWeUhvc"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabEjtiMMMQvJaMBmbxWeUhvc">id</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabjx2XegTggWePPYnekSPifV"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabjx2XegTggWePPYnekSPifV">label</label><input class="ipyplot-tab-J7jh82tGRqaUvLntLyMjvJ" type="radio" name="tabs-J7jh82tGRqaUvLntLyMjvJ" id="tabizCwV9oBqJyVqHych7p3kM"/><label class="ipyplot-tab-label-J7jh82tGRqaUvLntLyMjvJ" for="tabizCwV9oBqJyVqHych7p3kM">somplot</label><div class="tab contentApS6Hea5nVRBtWhw9aDbdd">
#         <style>
#         #ipyplot-imgs-container-div-ko4aERFMsrQQUfRNNaj5un {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ko4aERFMsrQQUfRNNaj5un {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ko4aERFMsrQQUfRNNaj5un">
#     <div class="ipyplot-placeholder-div-ko4aERFMsrQQUfRNNaj5un">
#         <div id="ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un-Yxr6zbxtpeLkKvrV2fcrvV" class="ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918\exports\plots\db_score.png</h4><img src="models\SOM_BASELINE_BISON_F18_X50_Y50_CMAX50_20240610-123918\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ko4aERFMsrQQUfRNNaj5un-Yxr6zbxtpeLkKvrV2fcrvV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentdyoEzeMZTtSgjuU64qhFsx">
#         <style>
#         #ipyplot-imgs-container-div-dbnBiZxvMAjb9wafhGaX8Z {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-dbnBiZxvMAjb9wafhGaX8Z {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-dbnBiZxvMAjb9wafhGaX8Z]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div