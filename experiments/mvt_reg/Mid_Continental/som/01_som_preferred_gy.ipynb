# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import mvt_nat, mvt_reg
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "MVT_PREFERRED_GEOPHYSICS_ISOGRAV_SOM"
model = mvt_reg.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "EPSG_32615_RES_50_0"
BASE_EXTENT = "MID_CONTINENTAL"

# Choose data path
PATH_MCCAFFERTY =  BASE_PATH / "MCCAFFERTY23" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "GEOPHYSICS_SCALED_STD"
PATH_ISOGRAVITY = BASE_PATH / "GEOPHYSICS_ISOGRAVITY" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_MAGNETOTELLURIC = BASE_PATH / "GEOPHYSICS_MAGNETOTELLURICS" / "PROCESSED" / "CONUS_2023" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_LAWLEY_NUMERICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "NUMERICAL_IMPUTED_SCALED_STANDARD"
PATH_LAWLEY_CATEGORICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "CATEGORICAL"
PATH_HIGH_RES_AEROMAG = BASE_PATH / "GEOPHYSICS_AEROMAGNETICS" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "SCALED_STD"

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_MAGNETOTELLURIC, PATH_ISOGRAVITY,
             PATH_MCCAFFERTY, PATH_LAWLEY_NUMERICAL, PATH_HIGH_RES_AEROMAG,
             PATH_LAWLEY_CATEGORICAL],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)
# Out:
# Loading model definition...
# Selected 14 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 6 folders, 43 subfolders and 834 files.
#
# Searching for corresponding files...
# Found 'Gravity_Up30km' in 1 file(s).
# Found 'SatelliteGravity_ShapeIndex' in 1 file(s).
# Found 'Gravity_Bouguer_HGM_Worms_Proximity' in 1 file(s).
# Found 'Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity' in 1 file(s).
# Found 'US_IsostaticGravity_HGM_WGS84' in 1 file(s).
# Found 'US_IsostaticGravity_WGS84' in 1 file(s).
# Found 'MagRTP_HGMDeepSources' in 1 file(s).
# Found 'Mag_AnalyticSignal_cog' in 1 file(s).
# Found 'Magnetic_HGM_Worms_Proximity' in 1 file(s).
# Found 'Magnetic_LongWavelength_HGM_Worms_Proximity' in 1 file(s).
# Found 'SMidCont_RTP_UTM15' in 1 file(s).
# Found 'SMidCont_RTP_PGRV_HGM_UTM15' in 1 file(s).
# Found 'LAB' in 1 file(s).
# Found 'Moho' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 14

# %%
# Replace Mag Analytical Signal STD with LOG version
LOG_MOD = True

if LOG_MOD is True:
    for i, path in enumerate(file_list):
        if "Mag_AnalyticSignal_cog.tif" in str(path):
            print(f"{path} found at index {i}.")
            file_list[i] = str(file_list[i]).replace("GEOPHYSICS_SCALED_STD", "GEOPHYSICS_SCALED_LOG")
            file_list[i] = Path(file_list[i])
            break
# Out:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\GEOPHYSICS_SCALED_STD\Mag_AnalyticSignal_cog.tif found at index 7.

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 50                    # X dimension of generated SOM
args.som_y = 50                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = "true"               # Run k-means clustering (true, false)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 20               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = False                 # Whether data contains label column, True or False

# %%
# Set model name and folder
MODEL_NAME = "SOM_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME
check_path(MODEL_FOLDER)
# Out:
# WindowsPath('s:/Projekte/20230082_DARPA_CriticalMAAS_TA3/Bearbeitung/GitHub/beak-ta3/experiments/mvt_reg/Mid_Continental/som/models/SOM_F14_X50_Y50_CMAX50_20240308-121302')

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()
    

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.
args.label_geotiff_file = args.output_folder + "/" + "input_file_list.txt"           # GeoTiff_input file (None)

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
# Out:
# Number of files added: 14
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\GEOPHYSICS_SCALED_STD\Gravity_Up30km.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\GEOPHYSICS_SCALED_STD\SatelliteGravity_ShapeIndex.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_32615_RES_50_0\MID_CONTINENTAL\NUMERICAL_IMPUTED_SCALED_STANDARD\Gravity_Bouguer_HGM_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_32615_RES_50_0\MID_CONTINENTAL\NUMERICAL_IMPUTED_SCALED_STANDARD\Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\UNIFIED_SCALED_STD\US_IsostaticGravity_HGM_WGS84.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\GEOPHYSICS_ISOGRAVITY\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\GEOPHYSICS_SCALED_STD\MagRTP_HGMDeepSources.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\GEOPHYSICS_SCALED_LOG\Mag_AnalyticSignal_cog.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_32615_RES_50_0\MID_CONTINENTAL\NUMERICAL_IMPUTED_SCALED_STANDARD\Magnetic_HGM_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_32615_RES_50_0\MID_CONTINENTAL\NUMERICAL_IMPUTED_SCALED_STANDARD\Magnetic_LongWavelength_HGM_Worms_Proximity.tif
# ...
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\MCCAFFERTY23\PROCESSED\EPSG_32615_RES_50_0\MID_CONTINENTAL\GEOPHYSICS_SCALED_STD\Moho.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
#     Execution time: 34.302347898483276 seconds
# Run SOM
#     Execution time: 2104.0298132896423 seconds
# Clustering progress:
# 0.00%
# 9.68%
# 19.35%
# 29.03%
# 38.71%
# 48.39%
# 58.06%
# 67.74%
# 77.42%
# 87.10%
# 96.77%
# 100% Clustering completed.
#     Execution time: 21.800520420074463 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 2845.2993569374084 seconds
# Save SOM space results
#     Execution time: 49.97316312789917 seconds
# Save SOM object to file
#     Execution time: 0.4216325283050537 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_Gravity_Up30km
#           b_SatelliteGravity_ShapeIndex
#           b_Gravity_Bouguer_HGM_Worms_Proximity
#           b_Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity
#           b_US_IsostaticGravity_HGM_WGS84
#           b_US_IsostaticGravity_WGS84
#           b_MagRTP_HGMDeepSources
#           b_Mag_AnalyticSignal_cog
#           b_Magnetic_HGM_Worms_Proximity
#           b_Magnetic_LongWavelength_HGM_Worms_Proximity
#           b_SMidCont_RTP_UTM15
#           b_SMidCont_RTP_PGRV_HGM_UTM15
#           b_LAB
#           b_Moho
#     Execution time: 1004.973934173584 seconds
# Count cluster hit count
#         Cluster hit count: 42 - 1683315
#         Cluster hit count: 41 - 1072977
#         Cluster hit count: 40 - 689852
#         Cluster hit count: 39 - 1695886
#         Cluster hit count: 38 - 1628603
#         Cluster hit count: 37 - 152077
#         Cluster hit count: 36 - 13914
#         Cluster hit count: 35 - 112965
#         Cluster hit count: 34 - 1341237
#         Cluster hit count: 33 - 1104557
#         Cluster hit count: 32 - 1753992
#         Cluster hit count: 31 - 1052788
#         Cluster hit count: 30 - 3388550
#         Cluster hit count: 29 - 2256402
#         Cluster hit count: 28 - 1067950
#         Cluster hit count: 27 - 965986
#         Cluster hit count: 26 - 887343
#         Cluster hit count: 25 - 1436572
#         Cluster hit count: 24 - 1450283
#         Cluster hit count: 23 - 796150
#         Cluster hit count: 22 - 1677838
#         Cluster hit count: 21 - 1467754
#         Cluster hit count: 20 - 1239095
#         Cluster hit count: 19 - 914268
#         Cluster hit count: 18 - 2158196
#         Cluster hit count: 17 - 1311026
#         Cluster hit count: 16 - 2453698
#         Cluster hit count: 15 - 733019
#         Cluster hit count: 14 - 1864341
#         Cluster hit count: 13 - 1429945
#         Cluster hit count: 12 - 2431069
#         Cluster hit count: 11 - 2665919
#         Cluster hit count: 10 - 39634
#         Cluster hit count: 9 - 1341000
#         Cluster hit count: 8 - 1912390
#         Cluster hit count: 7 - 375822
#         Cluster hit count: 6 - 1188766
#         Cluster hit count: 5 - 1133758
#         Cluster hit count: 4 - 133986
#         Cluster hit count: 3 - 2177035
#         Cluster hit count: 2 - 907096
#         Cluster hit count: 1 - 2629552
#         Cluster hit count: 0 - 1150159
#     Execution time: 1474.4525046348572 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = 'true'                                   # true: draw all plots. false: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.05100250244140625 seconds
#         Read geo data execution time: 913.1482031345367 seconds
#     Execution time: 913.3192105293274 seconds
# Plot geo space results
#     geospace plot no. 2 from 16
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\methods\som\plot_som_results.py:314: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 16 from 16
#     q-error plot
#     Execution time: 1860.5335743427277 seconds
# Plot Cluster result SOM space
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Execution time: 1.9592971801757812 seconds
# Plot SOM space results
#     somspace plot no. 14 from 14
#     Execution time: 67.14484333992004 seconds
# Plot Boxplots
#     boxplot no. 14 from 14
#     Execution time: 12.885871171951294 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-QUZvYSBjuXz2AYbzUuDCPE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QUZvYSBjuXz2AYbzUuDCPE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QUZvYSBjuXz2AYbzUuDCPE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QUZvYSBjuXz2AYbzUuDCPE:checked ~ #ipyplot-html-viewer-textarea-QUZvYSBjuXz2AYbzUuDCPE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QUZvYSBjuXz2AYbzUuDCPE:checked + #ipyplot-html-viewer-label-QUZvYSBjuXz2AYbzUuDCPE:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QUZvYSBjuXz2AYbzUuDCPE">
#         <label id="ipyplot-html-viewer-label-QUZvYSBjuXz2AYbzUuDCPE" for="ipyplot-html-viewer-toggle-QUZvYSBjuXz2AYbzUuDCPE">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QUZvYSBjuXz2AYbzUuDCPE" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i {
#                 display: none;
#             }
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i + label.ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i:checked + label.ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i ~ .tab {
#                 display: none
#             }
#     #tabAiq32DoucuwBamjpshDnyw:checked ~ .tab.contentAiq32DoucuwBamjpshDnyw,#tabTkCPVVdPaLFTsEynEneNDn:checked ~ .tab.contentTkCPVVdPaLFTsEynEneNDn,#tabD4fAcq9dtRSYR96aojRggz:checked ~ .tab.contentD4fAcq9dtRSYR96aojRggz,#tabGim6QAEHAMU45tkfT7QUeB:checked ~ .tab.contentGim6QAEHAMU45tkfT7QUeB,#tab4n2YJrYJt6db6cb2ZHzEXt:checked ~ .tab.content4n2YJrYJt6db6cb2ZHzEXt{ display: block; }</style><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabAiq32DoucuwBamjpshDnyw" checked /><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabAiq32DoucuwBamjpshDnyw">boxplot</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabTkCPVVdPaLFTsEynEneNDn"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabTkCPVVdPaLFTsEynEneNDn">db</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabD4fAcq9dtRSYR96aojRggz"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabD4fAcq9dtRSYR96aojRggz">geoplot</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabGim6QAEHAMU45tkfT7QUeB"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabGim6QAEHAMU45tkfT7QUeB">hit</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tab4n2YJrYJt6db6cb2ZHzEXt"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tab4n2YJrYJt6db6cb2ZHzEXt">somplot</label><div class="tab contentAiq32DoucuwBamjpshDnyw">
#         <style>
#         #ipyplot-imgs-container-div-GbKkZfF2cH3jtD7LdYc4q5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-GbKkZfF2cH3jtD7LdYc4q5">
#     <div class="ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5">
#         <div id="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-3qYvWrPNNDbZu3GTqgARfB" class="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_1.png</h4><img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-3qYvWrPNNDbZu3GTqgARfB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5">
#         <div id="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-PSYAZoAtkqxAY5Wxf2bgSh" class="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_10.png</h4><img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-PSYAZoAtkqxAY5Wxf2bgSh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5">
#         <div id="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-hgMWGLcruGLsQ
# <div>
#         <style>
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i {
#                 display: none;
#             }
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i + label.ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i:checked + label.ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-DFWZwr3jTtbCr9iVoK663i ~ .tab {
#                 display: none
#             }
#     #tabAiq32DoucuwBamjpshDnyw:checked ~ .tab.contentAiq32DoucuwBamjpshDnyw,#tabTkCPVVdPaLFTsEynEneNDn:checked ~ .tab.contentTkCPVVdPaLFTsEynEneNDn,#tabD4fAcq9dtRSYR96aojRggz:checked ~ .tab.contentD4fAcq9dtRSYR96aojRggz,#tabGim6QAEHAMU45tkfT7QUeB:checked ~ .tab.contentGim6QAEHAMU45tkfT7QUeB,#tab4n2YJrYJt6db6cb2ZHzEXt:checked ~ .tab.content4n2YJrYJt6db6cb2ZHzEXt{ display: block; }</style><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabAiq32DoucuwBamjpshDnyw" checked /><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabAiq32DoucuwBamjpshDnyw">boxplot</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabTkCPVVdPaLFTsEynEneNDn"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabTkCPVVdPaLFTsEynEneNDn">db</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabD4fAcq9dtRSYR96aojRggz"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabD4fAcq9dtRSYR96aojRggz">geoplot</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tabGim6QAEHAMU45tkfT7QUeB"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tabGim6QAEHAMU45tkfT7QUeB">hit</label><input class="ipyplot-tab-DFWZwr3jTtbCr9iVoK663i" type="radio" name="tabs-DFWZwr3jTtbCr9iVoK663i" id="tab4n2YJrYJt6db6cb2ZHzEXt"/><label class="ipyplot-tab-label-DFWZwr3jTtbCr9iVoK663i" for="tab4n2YJrYJt6db6cb2ZHzEXt">somplot</label><div class="tab contentAiq32DoucuwBamjpshDnyw">
#         <style>
#         #ipyplot-imgs-container-div-GbKkZfF2cH3jtD7LdYc4q5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-GbKkZfF2cH3jtD7LdYc4q5">
#     <div class="ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5">
#         <div id="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-3qYvWrPNNDbZu3GTqgARfB" class="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_1.png</h4><img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-3qYvWrPNNDbZu3GTqgARfB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5">
#         <div id="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-PSYAZoAtkqxAY5Wxf2bgSh" class="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_10.png</h4><img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-PSYAZoAtkqxAY5Wxf2bgSh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5">
#         <div id="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-hgMWGLcruGLsQtkpVofcW6" class="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_11.png</h4><img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-hgMWGLcruGLsQtkpVofcW6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-GbKkZfF2cH3jtD7LdYc4q5">
#         <div id="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-CYosnmDdNB9jyczBR5QSRQ" class="ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_12.png</h4><img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-GbKkZfF2cH3jtD7LdYc4q5-CYosnmDdNB9jyczBR5QSRQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-nHKpk8jL5dMmyhhSwRVCuu {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-nHKpk8jL5dMmyhhSwRVCuu {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-nHKpk8jL5dMmyhhSwRVCuu {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-nHKpk8jL5dMmyhhSwRVCuu:checked ~ #ipyplot-html-viewer-textarea-nHKpk8jL5dMmyhhSwRVCuu {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-nHKpk8jL5dMmyhhSwRVCuu:checked + #ipyplot-html-viewer-label-nHKpk8jL5dMmyhhSwRVCuu:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-nHKpk8jL5dMmyhhSwRVCuu">
#         <label id="ipyplot-html-viewer-label-nHKpk8jL5dMmyhhSwRVCuu" for="ipyplot-html-viewer-toggle-nHKpk8jL5dMmyhhSwRVCuu">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-nHKpk8jL5dMmyhhSwRVCuu" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-jUYCxDJSF2VYiYEuhHSYzM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jUYCxDJSF2VYiYEuhHSYzM">
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-RKT9PN7bG7kWDyhtx2PDGr" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-RKT9PN7bG7kWDyhtx2PDGr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-LKs8fQ5raVWJBs6rr6vLod" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-LKs8fQ5raVWJBs6rr6vLod">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-9CQVG9nMnvy5SsuCkFxAzq" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-9CQVG9nMnvy5SsuCkFxAzq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-mGgFWB7xX4WP9oNhMVxV5G" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-mGgFWB7xX4WP9oNhMVxV5G">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-kCZpqe5kfAhJ3yjqH9pHWN" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-kCZpqe5kfAhJ3yjqH9pHWN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-DCibJCJFuzsYcCXmETizG3" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_14.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-DCibJCJFuzsYcCXmETizG3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-nnneP4TBsRsdpYjjV8TkkP" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_2.png"/
#         <style>
#         #ipyplot-imgs-container-div-jUYCxDJSF2VYiYEuhHSYzM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jUYCxDJSF2VYiYEuhHSYzM">
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-RKT9PN7bG7kWDyhtx2PDGr" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-RKT9PN7bG7kWDyhtx2PDGr">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-LKs8fQ5raVWJBs6rr6vLod" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-LKs8fQ5raVWJBs6rr6vLod">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-9CQVG9nMnvy5SsuCkFxAzq" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-9CQVG9nMnvy5SsuCkFxAzq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-mGgFWB7xX4WP9oNhMVxV5G" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-mGgFWB7xX4WP9oNhMVxV5G">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-kCZpqe5kfAhJ3yjqH9pHWN" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-kCZpqe5kfAhJ3yjqH9pHWN">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-DCibJCJFuzsYcCXmETizG3" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_14.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-DCibJCJFuzsYcCXmETizG3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-nnneP4TBsRsdpYjjV8TkkP" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-nnneP4TBsRsdpYjjV8TkkP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-LmzuabfTJwEQSG2VrcXx4H" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-LmzuabfTJwEQSG2VrcXx4H">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-jUYCxDJSF2VYiYEuhHSYzM">
#         <div id="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-URCtbfiyt827ANQ4KEspVh" class="ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="models\SOM_F14_X50_Y50_CMAX50_20240308-121302\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jUYCxDJSF2VYiYEuhHSYzM-URCtbfiyt827ANQ4KEspVh">
#                 <span class="ipyplot-img-expand"/>
