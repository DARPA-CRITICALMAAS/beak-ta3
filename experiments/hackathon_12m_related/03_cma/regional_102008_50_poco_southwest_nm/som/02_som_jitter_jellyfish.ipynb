# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import hack_12m_poco
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "JITTER_JELLYFISH"
model = hack_12m_poco.regional_scale_southwest[MODEL]

BASE_PATH = files("beak.data")

# Choose data path
ROOT_PATH = BASE_PATH / "PROCESSED" / "regional_102008_50_poco_southwest_nm"
PATH_BIN_DATA_GEOL = ROOT_PATH / "unified_scaled_bin" / "geology"
PATH_STD_DATA = ROOT_PATH / "unified_scaled_std"
PATH_LOG_DATA_GEOPHYSICS = ROOT_PATH / "unified_imputed_mean_scaled_log"
PATH_LOG_DATA_GEOCHEM = ROOT_PATH / "unified_scaled_log" / "geophysics"
PATH_LABELS = ROOT_PATH / "labels" / "TA2_240609_FILTERED_HM9_PCUDEPPRO.tif"

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_BIN_DATA_GEOL, PATH_STD_DATA,  PATH_LOG_DATA_GEOPHYSICS, PATH_LOG_DATA_GEOCHEM],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 32 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 4 folders, 15 subfolders and 66 files.
#
# Searching for corresponding files...
# Found 'LAB' in 1 file(s).
# Found 'LAB_HGM' in 1 file(s).
# Found 'LAB_Worms_Proximity' in 1 file(s).
# Found 'Moho' in 1 file(s).
# Found 'Gravity_Up30km' in 1 file(s).
# Found 'Gravity_Up30km_HGM' in 1 file(s).
# Found 'ShallowGravitySources_Worms_Proximity' in 1 file(s).
# Found 'DeepGravitySources_Worms_Proximity' in 1 file(s).
# Found 'IsostaticGravity' in 1 file(s).
# Found 'IsostaticGravity_HGM' in 1 file(s).
# Found 'IsostaticGravity_HGM_Worms' in 1 file(s).
# Found 'Mag_RTP' in 1 file(s).
# Found 'Mag_RTP_HGM' in 1 file(s).
# Found 'Mag_RTP_VD' in 1 file(s).
# Found 'Mag_RTP_DeepSources' in 1 file(s).
# Found 'Mag_RTP_HGM_DeepSources' in 1 file(s).
# Found 'DeepMagSources_Worms_Proximity' in 1 file(s).
# Found 'CONUS_MT2023_9km' in 1 file(s).
# Found 'CONUS_MT2023_15km' in 1 file(s).
# Found 'CONUS_MT2023_30km' in 1 file(s).
# Found 'NAMrad_K' in 1 file(s).
# Found 'NAMrad_Th' in 1 file(s).
# Found 'NAMrad_U' in 1 file(s).
# Found 'BGE_ALL' in 1 file(s).
# Found 'BGE_DEPOSIT' in 1 file(s).
# Found 'BGE_ROCK_TYPE' in 1 file(s).
# Found 'CEUS_pc_Whitmeyer2007_R0_Unit' in 21 file(s).
# Found 'All_Alteration_Proximity' in 1 file(s).
# Found 'cdr_sgmc_proximity_faults_shear_zones' in 1 file(s).
# Found 'Geochemistry_StrmSed_Cu_SBR' in 1 file(s).
# Found 'Geochemistry_StrmSed_Mo_SBR' in 1 file(s).
# Found 'Geochemistry_StrmSed_Zn_SBR' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 52

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 50                    # X dimension of generated SOM
args.som_y = 50                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 20               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborh
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
import os
current_dir = Path(os.path.dirname(__file__)).resolve()
os.chdir(current_dir)

MODEL_NAME = "F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_E" + str(args.epochs) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL / MODEL_NAME

print(MODEL_FOLDER)
# Out:
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_12m_related\03_cma\regional_102008_50_poco_southwest_nm\som\models\BASELINE_BISON\F20_X50_Y50_CMAX50_20240718-163521

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
check_path(MODEL_FOLDER)

# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.
#args.label_geotiff_file = args.output_folder + "/" + "input_file_list.txt"           # GeoTiff_input file (None)

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 20
# Files:
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\seismic\LAB.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\seismic\LAB_HGM.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\seismic\LAB_Worms_Proximity.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\seismic\Moho.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\gravity\Gravity_Up30km.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\gravity\Gravity_Up30km_HGM.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\gravity\ShallowGravitySources_Worms_Proximity.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\gravity\DeepGravitySources_Worms_Proximity.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\gravity\IsostaticGravity.tif
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\gravity\IsostaticGravity_HGM.tif
# ...
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\unified_scaled_std\geophysics\magnetotelluric\CONUS_2023\CONUS_MT2023_30km.tif
# Number of files added: 1
# Files:
# S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\regional_102008_50_poco_southwest_nm\labels\EPSG_102008_RES_50_poco_southwest_nm_TA2_240609_FILTERED_HM9_PCUDEPPRO.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
#     Execution time: 27.008288145065308 seconds
# Run SOM
#     Execution time: 503.14397954940796 seconds
# Save SOM object to file
#     Execution time: 0.07901310920715332 seconds
# Clustering progress:
# 0.00%
# 9.68%
# 19.35%
# 29.03%
# 38.71%
# 48.39%
# 58.06%
# 67.74%
# 77.42%
# 87.10%
# 96.77%
# 100% Clustering completed.
#     Execution time: 20.67345666885376 seconds
# Save SOM space results
#     Execution time: 8.886117219924927 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 505.27353024482727 seconds
# Do label analysis and write to file
#     Execution time: 28.698622703552246 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_LAB
#           b_LAB_HGM
#           b_LAB_Worms_Proximity
#           b_Moho
#           b_Gravity_Up30km
#           b_Gravity_Up30km_HGM
#           b_ShallowGravitySources_Worms_Proximity
#           b_DeepGravitySources_Worms_Proximity
#           b_IsostaticGravity
#           b_IsostaticGravity_HGM
#           b_IsostaticGravity_HGM_Worms
#           b_Mag_RTP
#           b_Mag_RTP_HGM
#           b_Mag_RTP_VD
#           b_Mag_RTP_DeepSources
#           b_Mag_RTP_HGM_DeepSources
#           b_DeepMagSources_Worms_Proximity
#           b_CONUS_MT2023_9km
#           b_CONUS_MT2023_15km
#           b_CONUS_MT2023_30km
#           q_error
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       8 with warnings.catch_warnings():
#       9     warnings.simplefilter("ignore")
# ---> 10     dnsr.run_SOM(args)
#
# File S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\methods\som\do_nextsomcore_save_results.py:108, in run_SOM(args)
#     106 inputFileArray=args.geotiff_input.split(",")
#     107 bmu_id = create_bmu_id(args.som_x, args.som_y, args.output_folder)
# --> 108 nxtsomcore.write_geotiff_out(args.output_folder, args.output_file_geospace, args.output_file_somspace, inputFileArray[0], args.label, index_nolabel, bmu_id)
#     109 end_time = time.time()
#     110 print(f"    Execution time: {end_time - start_time} seconds")
#
# File S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\methods\som\nextsomcore\nextsomcore.py:447, in NxtSomCore.write_geotiff_out(self, output_folder, geodatafile, somdatafile, input_file, label, index_nolabel, bmu_id)
#     445 df.columns = ['X_value','Y_value','Z_value']
#     446 df['Z_value'] = pd.to_numeric(df['Z_value'])
# --> 447 pivotted= df.pivot(index='Y_value',columns='X_value',values='Z_value')
#     449 driver = gdal.GetDriverByName('GTiff')
#     450 outName = destination_path + "q_error.tif"
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\frame.py:9028, in DataFrame.pivot(self, columns, index, values)
#    9021 @Substitution("")
#    9022 @Appender(_shared_docs["pivot"])
#    9023 def pivot(
#    9024     self, *, columns, index=lib.no_default, values=lib.no_default
#    9025 ) -> DataFrame:
#    9026     from pandas.core.reshape.pivot import pivot
# -> 9028     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\reshape\pivot.py:553, in pivot(data, columns, index, values)
#     549         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     550 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     551 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     552 # "Hashable"
# --> 553 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     554 result.index.names = [
#     555     name if name is not lib.no_default else None for name in result.index.names
#     556 ]
#     558 return result
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\series.py:4455, in Series.unstack(self, level, fill_value, sort)
#    4410 """
#    4411 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4412
#    (...)
#    4451 b    2    4
#    4452 """
#    4453 from pandas.core.reshape.reshape import unstack
# -> 4455 return unstack(self, level, fill_value, sort)
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\reshape\reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\reshape\reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\reshape\reshape.py:195, in _Unstacker._make_selectors(self)
#     192 new_levels = self.new_index_levels
#     194 # make the mask
# --> 195 remaining_labels = self.sorted_labels[:-1]
#     196 level_sizes = tuple(len(x) for x in new_levels)
#     198 comp_index, obs_ids = get_compressed_ids(remaining_labels, level_sizes)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\reshape\reshape.py:178, in _Unstacker.sorted_labels(self)
#     176 @cache_readonly
#     177 def sorted_labels(self) -> list[np.ndarray]:
# --> 178     indexer, to_sort = self._indexer_and_to_sort
#     179     if self.sort:
#     180         return [line.take(indexer) for line in to_sort]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\reshape\reshape.py:170, in _Unstacker._indexer_and_to_sort(self)
#     167 to_sort = codes[:v] + codes[v + 1 :] + [codes[v]]
#     168 sizes = tuple(len(x) for x in levs[:v] + levs[v + 1 :] + [levs[v]])
# --> 170 comp_index, obs_ids = get_compressed_ids(to_sort, sizes)
#     171 ngroups = len(obs_ids)
#     173 indexer = get_group_index_sorter(comp_index, ngroups)
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\sorting.py:235, in get_compressed_ids(labels, sizes)
#     217 """
#     218 Group_index is offsets into cartesian product of all possible labels. This
#     219 space can be huge, so this function compresses it, by computing offsets
#    (...)
#     232     obs_group_ids
#     233 """
#     234 ids = get_group_index(labels, sizes, sort=True, xnull=False)
# --> 235 return compress_group_index(ids, sort=True)
#
# File ~\.conda\envs\beak-ta3\lib\site-packages\pandas\core\sorting.py:769, in compress_group_index(group_index, sort)
#     766 group_index = ensure_int64(group_index)
#     768 # note, group labels come out ascending (ie, 1,2,3 etc)
# --> 769 comp_ids, obs_group_ids = table.get_labels_groupby(group_index)
#     771 if sort and len(obs_group_ids) > 0:
#     772     obs_group_ids, comp_ids = _reorder_by_uniques(obs_group_ids, comp_ids)
#
# KeyboardInterrupt:

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
