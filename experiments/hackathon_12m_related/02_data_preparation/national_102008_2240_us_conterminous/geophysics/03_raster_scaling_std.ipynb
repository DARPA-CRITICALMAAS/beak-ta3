# %% [markdown]
# # Information
# ## How to
# 1. Set the parameters. **UPPERCASE** letters are user input variables
# 2. Run the reprojection cell

# %% [markdown]
# # Requirements

# %%
import os
from importlib_resources import files
from pathlib import Path

from beak.utilities import transformation

# %% [markdown]
# # Scaling

# %% [markdown]
# **Scaling** all numerical folders within a specified model configuration.<br>
# Reads the <code>ROOT_FOLDER</code> and takes the <code>NUMERICAL</code> subfolder within each model configuration.

# %% [markdown]
# **User inputs**

# %%
BASE_PATH = files("beak.data")

EPSG_CODE = 102008
RESOLUTION = 2240
BASE_SPATIAL = str(EPSG_CODE) + "_" + str(RESOLUTION)
BASE_EXTENT = "us_cont"
BASE_RASTER = BASE_PATH / "BASE_RASTERS" / str("EPSG_" + str(EPSG_CODE) + "_RES_" + str(RESOLUTION) + "_" + BASE_EXTENT + ".tif")
BASE_EVIDENCE = "geophysics"

# Export to current location for testing purposes
PATH_ROOT = BASE_PATH / "PROCESSED" / str("national" + "_" + BASE_SPATIAL + "_" + BASE_EXTENT)
PATH_INPUT = PATH_ROOT / "unified" / BASE_EVIDENCE
PATH_EXPORT = PATH_ROOT / "unified_scaled_std" / BASE_EVIDENCE

CURRENT_DIR = Path(os.getcwd()) / PATH_EXPORT.name
OUT_FOLDER = PATH_EXPORT

print(f"Input folder: {PATH_INPUT}")
print(f"Export folder: {OUT_FOLDER}")

METHOD = "standard"
# Out:
# Input folder: s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics
# Export folder: s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified_scaled_std\geophysics

# %% [markdown]
# Select subfolders to be scaled.

# %%
# Get the list of folders
root_folder = PATH_INPUT
folders = os.listdir(root_folder)

for folder in folders:
  if os.path.isdir(os.path.join(root_folder, folder)):
    print(folder)
  else:
    print(f"No subfolders existing but found {len(folders)} files.")
    break
# Out:
# gravity
# magnetic
# magnetotelluric
# radiometric
# seismic

# %%
# Select the folders to process
SELECTION = ["gravity",
             "magnetic",
             "magnetotelluric",
             "radiometric",
             "seismic",]

input_folders = [root_folder / folder for folder in SELECTION]

print("Selected folders:")
for folder in input_folders:
  print(folder)
# Out:
# Selected folders:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\gravity
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\magnetic
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\magnetotelluric
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\radiometric
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\seismic

# %% [markdown]
# **Run Scaling** for STD scaler
# Existing files will **not** be overwritten

# %%
for folder in input_folders:
  folder_relative = os.path.relpath(folder, root_folder)
  print(f"\nProcessing {folder.name} with {METHOD} method...")    
  output_folder = OUT_FOLDER / str(folder_relative)
  print(f"Output folder: {output_folder}")
  transformation.scale_raster(folder, output_folder, METHOD)
# Out:
# Processing gravity with standard method...
# Output folder: s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified_scaled_std\geophysics\gravity
# Selected folder: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\gravity
# Total of folders found: 1
# Files loaded: 10
# Processing files: 100%|██████████| 10/10 [00:02<00:00,  3.46it/s]
# Processing magnetic with standard method...
# Output folder: s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified_scaled_std\geophysics\magnetic
# Selected folder: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\magnetic
# Total of folders found: 1
# Files loaded: 7
# Processing files: 100%|██████████| 7/7 [00:02<00:00,  2.86it/s]
# Processing magnetotelluric with standard method...
# Output folder: s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified_scaled_std\geophysics\magnetotelluric
# Selected folder: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\magnetotelluric
# Total of folders found: 2
# Files loaded: 5
# Processing files: 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
# Processing radiometric with standard method...
# Output folder: s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified_scaled_std\geophysics\radiometric
# Selected folder: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\radiometric
# Total of folders found: 1
# Files loaded: 3
# Processing files: 100%|██████████| 3/3 [00:01<00:00,  1.64it/s]
# Processing seismic with standard method...
# Output folder: s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified_scaled_std\geophysics\seismic
# Selected folder: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_102008_2240_us_cont\unified\geophysics\seismic
# Total of folders found: 1
# Files loaded: 4
# Processing files: 100%|██████████| 4/4 [00:02<00:00,  1.99it/s]
