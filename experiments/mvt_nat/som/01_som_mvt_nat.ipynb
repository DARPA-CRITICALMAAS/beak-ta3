# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import mvt_nat
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "MVT_PREFERRED_NUMERICAL_ISOGRAVITY_SOM"
model = mvt_nat.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "EPSG_4326_RES_0_025"
BASE_EXTENT = "CLIPPED_USC"

# Choose data path
PATH_MCCAFFERTY =  BASE_PATH / "MCCAFFERTY23" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "GEOPHYSICS_SCALED_STD"
PATH_ISOGRAVITY = BASE_PATH / "GEOPHYSICS_ISOGRAVITY" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_MAGNETOTELLURIC = BASE_PATH / "GEOPHYSICS_MAGNETOTELLURICS" / "PROCESSED" / "CONUS_2023" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_ULTRAMAFICS = BASE_PATH / "GEOLOGY_US_ULTRAMAFICS" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED"
PATH_LAWLEY_NUMERICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "NUMERICAL_SCALED_STANDARD"
PATH_LAWLEY_CATEGORICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "CATEGORICAL"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "MVT_NAT" / f"MVT_{BASE_SPATIAL}_{BASE_EXTENT}.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_MAGNETOTELLURIC, PATH_ISOGRAVITY,
             PATH_MCCAFFERTY, PATH_LAWLEY_NUMERICAL,
             PATH_ULTRAMAFICS, PATH_LAWLEY_CATEGORICAL],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 18 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 6 folders, 43 subfolders and 837 files.
#
# Searching for corresponding files...
# Found 'Terrane_Proximity' in 1 file(s).
# Found 'Geology_PassiveMargin_Proximity' in 1 file(s).
# Found 'Geology_BlackShale_Proximity' in 1 file(s).
# Found 'Geology_Fault_Proximity' in 1 file(s).
# Found 'Geology_Paleolatitude_Period_Maximum' in 1 file(s).
# Found 'Geology_Paleolatitude_Period_Minimum' in 1 file(s).
# Found 'Gravity_GOCE_ShapeIndex' in 1 file(s).
# Found 'Gravity_Bouguer_UpCont30km_HGM' in 1 file(s).
# Found 'Gravity_Bouguer_HGM_Worms_Proximity' in 1 file(s).
# Found 'Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity' in 1 file(s).
# Found 'US_IsostaticGravity_HGM_WGS84' in 1 file(s).
# Found 'US_IsostaticGravity_WGS84' in 1 file(s).
# Found 'Magnetic_HGM' in 1 file(s).
# Found 'Magnetic_LongWavelength_HGM' in 1 file(s).
# Found 'Magnetic_HGM_Worms_Proximity' in 1 file(s).
# Found 'Magnetic_LongWavelength_HGM_Worms_Proximity' in 1 file(s).
# Found 'Seismic_LAB_Hoggard' in 1 file(s).
# Found 'Seismic_Moho' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 18

# %%
# Replace Mag Analytical Signal STD with LOG version
LOG_MOD = True

if LOG_MOD is True:
    for i, path in enumerate(file_list):
        if "Mag_AnalyticSignal_cog.tif" in str(path):
            print(f"{path} found at index {i}.")
            file_list[i] = str(file_list[i]).replace("GEOPHYSICS_SCALED_STD", "GEOPHYSICS_SCALED_LOG")
            file_list[i] = Path(file_list[i])
            break

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 40                    # X dimension of generated SOM
args.som_y = 40                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 30               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
MODEL_NAME = "SOM_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME
check_path(MODEL_FOLDER)
# Out:
# WindowsPath('d:/Programmieren/00_Repositories/CMAAS/beak-ta3/experiments/mvt_nat/som/models/SOM_F18_X40_Y40_CMAX50_20240403-152413')

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 18
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Terrane_Proximity.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Geology_PassiveMargin_Proximity.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Geology_BlackShale_Proximity.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Geology_Fault_Proximity.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Geology_Paleolatitude_Period_Maximum.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Geology_Paleolatitude_Period_Minimum.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Gravity_GOCE_ShapeIndex.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer_UpCont30km_HGM.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer_HGM_Worms_Proximity.tif
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity.tif
# ...
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Seismic_Moho.tif
# Number of files added: 1
# Files:
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\TRAINING_LABELS\MVT_NAT\MVT_EPSG_4326_RES_0_025_CLIPPED_USC.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
# Warning: Geotransform of d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\TRAINING_LABELS\MVT_NAT\MVT_EPSG_4326_RES_0_025_CLIPPED_USC.tif does not match with d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\CLIPPED_USC\NUMERICAL_SCALED_STANDARD\Terrane_Proximity.tif
#     Execution time: 0.7995500564575195 seconds
# Run SOM
#     Execution time: 58.32162880897522 seconds
# Clustering progress:
#   File "c:\Users\storch\AppData\Local\miniconda3\envs\beak-ta3\lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# 0.00%
# 9.52%
# 19.05%
# 28.57%
# 38.10%
# 47.62%
# 57.14%
# 66.67%
# 76.19%
# 85.71%
# 95.24%
# 100% Clustering completed.
#     Execution time: 10.718470335006714 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 36.664321184158325 seconds
# Save SOM space results
#     Execution time: 0.7529933452606201 seconds
# Save SOM object to file
#     Execution time: 0.006015777587890625 seconds
# Do label analysis and write to file
#     Execution time: 10.654794931411743 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_Terrane_Proximity
#           b_Geology_PassiveMargin_Proximity
#           b_Geology_BlackShale_Proximity
#           b_Geology_Fault_Proximity
#           b_Geology_Paleolatitude_Period_Maximum
#           b_Geology_Paleolatitude_Period_Minimum
#           b_Gravity_GOCE_ShapeIndex
#           b_Gravity_Bouguer_UpCont30km_HGM
#           b_Gravity_Bouguer_HGM_Worms_Proximity
#           b_Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity
#           b_US_IsostaticGravity_HGM_WGS84
#           b_US_IsostaticGravity_WGS84
#           b_Magnetic_HGM
#           b_Magnetic_LongWavelength_HGM
#           b_Magnetic_HGM_Worms_Proximity
#           b_Magnetic_LongWavelength_HGM_Worms_Proximity
#           b_Seismic_LAB_Hoggard
#           b_Seismic_Moho
#           q_error
#           BMU_BMU_label_count.tif
#           BMU_cluster_label_count.tif
#     Execution time: 22.09667944908142 seconds
# Count cluster hit count
#     Execution time: 24.922547340393066 seconds

# %%
import beak.methods.som.plot_som_results as plot
#from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/exports/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= '-9999'                              # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.03145289421081543 seconds
#         Read geo data execution time: 10.164107322692871 seconds
#         Read label annotation data
#     Execution time: 18.2865252494812 seconds
# Plot geo space results
#     geospace plot no. 2 from 20
# d:\programmieren\00_repositories\cmaas\beak-ta3\src\beak\methods\som\plot_som_results.py:283: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 20 from 20
#     q-error plot
#     Execution time: 38.16765069961548 seconds
# Plot Cluster result SOM space
#     Draw som cluster plot
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Plot cluster label count
#     Execution time: 1.3591210842132568 seconds
# Plot SOM space results
#     somspace plot no. 18 from 18
#     Execution time: 6.386592626571655 seconds
# Plot Boxplots
#     boxplot no. 18 from 18
#     Execution time: 15.934245586395264 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-Q6sAWuFg8CDRDZxq7LwssE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Q6sAWuFg8CDRDZxq7LwssE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Q6sAWuFg8CDRDZxq7LwssE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Q6sAWuFg8CDRDZxq7LwssE:checked ~ #ipyplot-html-viewer-textarea-Q6sAWuFg8CDRDZxq7LwssE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Q6sAWuFg8CDRDZxq7LwssE:checked + #ipyplot-html-viewer-label-Q6sAWuFg8CDRDZxq7LwssE:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Q6sAWuFg8CDRDZxq7LwssE">
#         <label id="ipyplot-html-viewer-label-Q6sAWuFg8CDRDZxq7LwssE" for="ipyplot-html-viewer-toggle-Q6sAWuFg8CDRDZxq7LwssE">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Q6sAWuFg8CDRDZxq7LwssE" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw {
#                 display: none;
#             }
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw + label.ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw:checked + label.ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw ~ .tab {
#                 display: none
#             }
#     #tabFuQNnSGe7cut6zUWrSNqmh:checked ~ .tab.contentFuQNnSGe7cut6zUWrSNqmh,#tabUJRRADZZNmucjMdKpcGrWN:checked ~ .tab.contentUJRRADZZNmucjMdKpcGrWN,#tab3xzCwywQ2tZupzqDZJeCgg:checked ~ .tab.content3xzCwywQ2tZupzqDZJeCgg,#tabLFwqzPTVyD9mQVcgWw97sb:checked ~ .tab.contentLFwqzPTVyD9mQVcgWw97sb,#tabN74fBhhxCouYFhh3ViD9Nx:checked ~ .tab.contentN74fBhhxCouYFhh3ViD9Nx{ display: block; }</style><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabFuQNnSGe7cut6zUWrSNqmh" checked /><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabFuQNnSGe7cut6zUWrSNqmh">boxplot</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabUJRRADZZNmucjMdKpcGrWN"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabUJRRADZZNmucjMdKpcGrWN">db</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tab3xzCwywQ2tZupzqDZJeCgg"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tab3xzCwywQ2tZupzqDZJeCgg">geoplot</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabLFwqzPTVyD9mQVcgWw97sb"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabLFwqzPTVyD9mQVcgWw97sb">hit</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabN74fBhhxCouYFhh3ViD9Nx"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabN74fBhhxCouYFhh3ViD9Nx">somplot</label><div class="tab contentFuQNnSGe7cut6zUWrSNqmh">
#         <style>
#         #ipyplot-imgs-container-div-gDCmS6iSaDaboYvqtXh3H5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gDCmS6iSaDaboYvqtXh3H5">
#     <div class="ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5">
#         <div id="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-hUCtdxyrxx2bjN9sq29xMh" class="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_1.png</h4><img src="models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-hUCtdxyrxx2bjN9sq29xMh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5">
#         <div id="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-GBkst2TD9pF7H8x8oQNKF6" class="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_10.png</h4><img src="models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-GBkst2TD9pF7H8x8oQNKF6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5">
#         <div id="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-TcCWuTJSfDLKn
# <div>
#         <style>
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw {
#                 display: none;
#             }
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw + label.ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw:checked + label.ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw ~ .tab {
#                 display: none
#             }
#     #tabFuQNnSGe7cut6zUWrSNqmh:checked ~ .tab.contentFuQNnSGe7cut6zUWrSNqmh,#tabUJRRADZZNmucjMdKpcGrWN:checked ~ .tab.contentUJRRADZZNmucjMdKpcGrWN,#tab3xzCwywQ2tZupzqDZJeCgg:checked ~ .tab.content3xzCwywQ2tZupzqDZJeCgg,#tabLFwqzPTVyD9mQVcgWw97sb:checked ~ .tab.contentLFwqzPTVyD9mQVcgWw97sb,#tabN74fBhhxCouYFhh3ViD9Nx:checked ~ .tab.contentN74fBhhxCouYFhh3ViD9Nx{ display: block; }</style><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabFuQNnSGe7cut6zUWrSNqmh" checked /><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabFuQNnSGe7cut6zUWrSNqmh">boxplot</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabUJRRADZZNmucjMdKpcGrWN"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabUJRRADZZNmucjMdKpcGrWN">db</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tab3xzCwywQ2tZupzqDZJeCgg"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tab3xzCwywQ2tZupzqDZJeCgg">geoplot</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabLFwqzPTVyD9mQVcgWw97sb"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabLFwqzPTVyD9mQVcgWw97sb">hit</label><input class="ipyplot-tab-VcxatYgK8iHRx8NsjEV8tw" type="radio" name="tabs-VcxatYgK8iHRx8NsjEV8tw" id="tabN74fBhhxCouYFhh3ViD9Nx"/><label class="ipyplot-tab-label-VcxatYgK8iHRx8NsjEV8tw" for="tabN74fBhhxCouYFhh3ViD9Nx">somplot</label><div class="tab contentFuQNnSGe7cut6zUWrSNqmh">
#         <style>
#         #ipyplot-imgs-container-div-gDCmS6iSaDaboYvqtXh3H5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gDCmS6iSaDaboYvqtXh3H5">
#     <div class="ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5">
#         <div id="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-hUCtdxyrxx2bjN9sq29xMh" class="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_1.png</h4><img src="models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-hUCtdxyrxx2bjN9sq29xMh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5">
#         <div id="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-GBkst2TD9pF7H8x8oQNKF6" class="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_10.png</h4><img src="models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-GBkst2TD9pF7H8x8oQNKF6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5">
#         <div id="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-TcCWuTJSfDLKnLqn6mY4rt" class="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_11.png</h4><img src="models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-TcCWuTJSfDLKnLqn6mY4rt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gDCmS6iSaDaboYvqtXh3H5">
#         <div id="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5-5DpMHScQai4aT3YNHQyMwo" class="ipyplot-content-div-gDCmS6iSaDaboYvqtXh3H5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_12.png</h4><img src="models\SOM_F18_X40_Y40_CMAX50_20240403-152413\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-