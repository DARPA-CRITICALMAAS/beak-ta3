# %% [markdown]
# <p style="font-size:35px; text-align:center; font-weight:bold">CMAAS run SOM clustering method</p>
# <p style="font-size:17px; text-align:left">Ina Storch 06-11-2023 </p>
# <p style="font-size:17px; text-align:left">Note: This notebook is designed to run SOM using preprocessed data gained from the datacube from: Lawley et al., 2021. </p>
# <p style="font-size:17px; text-align:left">Reference: Lawley, C.J.M., McCafferty, A.E., Graham, G.E., Gadd, M.G., Huston, D.L., Kelley, K.D., Paradis, S., Peter, J.M., and Czarnota, K., 2021. Datasets to support prospectivity modelling for sediment-hosted Zn-Pb mineral systems; Geological Survey of Canada, Open File 8836, 1 .zip file. https://doi.org/10.4095/329203</p>

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">1) Import libraries, define SOM arguments</p>

# %%
from beak.methods.som.nextsomcore.nextsomcore import NxtSomCore
import pickle

import beak.methods.som.argsSOM as asom

args = asom.Args()

#base_path = "d:/Programmieren/00_Repositories/CMAAS"
base_path = "d:/projekte/cmaas/repository"

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">2) Provide input file(s).
#
# Input data can eighter be in LRN file format (a table with X, Y, Z and one line with the values for each data layer) or geoTIF file format. Choose one.
#
# When you run a Docker container, you need to specify which directories or paths from your local machine should be mounted into the container since Docker containers are isolated environments, and by default, they can only access files within their own filesystem or volumes.
#
# Alternatively, copy your input data to beak-ta3\src\beak\data. In case of GeoTIF input files, you can create subfolders and collect all TIF files that you want to use for SOM in there. In the following code cell you can provide a file path and a patterns (like "*.tif") for files within that specific folder that you want to use for SOM.
#
# If input file format is LRN, skip the next code cell and provide the file name (including file path) with args.input_file. LRN files should not contain nan values since so far noData handeling is implemented for GeoTIF input only.

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">Either: Data input in geoTiff format:
#
# List geoTiff files, separated by komma: ["path/name1.tiff","path/name2.tiff"] </br>
#
# Here an option is provided how to compose such a list: provide a file path and one or more file patterns (or a list of file names) to select all files matching this pattern inside the specified folder. The file patterns can also include subfolder specifications and * to select all files within this subfolder ('subfolder/*.tif') .

# %%
#--------------- Option 1: specify data path and file patterns 
#import sys
#if sys.version_info < (3, 9):
#    from importlib_resources import files
#else:
#    from importlib.resources import files

#BASE_PATH = (files("beak.data") / "LAWLEY22-EXPORT" / "EPSG_3857_RES_5000" / "CLIPPED_USC")

#PATH_NUMERICAL = BASE_PATH / "NUMERICAL_SCALED_MINMAX" / "*.tif"
#PATH_CATEGORICAL = BASE_PATH / "CATEGORICAL" / "*" /"*.tif"

#PATH_NUMERICAL = BASE_PATH / "NUMERICAL_SCALED_MINMAX" / "Magnetic_LongWavelength_HGM.tif"
#PATH_CATEGORICAL = BASE_PATH / "CATEGORICAL" / "Geology_Lithology_Majority_Igneous_Intrusive_Felsic.tif"

#file_patterns = [str(PATH_NUMERICAL), str(PATH_CATEGORICAL)]


#args.input_file = args.create_list_from_pattern("", file_patterns)

#--------------- Option 2: load a list of GeoTIF files from TXT file 
# Specify the file path
file_path = base_path + "/beak-ta3/experiments/mag_nickel_nat/som/results/input_file_list.txt"
# optional:
#file_path_label = base_path + "/beak-ta3/experiments/mvt_nat/som/results/label_file_list.txt"


args.input_file = args.create_list_from_file(file_path)

#---------------
args.geotiff_input=args.input_file      # geotiff_input files, separated by komma, to write GeoTIF out (only first line is used to get the geotransform and projection information to set output GeoFIT geotransform and projection)
# Out:
# Number of files added: 14
# Files:
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\ISOGRAVITY-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Gravity_Up30km_HGM.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\MagRTP.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Mag_AnalyticSignal_cog_log.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\MagRTP_HGMDeepSources.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Moho.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\LAB.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\LAB_HGM_cog.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MAGNETOTELLURICS-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\CONUS_MT2023_9km_cog.tif
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MAGNETOTELLURICS-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\CONUS_MT2023_15km_cog.tif
# ...
# d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\LAB_Worms_Proximity.tif

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">Or: Data input in LRN format (data table):
#
# Specify file path and name!

# %%
#args.input_file="/methods/methods/som/data/input/SOM_grav_mag.lrn"

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">3) Specify parameter for SOM.

# %%
     
args.output_folder = base_path + "/beak-ta3/experiments/mag_nickel_nat/som/results" # Folder to save som dictionary and cluster dictionary
args.output_file_somspace = args.output_folder+"/result_som.txt"   # DO NOT CHANGE! Text file that will contain calculated values: som_x som_y b_data1 b_data2 b_dataN umatrix cluster in geospace.

args.som_x = 50                # X dimension of generated SOM
args.som_y = 50               # Y dimension of generated SOM
args.epochs = 10               # Number of epochs to run

# Additional optional parameters:
args.outgeofile= args.output_folder+"/result_geo.txt"             # DO NOT CHANGE!
args.output_file_geospace=args.outgeofile   # Text file that will contain calculated values: {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN in geospace.

args.kmeans="true"          # Run k-means clustering (true, false)
args.kmeans_init = 5           # Number of initializations
args.kmeans_min = 20            # Minimum number of k-mean clusters
args.kmeans_max = 50           # Maximum number of k-mean clusters

args.neighborhood = 'gaussian'     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = 'toroid'            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = 'linear'      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = 'linear'       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = 'random'     # Type of SOM initialization (random, pca)
args.gridtype = 'rectangular'      # Type of SOM grid (hexagonal, rectangular)

args.label = False                  # Whether data contains label column, True or False
args.label_geotiff_file = args.output_folder + "/input_file_list.txt"      # geotiff_input file (None)

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">4) Run SOM
#
# Before running SOM - clean up existing files and move them to a subfolder.

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

# move or remove existing SOM output files from previous runs into subfolder
#mts.move_som_results(args.output_folder, "old_results")
mts.remove_som_results(args.output_folder)

# run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
# Warning: Geotransform of d:\projekte\cmaas\repository\beak-ta3\src\beak\data\MCCAFFERTY23-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\GEOPHYSICS_SCALED_STD\Mag_AnalyticSignal_cog_log.tif does not match with d:\projekte\cmaas\repository\beak-ta3\src\beak\data\ISOGRAVITY-PROCESSED\EPSG_4326_RES_0_025\CLIPPED_USC\UNIFIED_SCALED_STD\US_IsostaticGravity_WGS84.tif
#     Execution time: 0.9710345268249512 seconds
# Run SOM
#     Execution time: 537.5104846954346 seconds
# Clustering progress:
# 0.00%
# 9.68%
# 19.35%
# 29.03%
# 38.71%
# 48.39%
# 58.06%
# 67.74%
# 77.42%
# 87.10%
# 96.77%
# 100% Clustering completed.
#     Execution time: 21.837078094482422 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 99.41535520553589 seconds
# Save SOM space results
#     Execution time: 1.462230920791626 seconds
# Save SOM object to file
#     Execution time: 0.005864143371582031 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_US_IsostaticGravity_WGS84
#           b_Gravity_Up30km_HGM
#           b_MagRTP
#           b_Mag_AnalyticSignal_cog_log
#           b_MagRTP_HGMDeepSources
#           b_Moho
#           b_LAB
#           b_LAB_HGM_cog
#           b_CONUS_MT2023_9km_cog
#           b_CONUS_MT2023_15km_cog
#           b_CONUS_MT2023_30km_cog
#           b_Magnetic_LongWavelength_HGM_Worms_Proximity
#           b_Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity
#           b_LAB_Worms_Proximity
#     Execution time: 30.98854088783264 seconds
# Count cluster hit count
#         Cluster hit count: 49 - 19628
#         Cluster hit count: 48 - 18045
#         Cluster hit count: 47 - 29473
#         Cluster hit count: 46 - 13250
#         Cluster hit count: 45 - 15679
#         Cluster hit count: 44 - 14806
#         Cluster hit count: 43 - 41643
#         Cluster hit count: 42 - 20153
#         Cluster hit count: 41 - 40828
#         Cluster hit count: 40 - 18152
#         Cluster hit count: 39 - 29757
#         Cluster hit count: 38 - 21607
#         Cluster hit count: 37 - 15788
#         Cluster hit count: 36 - 12248
#         Cluster hit count: 35 - 12423
#         Cluster hit count: 34 - 20165
#         Cluster hit count: 33 - 24776
#         Cluster hit count: 32 - 20627
#         Cluster hit count: 31 - 16824
#         Cluster hit count: 30 - 13549
#         Cluster hit count: 29 - 13375
#         Cluster hit count: 28 - 19019
#         Cluster hit count: 27 - 44342
#         Cluster hit count: 26 - 21375
#         Cluster hit count: 25 - 20038
#         Cluster hit count: 24 - 26274
#         Cluster hit count: 23 - 28187
#         Cluster hit count: 22 - 14272
#         Cluster hit count: 21 - 35387
#         Cluster hit count: 20 - 30792
#         Cluster hit count: 19 - 37759
#         Cluster hit count: 18 - 18492
#         Cluster hit count: 17 - 38294
#         Cluster hit count: 16 - 32101
#         Cluster hit count: 15 - 43679
#         Cluster hit count: 14 - 35690
#         Cluster hit count: 13 - 28932
#         Cluster hit count: 12 - 45866
#         Cluster hit count: 11 - 16693
#         Cluster hit count: 10 - 24524
#         Cluster hit count: 9 - 55688
#         Cluster hit count: 8 - 28160
#         Cluster hit count: 7 - 7196
#         Cluster hit count: 6 - 40746
#         Cluster hit count: 5 - 18043
#         Cluster hit count: 4 - 38616
#         Cluster hit count: 3 - 39411
#         Cluster hit count: 2 - 29208
#         Cluster hit count: 1 - 10072
#         Cluster hit count: 0 - 23161
#     Execution time: 54.593064069747925 seconds

# %%
import beak.methods.som.plot_som_results as plot
from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)
# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# <p style="font-size:19px; text-align:left; font-weight:bold">5) Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile= args.output_file_somspace   # som calculation somspace output text file
argsP.som_x= args.som_x         # som x dimension
argsP.som_y= args.som_y         # som y dimension
argsP.input_file= args.input_file   # Input file(*.lrn)
argsP.dir= args.output_folder            # Input file(*.lrn) or directory where som.dictionary was safet to (/output/som.dictionary)
argsP.grid_type= 'rectangular' # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw='true'       # whether to draw all plots, or only those required for clustering (true: draw all. false:draw only for clustering).
argsP.outgeofile=args.output_file_geospace     # som geospace results txt file
argsP.dataType='grid'       # Data type (scatter or grid)
argsP.noDataValue='-9999'    # noData value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.07432150840759277 seconds
#         Read geo data execution time: 15.027573585510254 seconds
#     Execution time: 15.128480434417725 seconds
# Plot geo space results
#     geospace plot no. 2 from 16
# d:\projekte\cmaas\repository\beak-ta3\src\beak\methods\som\plot_som_results.py:274: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 16 from 16
#     q-error plot
#     Execution time: 82.0759105682373 seconds
# Plot Cluster result SOM space
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Execution time: 3.3434712886810303 seconds
# Plot SOM space results
#     somspace plot no. 14 from 14
#     Execution time: 12.207745552062988 seconds
# Plot Boxplots
#     boxplot no. 14 from 14
#     Execution time: 32.17098951339722 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

tabs = [image.split('_')[-2] for image in labels]

print("List of figures:")
print(labels)
#print(tabs)

# Plot the images
#ipyplot.plot_images(images, max_images=50, img_width=250)
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
# List of figures:
# ['geoplot_1.png', 'geoplot_10.png', 'geoplot_11.png', 'geoplot_12.png', 'geoplot_13.png', 'geoplot_14.png', 'geoplot_15.png', 'geoplot_16.png', 'geoplot_2.png', 'geoplot_3.png', 'geoplot_4.png', 'geoplot_5.png', 'geoplot_6.png', 'geoplot_7.png', 'geoplot_8.png', 'geoplot_9.png', 'somplot_1.png', 'somplot_10.png', 'somplot_11.png', 'somplot_12.png', 'somplot_13.png', 'somplot_14.png', 'somplot_15.png', 'somplot_16.png', 'somplot_17.png', 'somplot_2.png', 'somplot_3.png', 'somplot_4.png', 'somplot_5.png', 'somplot_6.png', 'somplot_7.png', 'somplot_8.png', 'somplot_9.png', 'boxplot_1.png', 'boxplot_10.png', 'boxplot_11.png', 'boxplot_12.png', 'boxplot_13.png', 'boxplot_14.png', 'boxplot_2.png', 'boxplot_3.png', 'boxplot_4.png', 'boxplot_5.png', 'boxplot_6.png', 'boxplot_7.png', 'boxplot_8.png', 'boxplot_9.png', 'db_score.png', 'cluster_hit_count.png']
#     <style>
#         #ipyplot-html-viewer-toggle-L2G44Chuaa7WEog4LinvgH {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-L2G44Chuaa7WEog4LinvgH {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-L2G44Chuaa7WEog4LinvgH {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-L2G44Chuaa7WEog4LinvgH:checked ~ #ipyplot-html-viewer-textarea-L2G44Chuaa7WEog4LinvgH {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-L2G44Chuaa7WEog4LinvgH:checked + #ipyplot-html-viewer-label-L2G44Chuaa7WEog4LinvgH:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-L2G44Chuaa7WEog4LinvgH">
#         <label id="ipyplot-html-viewer-label-L2G44Chuaa7WEog4LinvgH" for="ipyplot-html-viewer-toggle-L2G44Chuaa7WEog4LinvgH">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-L2G44Chuaa7WEog4LinvgH" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa {
#                 display: none;
#             }
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa + label.ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa:checked + label.ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa ~ .tab {
#                 display: none
#             }
#     #tabKomCXPbvwLZ694dwMQZkbs:checked ~ .tab.contentKomCXPbvwLZ694dwMQZkbs,#tab6WckVXuowC7HqijBeMaLxq:checked ~ .tab.content6WckVXuowC7HqijBeMaLxq,#tabUr8hvW7raDetSmiPxgTGoP:checked ~ .tab.contentUr8hvW7raDetSmiPxgTGoP,#tabFN5FcZEcYwDK6XroRJWNHa:checked ~ .tab.contentFN5FcZEcYwDK6XroRJWNHa,#tabEHYcopKZwmCRdpZeFbLMtk:checked ~ .tab.contentEHYcopKZwmCRdpZeFbLMtk{ display: block; }</style><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabKomCXPbvwLZ694dwMQZkbs" checked /><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabKomCXPbvwLZ694dwMQZkbs">boxplot</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tab6WckVXuowC7HqijBeMaLxq"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tab6WckVXuowC7HqijBeMaLxq">db</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabUr8hvW7raDetSmiPxgTGoP"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabUr8hvW7raDetSmiPxgTGoP">geoplot</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabFN5FcZEcYwDK6XroRJWNHa"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabFN5FcZEcYwDK6XroRJWNHa">hit</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabEHYcopKZwmCRdpZeFbLMtk"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabEHYcopKZwmCRdpZeFbLMtk">somplot</label><div class="tab contentKomCXPbvwLZ694dwMQZkbs">
#         <style>
#         #ipyplot-imgs-container-div-KPBSDp778XCQwbMCnWBRbs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-KPBSDp778XCQwbMCnWBRbs">
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-eCjCN8ngfRa4rHWruN2sFg" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_1.png</h4><img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-eCjCN8ngfRa4rHWruN2sFg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-H597FsJTkoavMEwfz4wDge" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_10.png</h4><img src="results\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-H597FsJTkoavMEwfz4wDge">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-L85qQrdfnSDDAas5GyGz29" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-lef
# <div>
#         <style>
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa {
#                 display: none;
#             }
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa + label.ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa:checked + label.ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa ~ .tab {
#                 display: none
#             }
#     #tabKomCXPbvwLZ694dwMQZkbs:checked ~ .tab.contentKomCXPbvwLZ694dwMQZkbs,#tab6WckVXuowC7HqijBeMaLxq:checked ~ .tab.content6WckVXuowC7HqijBeMaLxq,#tabUr8hvW7raDetSmiPxgTGoP:checked ~ .tab.contentUr8hvW7raDetSmiPxgTGoP,#tabFN5FcZEcYwDK6XroRJWNHa:checked ~ .tab.contentFN5FcZEcYwDK6XroRJWNHa,#tabEHYcopKZwmCRdpZeFbLMtk:checked ~ .tab.contentEHYcopKZwmCRdpZeFbLMtk{ display: block; }</style><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabKomCXPbvwLZ694dwMQZkbs" checked /><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabKomCXPbvwLZ694dwMQZkbs">boxplot</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tab6WckVXuowC7HqijBeMaLxq"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tab6WckVXuowC7HqijBeMaLxq">db</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabUr8hvW7raDetSmiPxgTGoP"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabUr8hvW7raDetSmiPxgTGoP">geoplot</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabFN5FcZEcYwDK6XroRJWNHa"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabFN5FcZEcYwDK6XroRJWNHa">hit</label><input class="ipyplot-tab-cgkxzYKJHunLSvNfTaqHBa" type="radio" name="tabs-cgkxzYKJHunLSvNfTaqHBa" id="tabEHYcopKZwmCRdpZeFbLMtk"/><label class="ipyplot-tab-label-cgkxzYKJHunLSvNfTaqHBa" for="tabEHYcopKZwmCRdpZeFbLMtk">somplot</label><div class="tab contentKomCXPbvwLZ694dwMQZkbs">
#         <style>
#         #ipyplot-imgs-container-div-KPBSDp778XCQwbMCnWBRbs {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-KPBSDp778XCQwbMCnWBRbs">
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-eCjCN8ngfRa4rHWruN2sFg" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_1.png</h4><img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-eCjCN8ngfRa4rHWruN2sFg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-H597FsJTkoavMEwfz4wDge" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_10.png</h4><img src="results\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-H597FsJTkoavMEwfz4wDge">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-L85qQrdfnSDDAas5GyGz29" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_11.png</h4><img src="results\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-L85qQrdfnSDDAas5GyGz29">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-8moqeo7knbmBcpEJ5eBbYk" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">results\plots\boxplot_12.png</h4><img src="results\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-8moqeo7knbmBcpEJ5eBbYk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-KPBSDp778XCQwbMCnWBRbs">
#         <div id="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs-eeZYHGpRgwSZuEupq747eq" class="ipyplot-content-div-KPBSDp778XCQwbMCnWBRbs">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; w
#     <style>
#         #ipyplot-html-viewer-toggle-aKfvXAPyQBno8bXTtVWiHE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-aKfvXAPyQBno8bXTtVWiHE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-aKfvXAPyQBno8bXTtVWiHE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-aKfvXAPyQBno8bXTtVWiHE:checked ~ #ipyplot-html-viewer-textarea-aKfvXAPyQBno8bXTtVWiHE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-aKfvXAPyQBno8bXTtVWiHE:checked + #ipyplot-html-viewer-label-aKfvXAPyQBno8bXTtVWiHE:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-aKfvXAPyQBno8bXTtVWiHE">
#         <label id="ipyplot-html-viewer-label-aKfvXAPyQBno8bXTtVWiHE" for="ipyplot-html-viewer-toggle-aKfvXAPyQBno8bXTtVWiHE">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-aKfvXAPyQBno8bXTtVWiHE" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-SqEooPrsAWtB5YaDaV3ea2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2 {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-SqEooPrsAWtB5YaDaV3ea2">
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-eCf4ryJiN2n5QpsqZEbGGW" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-eCf4ryJiN2n5QpsqZEbGGW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-VFtYaLb7bDMfiFK6XTpujk" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="results\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-VFtYaLb7bDMfiFK6XTpujk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WghbFAYoKUvWxhM9C6qsSz" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="results\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WghbFAYoKUvWxhM9C6qsSz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-LUxgJ2YaMEPrmbEHCxNDPb" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="results\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-LUxgJ2YaMEPrmbEHCxNDPb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-QvHdhyjv8WT2qZNtaBz8RH" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="results\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-QvHdhyjv8WT2qZNtaBz8RH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WU762WXMA3Sd23yF5kJRJk" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#             <img src="results\plots\boxplot_14.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WU762WXMA3Sd23yF5kJRJk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-NqwviqcHJdRb2AHoNmjXai" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="results\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-NqwviqcHJdRb2AHoNmjXai">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-di
#         <style>
#         #ipyplot-imgs-container-div-SqEooPrsAWtB5YaDaV3ea2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2 {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-SqEooPrsAWtB5YaDaV3ea2">
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-eCf4ryJiN2n5QpsqZEbGGW" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="results\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-eCf4ryJiN2n5QpsqZEbGGW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-VFtYaLb7bDMfiFK6XTpujk" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="results\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-VFtYaLb7bDMfiFK6XTpujk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WghbFAYoKUvWxhM9C6qsSz" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="results\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WghbFAYoKUvWxhM9C6qsSz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-LUxgJ2YaMEPrmbEHCxNDPb" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="results\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-LUxgJ2YaMEPrmbEHCxNDPb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-QvHdhyjv8WT2qZNtaBz8RH" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_13.png</h4>
#             <img src="results\plots\boxplot_13.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-QvHdhyjv8WT2qZNtaBz8RH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WU762WXMA3Sd23yF5kJRJk" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_14.png</h4>
#             <img src="results\plots\boxplot_14.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-WU762WXMA3Sd23yF5kJRJk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-NqwviqcHJdRb2AHoNmjXai" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="results\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-NqwviqcHJdRb2AHoNmjXai">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-NKZKi5aFGbp8zHfR9avSxT" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="results\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-NKZKi5aFGbp8zHfR9avSxT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-U7gwumJhjYNatovYbH9KJ6" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="results\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-U7gwumJhjYNatovYbH9KJ6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-SqEooPrsAWtB5YaDaV3ea2">
#         <div id="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2-3RhTCD4wDtoYa3m9WjMjYr" class="ipyplot-content-div-SqEooPrsAWtB5YaDaV3ea2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_5.png</h4>
#             <img src="results\plots\boxplot_5.png"/>
#             <a href="#!">
