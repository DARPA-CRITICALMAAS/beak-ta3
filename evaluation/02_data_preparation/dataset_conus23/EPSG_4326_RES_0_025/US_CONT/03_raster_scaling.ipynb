# %% [markdown]
# # Information
# ## How to
# 1. Set the parameters. **UPPERCASE** letters are user input variables
# 2. Run the reprojection cell

# %% [markdown]
# # Requirements

# %%
import os

import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

from pathlib import Path
from beak.utilities import transformation

# %% [markdown]
# # Scaling

# %% [markdown]
# **Scaling** all numerical folders within a specified model configuration.<br>
# Reads the <code>ROOT_FOLDER</code> and takes the <code>NUMERICAL</code> subfolder within each model configuration.

# %% [markdown]
# **User inputs**

# %%
BASE_PATH = files("beak.data")

BASE_NAME = Path("GEOPHYSICS_MAGNETOTELLURICS") / "PROCESSED" / "CONUS_2023"
BASE_SPATIAL = "EPSG_4326_RES_0_025"
BASE_EXTENT = "US_CONT"
METHODS = ["standard"]

# Export to current location for testing purposes
CURRENT_DIR = Path(os.getcwd())
PATH_EXPORT = CURRENT_DIR / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT

# %% [markdown]
# Select subfolders to be scaled.

# %%
root_folder = BASE_PATH / BASE_NAME / BASE_SPATIAL / BASE_EXTENT

for folder in os.listdir(root_folder):
  if os.path.isdir(os.path.join(root_folder, folder)):
    print(folder)
# Out:
# UNIFIED
# UNIFIED_IMPUTED
# UNIFIED_IMPUTED_SCALED_STD
# UNIFIED_SCALED_STD

# %%
SELECTION = ["UNIFIED", "UNIFIED_IMPUTED"]
input_folders = [root_folder / folder for folder in SELECTION]

print("Selected folders:")
for folder in input_folders:
  print(folder)
# Out:
# Selected folders:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\GEOPHYSICS_MAGNETOTELLURICS\PROCESSED\CONUS_2023\EPSG_4326_RES_0_025\US_CONT\UNIFIED
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\GEOPHYSICS_MAGNETOTELLURICS\PROCESSED\CONUS_2023\EPSG_4326_RES_0_025\US_CONT\UNIFIED_IMPUTED

# %% [markdown]
# **Scaling**

# %%
for folder in input_folders:
  folder_relative = os.path.relpath(folder, root_folder)
  for method in METHODS:
    if method == "standard":
      method_name = "STD"
    if method == "minmax":
      method_name = "MINMAX"
      
    print(f"\nProcessing {folder} with {method} method...")    
    output_folder = PATH_EXPORT / str(folder_relative + "_SCALED_" + str.upper(method_name))
    print(output_folder)
    transformation.scale_raster(folder, output_folder, method)
# Out:
# Processing s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\GEOPHYSICS_MAGNETOTELLURICS\PROCESSED\CONUS_2023\EPSG_4326_RES_0_025\US_CONT\UNIFIED with standard method...
# s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\examples\notebooks\dataset_conus23\PROCESSED\EPSG_4326_RES_0_025\US_CONT\UNIFIED_SCALED_STD
#
# Processing s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\GEOPHYSICS_MAGNETOTELLURICS\PROCESSED\CONUS_2023\EPSG_4326_RES_0_025\US_CONT\UNIFIED_IMPUTED with standard method...
# s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\examples\notebooks\dataset_conus23\PROCESSED\EPSG_4326_RES_0_025\US_CONT\UNIFIED_IMPUTED_SCALED_STD
