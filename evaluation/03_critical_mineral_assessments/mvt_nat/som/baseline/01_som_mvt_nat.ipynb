# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import mvt_nat
from beak.utilities.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom
args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "MVT_BASELINE"
model = mvt_nat.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "EPSG_4326_RES_0_025"
BASE_EXTENT = "US_CONT"

# Choose data path
PATH_MCCAFFERTY =  BASE_PATH / "MCCAFFERTY23" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "GEOPHYSICS_SCALED_STD"
PATH_ISOGRAVITY = BASE_PATH / "GEOPHYSICS_ISOGRAVITY" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_MAGNETOTELLURIC = BASE_PATH / "GEOPHYSICS_MAGNETOTELLURICS" / "PROCESSED" / "CONUS_2023" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED_SCALED_STD"
PATH_ULTRAMAFICS = BASE_PATH / "GEOLOGY_US_ULTRAMAFICS" / "PROCESSED" / BASE_SPATIAL / BASE_EXTENT / "UNIFIED"
PATH_LAWLEY_NUMERICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "NUMERICAL_SCALED_STANDARD"
PATH_LAWLEY_CATEGORICAL = BASE_PATH / "LAWLEY22" / "EXPORT" / BASE_SPATIAL / BASE_EXTENT / "CATEGORICAL"
PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "MVT_NAT" / f"MVT_{BASE_SPATIAL}_{BASE_EXTENT}.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_MAGNETOTELLURIC, PATH_ISOGRAVITY,
             PATH_MCCAFFERTY, PATH_LAWLEY_NUMERICAL,
             PATH_ULTRAMAFICS, PATH_LAWLEY_CATEGORICAL],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 12 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 6 folders, 43 subfolders and 837 files.
#
# Searching for corresponding files...
# Found 'Gravity_GOCE_ShapeIndex' in 1 file(s).
# Found 'Gravity_Bouguer' in 1 file(s).
# Found 'Gravity_Bouguer_HGM' in 1 file(s).
# Found 'Gravity_Bouguer_UpCont30km_HGM' in 1 file(s).
# Found 'Gravity_Bouguer_HGM_Worms_Proximity' in 1 file(s).
# Found 'Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity' in 1 file(s).
# Found 'Magnetic_HGM' in 1 file(s).
# Found 'Magnetic_LongWavelength_HGM' in 1 file(s).
# Found 'Magnetic_HGM_Worms_Proximity' in 1 file(s).
# Found 'Magnetic_LongWavelength_HGM_Worms_Proximity' in 1 file(s).
# Found 'Seismic_LAB_Hoggard' in 1 file(s).
# Found 'Seismic_Moho' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 12

# %%
# Replace Mag Analytical Signal STD with LOG version
LOG_MOD = True

if LOG_MOD is True:
    for i, path in enumerate(file_list):
        if "Mag_AnalyticSignal_cog.tif" in str(path):
            print(f"{path} found at index {i}.")
            file_list[i] = str(file_list[i]).replace("GEOPHYSICS_SCALED_STD", "GEOPHYSICS_SCALED_LOG")
            file_list[i] = Path(file_list[i])
            break

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 40                    # X dimension of generated SOM
args.som_y = 40                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 30               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
MODEL_NAME = "SOM_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL_NAME
check_path(MODEL_FOLDER)
# Out:
# WindowsPath('s:/Projekte/20230082_DARPA_CriticalMAAS_TA3/Bearbeitung/GitHub/beak-ta3/evaluation/cma_mvt_nat/som/baseline/models/SOM_F12_X40_Y40_CMAX50_20240412-102125')

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 12
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Gravity_GOCE_ShapeIndex.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer_UpCont30km_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer_HGM_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Magnetic_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Magnetic_LongWavelength_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Magnetic_HGM_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Magnetic_LongWavelength_HGM_Worms_Proximity.tif
# ...
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Seismic_Moho.tif
# Number of files added: 1
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\TRAINING_LABELS\MVT_NAT\MVT_EPSG_4326_RES_0_025_US_CONT.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
# Warning: Geotransform of s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\TRAINING_LABELS\MVT_NAT\MVT_EPSG_4326_RES_0_025_US_CONT.tif does not match with s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\LAWLEY22\EXPORT\EPSG_4326_RES_0_025\US_CONT\NUMERICAL_SCALED_STANDARD\Gravity_GOCE_ShapeIndex.tif
#     Execution time: 0.7669219970703125 seconds
# Run SOM
#     Execution time: 26.84980273246765 seconds
# Clustering progress:
# 0.00%
# 9.52%
# 19.05%
# 28.57%
# 38.10%
# 47.62%
# 57.14%
# 66.67%
# 76.19%
# 85.71%
# 95.24%
# 100% Clustering completed.
#     Execution time: 12.5433509349823 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 36.14137935638428 seconds
# Save SOM space results
#     Execution time: 1.1752231121063232 seconds
# Save SOM object to file
#     Execution time: 0.006998300552368164 seconds
# Do label analysis and write to file
#     Execution time: 35.68536925315857 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_Gravity_GOCE_ShapeIndex
#           b_Gravity_Bouguer
#           b_Gravity_Bouguer_HGM
#           b_Gravity_Bouguer_UpCont30km_HGM
#           b_Gravity_Bouguer_HGM_Worms_Proximity
#           b_Gravity_Bouguer_UpCont30km_HGM_Worms_Proximity
#           b_Magnetic_HGM
#           b_Magnetic_LongWavelength_HGM
#           b_Magnetic_HGM_Worms_Proximity
#           b_Magnetic_LongWavelength_HGM_Worms_Proximity
#           b_Seismic_LAB_Hoggard
#           b_Seismic_Moho
#           q_error
#           BMU_BMU_label_count
#           BMU_cluster_label_count
#     Execution time: 19.206005334854126 seconds
# Count cluster hit count
#     Execution time: 39.79496741294861 seconds

# %%
import beak.methods.som.plot_som_results as plot
#from IPython.display import Image, display, clear_output

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/exports/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= '-9999'                              # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.03000497817993164 seconds
#         Read geo data execution time: 7.022767543792725 seconds
#         Read label annotation data
#     Execution time: 36.80724263191223 seconds
# Plot geo space results
#     geospace plot no. 2 from 14
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\methods\som\plot_som_results.py:283: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 14 from 14
#     q-error plot
#     Execution time: 37.5627646446228 seconds
# Plot Cluster result SOM space
#     Draw som cluster plot
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Plot cluster label count
#     Execution time: 1.6327109336853027 seconds
# Plot SOM space results
#     somspace plot no. 12 from 12
#     Execution time: 6.566734075546265 seconds
# Plot Boxplots
#     boxplot no. 12 from 12
#     Execution time: 13.233742952346802 seconds

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-JXrdccTj2wbzXajxpgyf2W {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-JXrdccTj2wbzXajxpgyf2W {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-JXrdccTj2wbzXajxpgyf2W {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-JXrdccTj2wbzXajxpgyf2W:checked ~ #ipyplot-html-viewer-textarea-JXrdccTj2wbzXajxpgyf2W {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-JXrdccTj2wbzXajxpgyf2W:checked + #ipyplot-html-viewer-label-JXrdccTj2wbzXajxpgyf2W:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-JXrdccTj2wbzXajxpgyf2W">
#         <label id="ipyplot-html-viewer-label-JXrdccTj2wbzXajxpgyf2W" for="ipyplot-html-viewer-toggle-JXrdccTj2wbzXajxpgyf2W">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-JXrdccTj2wbzXajxpgyf2W" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w {
#                 display: none;
#             }
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w + label.ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w:checked + label.ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w ~ .tab {
#                 display: none
#             }
#     #tabRS93ssHUd7Nvmhqx3sAnow:checked ~ .tab.contentRS93ssHUd7Nvmhqx3sAnow,#tabgWiu3hbSgxbynTvdzZ4JUD:checked ~ .tab.contentgWiu3hbSgxbynTvdzZ4JUD,#tabErckBPymjmR2AnSdTnQKYA:checked ~ .tab.contentErckBPymjmR2AnSdTnQKYA,#tab6LUDnju6SuFMP9sDkvEZLX:checked ~ .tab.content6LUDnju6SuFMP9sDkvEZLX,#tab4mz6KcQU9AURr7tJqwtbji:checked ~ .tab.content4mz6KcQU9AURr7tJqwtbji,#tabCGro7Zpn2gvTD3GYrTbMUY:checked ~ .tab.contentCGro7Zpn2gvTD3GYrTbMUY{ display: block; }</style><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabRS93ssHUd7Nvmhqx3sAnow" checked /><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabRS93ssHUd7Nvmhqx3sAnow">boxplot</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabgWiu3hbSgxbynTvdzZ4JUD"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabgWiu3hbSgxbynTvdzZ4JUD">db</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabErckBPymjmR2AnSdTnQKYA"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabErckBPymjmR2AnSdTnQKYA">geoplot</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tab6LUDnju6SuFMP9sDkvEZLX"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tab6LUDnju6SuFMP9sDkvEZLX">hit</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tab4mz6KcQU9AURr7tJqwtbji"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tab4mz6KcQU9AURr7tJqwtbji">label</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabCGro7Zpn2gvTD3GYrTbMUY"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabCGro7Zpn2gvTD3GYrTbMUY">somplot</label><div class="tab contentRS93ssHUd7Nvmhqx3sAnow">
#         <style>
#         #ipyplot-imgs-container-div-8DpYQzhVsqenfSPAk9xHY8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8DpYQzhVsqenfSPAk9xHY8">
#     <div class="ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8">
#         <div id="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-DzaLjBAywU6G7fzPZttpjy" class="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_1.png</h4><img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-DzaLjBAywU6G7fzPZttpjy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8">
#         <div id="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-YFhSxb9ADoUUiFB7r5Qhs6" class="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_10.png</h4><img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ip
# <div>
#         <style>
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w {
#                 display: none;
#             }
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w + label.ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w:checked + label.ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w ~ .tab {
#                 display: none
#             }
#     #tabRS93ssHUd7Nvmhqx3sAnow:checked ~ .tab.contentRS93ssHUd7Nvmhqx3sAnow,#tabgWiu3hbSgxbynTvdzZ4JUD:checked ~ .tab.contentgWiu3hbSgxbynTvdzZ4JUD,#tabErckBPymjmR2AnSdTnQKYA:checked ~ .tab.contentErckBPymjmR2AnSdTnQKYA,#tab6LUDnju6SuFMP9sDkvEZLX:checked ~ .tab.content6LUDnju6SuFMP9sDkvEZLX,#tab4mz6KcQU9AURr7tJqwtbji:checked ~ .tab.content4mz6KcQU9AURr7tJqwtbji,#tabCGro7Zpn2gvTD3GYrTbMUY:checked ~ .tab.contentCGro7Zpn2gvTD3GYrTbMUY{ display: block; }</style><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabRS93ssHUd7Nvmhqx3sAnow" checked /><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabRS93ssHUd7Nvmhqx3sAnow">boxplot</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabgWiu3hbSgxbynTvdzZ4JUD"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabgWiu3hbSgxbynTvdzZ4JUD">db</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabErckBPymjmR2AnSdTnQKYA"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabErckBPymjmR2AnSdTnQKYA">geoplot</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tab6LUDnju6SuFMP9sDkvEZLX"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tab6LUDnju6SuFMP9sDkvEZLX">hit</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tab4mz6KcQU9AURr7tJqwtbji"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tab4mz6KcQU9AURr7tJqwtbji">label</label><input class="ipyplot-tab-mbrbQfJUXqQYh9nbWPLP7w" type="radio" name="tabs-mbrbQfJUXqQYh9nbWPLP7w" id="tabCGro7Zpn2gvTD3GYrTbMUY"/><label class="ipyplot-tab-label-mbrbQfJUXqQYh9nbWPLP7w" for="tabCGro7Zpn2gvTD3GYrTbMUY">somplot</label><div class="tab contentRS93ssHUd7Nvmhqx3sAnow">
#         <style>
#         #ipyplot-imgs-container-div-8DpYQzhVsqenfSPAk9xHY8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-8DpYQzhVsqenfSPAk9xHY8">
#     <div class="ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8">
#         <div id="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-DzaLjBAywU6G7fzPZttpjy" class="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_1.png</h4><img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-DzaLjBAywU6G7fzPZttpjy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8">
#         <div id="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-YFhSxb9ADoUUiFB7r5Qhs6" class="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_10.png</h4><img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-YFhSxb9ADoUUiFB7r5Qhs6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8">
#         <div id="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-GCRYYJ55dQcTesmuKGbfPQ" class="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_11.png</h4><img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-GCRYYJ55dQcTesmuKGbfPQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-8DpYQzhVsqenfSPAk9xHY8">
#         <div id="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8-mFWYknRBXh4JLhBV8cJTrU" class="ipyplot-content-div-8DpYQzhVsqenfSPAk9xHY8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_12.png</h4><img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\
#     <style>
#         #ipyplot-html-viewer-toggle-Hx3cZz3GpeNNM5D59vbEaV {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Hx3cZz3GpeNNM5D59vbEaV {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Hx3cZz3GpeNNM5D59vbEaV {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Hx3cZz3GpeNNM5D59vbEaV:checked ~ #ipyplot-html-viewer-textarea-Hx3cZz3GpeNNM5D59vbEaV {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Hx3cZz3GpeNNM5D59vbEaV:checked + #ipyplot-html-viewer-label-Hx3cZz3GpeNNM5D59vbEaV:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Hx3cZz3GpeNNM5D59vbEaV">
#         <label id="ipyplot-html-viewer-label-Hx3cZz3GpeNNM5D59vbEaV" for="ipyplot-html-viewer-toggle-Hx3cZz3GpeNNM5D59vbEaV">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Hx3cZz3GpeNNM5D59vbEaV" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Z8w8FkhyXo4fQY8kXLqPZc {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Z8w8FkhyXo4fQY8kXLqPZc">
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-c6jbPodjzs4ukoRCtDgggx" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-c6jbPodjzs4ukoRCtDgggx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-9oohJ4vLjHyzmdB4i9pYs8" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-9oohJ4vLjHyzmdB4i9pYs8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-gMw57M4rAHNaxT7RPh8Eny" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-gMw57M4rAHNaxT7RPh8Eny">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-mzDxa6hdZtkzS2D4c73twc" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-mzDxa6hdZtkzS2D4c73twc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-ZZev7cgoXSgrgAgv8CYVcH" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-ZZev7cgoXSgrgAgv8CYVcH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-2j8WMZwoBzPrpGyz3rSxr6" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-2j8WMZwoBzPrpGyz3rSxr6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-6ougiBQP5fjaccDKEykF6U" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_4.png"/>
#         <style>
#         #ipyplot-imgs-container-div-Z8w8FkhyXo4fQY8kXLqPZc {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Z8w8FkhyXo4fQY8kXLqPZc">
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-c6jbPodjzs4ukoRCtDgggx" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_1.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-c6jbPodjzs4ukoRCtDgggx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-9oohJ4vLjHyzmdB4i9pYs8" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_10.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-9oohJ4vLjHyzmdB4i9pYs8">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-gMw57M4rAHNaxT7RPh8Eny" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_11.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-gMw57M4rAHNaxT7RPh8Eny">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-mzDxa6hdZtkzS2D4c73twc" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_12.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-mzDxa6hdZtkzS2D4c73twc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-ZZev7cgoXSgrgAgv8CYVcH" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_2.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_2.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-ZZev7cgoXSgrgAgv8CYVcH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-2j8WMZwoBzPrpGyz3rSxr6" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_3.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_3.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-2j8WMZwoBzPrpGyz3rSxr6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-6ougiBQP5fjaccDKEykF6U" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_4.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_4.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-6ougiBQP5fjaccDKEykF6U">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-T72iueCyUgcbr4rFHBaTQ6" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_5.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_5.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-T72iueCyUgcbr4rFHBaTQ6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Z8w8FkhyXo4fQY8kXLqPZc">
#         <div id="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-H8nfgpkyxMHg7MqEBdbjFV" class="ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc">
#             <h4 style="font-size: 12px; word-wrap: break-word;">boxplot_6.png</h4>
#             <img src="models\SOM_F12_X40_Y40_CMAX50_20240412-102125\exports\plots\boxplot_6.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Z8w8FkhyXo4fQY8kXLqPZc-H8nfgpkyxMHg7MqEBdbjFV">
#                 <span class="ipyplot-img-expand"/>
#             <
