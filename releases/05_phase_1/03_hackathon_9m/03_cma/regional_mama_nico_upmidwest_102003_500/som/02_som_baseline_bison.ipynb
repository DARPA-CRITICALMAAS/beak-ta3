# %% [markdown]
# # 1: Import libraries and set paths

# %%
# Models and utils
import json
from pathlib import Path
from datetime import datetime
from beak.models import cobalt_nickel_upper_midwest
from beak.experimental.io import load_model, check_path

# SOM specific
import beak.methods.som.argsSOM as asom

args = asom.Args()

# Files
import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

# Choose model
MODEL = "BASELINE_BISON"
model = cobalt_nickel_upper_midwest.models[MODEL]

BASE_PATH = files("beak.data")
BASE_SPATIAL = "102008_500"
BASE_EXTENT = "upper_midwest"

# Choose data path
PATH_STD_DATA = BASE_PATH / "PROCESSED" / f"regional_{BASE_SPATIAL}_{BASE_EXTENT}_cobalt_nickel" / "unified_scaled_std"
PATH_LOG_DATA = PATH_STD_DATA.parent / "unified_scaled_log"

PATH_LABELS = (BASE_PATH / "TRAINING_LABELS" / "COBALT_NICKEL_UPPER_MIDWEST" / "EPSG_102008_RES_500_UpperMidwest_ENV_MMS_TA2HM6.tif")

model_dict, file_list, counts = load_model(
    model=model,
    folders=[PATH_STD_DATA, PATH_LOG_DATA],
    file_extensions=[".tif", ".tiff"],
    verbose=0,
)

# SOM specific
label_data_file_list = [str(PATH_LABELS)]
# Out:
# Loading model definition...
# Selected 28 evidence layers.
#
# Searching for files and folders in provided paths...
# Found 2 folders, 11 subfolders and 71 files.
#
# Searching for corresponding files...
# Found 'LAB' in 1 file(s).
# Found 'LAB_HGM' in 1 file(s).
# Found 'LAB_Worms_Proximity' in 1 file(s).
# Found 'Moho' in 1 file(s).
# Found 'SatelliteGravity_ShapeIndex' in 1 file(s).
# Found 'Gravity' in 1 file(s).
# Found 'Gravity_HGM' in 1 file(s).
# Found 'ShallowGravitySources_Worms_Proximity' in 1 file(s).
# Found 'Gravity_Up30km' in 1 file(s).
# Found 'Gravity_Up30km_HGM' in 1 file(s).
# Found 'DeepGravitySources_Worms_Proximity' in 1 file(s).
# Found 'IsostaticGravity' in 1 file(s).
# Found 'IsostaticGravity_HGM' in 1 file(s).
# Found 'IsostaticGravity_Worms_Proximity' in 1 file(s).
# Found 'Mag_RTP' in 1 file(s).
# Found 'Mag_RTP_HGM' in 1 file(s).
# Found 'ShallowMagSources_Worms_Proximity' in 1 file(s).
# Found 'Mag_RTP_DeepSources' in 1 file(s).
# Found 'Mag_RTP_HGM_DeepSources' in 1 file(s).
# Found 'DeepMagSources_Worms_Proximity' in 1 file(s).
# Found 'CONUS_MT2023_9km' in 1 file(s).
# Found 'CONUS_MT2023_15km' in 1 file(s).
# Found 'CONUS_MT2023_30km' in 1 file(s).
# Found 'CONUS_MT2023_48km' in 1 file(s).
# Found 'CONUS_MT2023_92km' in 1 file(s).
# Found 'NAMrad_K' in 1 file(s).
# Found 'NAMrad_Th' in 1 file(s).
# Found 'NAMrad_U' in 1 file(s).
#
# Ensuring that all layers have matching files...
# All layers have matching files.
#
# Checking files for multiple occurences...
# No duplicates found. All filenames occur only once.
# Number of files in file list: 28

# %% [markdown]
# # 2: Set SOM parameters and model **name** and **configuration**

# %%
args.som_x = 50                    # X dimension of generated SOM
args.som_y = 50                    # Y dimension of generated SOM
args.epochs = 10                   # Number of epochs to run

args.kmeans = True                 # Run k-means clustering (True, False)
args.kmeans_init = 5               # Number of initializations
args.kmeans_min = 30               # Minimum number of k-mean clusters
args.kmeans_max = 50               # Maximum number of k-mean clusters

args.neighborhood = "gaussian"     # Shape of the neighborhood function. gaussian or bubble
args.std_coeff = 0.5               # Coefficient in the Gaussian neighborhood function
args.maptype = "toroid"            # Type of SOM (sheet, toroid)
args.initialcodebook = None        # File path of initial codebook, 2D numpy.array of float32.
args.radius0 = 0                   # Initial size of the neighborhood
args.radiusN = 1                   # Final size of the neighborhood
args.radiuscooling = "linear"      # Function that defines the decrease in the neighborhood size as the training proceeds (linear, exponential)
args.scalecooling = "linear"       # Function that defines the decrease in the learning scale as the training proceeds (linear, exponential)
args.scale0 = 0.1                  # Initial learning rate
args.scaleN = 0.01                 # Final learning rate
args.initialization = "random"     # Type of SOM initialization (random, pca)
args.gridtype = "rectangular"      # Type of SOM grid (hexagonal, rectangular)

args.label = True                 # Whether data contains label column, True or False

# %%
# Set model name and folder
MODEL_NAME = "SOM_" + MODEL + "_F" + str(len(file_list)) + "_X" + str(args.som_x) + "_Y" + str(args.som_y) + "_CMAX" + str(args.kmeans_max) + "_" + datetime.now().strftime("%Y%m%d-%H%M%S")
MODEL_FOLDER = Path.cwd() / "models" / MODEL / MODEL_NAME

print(MODEL_FOLDER)
# Out:
# s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\cobalt_nickel_upper_midwest\som\models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508

# %% [markdown]
# # 3: Input data, file lists etc.

# %%
check_path(MODEL_FOLDER)

# Set input files path
file_path = MODEL_FOLDER / "input_file_list.txt"
label_data_file_path = MODEL_FOLDER / "label_file_list.txt"

# Write input file paths and parameters to text files
with open(file_path, 'w') as file:
    for string in file_list:
        file.write(f"{string}\n")
    file.close()

with open(label_data_file_path, 'w') as file:
    for string in label_data_file_list:
        file.write(f"{string}\n")
    file.close()

args_path = MODEL_FOLDER / "args.txt"
def write_args_to_file(file_path, **kwargs):
  with open(file_path, "w") as f:
    json.dump(kwargs, f, indent=4)
    file.close()

args_path = MODEL_FOLDER / "args.json"
write_args_to_file(file_path=args_path,
                   som_x=args.som_x,
                   som_y=args.som_y,
                   epochs=args.epochs,
                   kmeans=args.kmeans,
                   k_means_init=args.kmeans_init,
                   kmeans_min=args.kmeans_min,
                   kmeans_max=args.kmeans_max,
                   neighborhood=args.neighborhood,
                   std_coeff=args.std_coeff,
                   maptype=args.maptype,
                   initialcodebook=args.initialcodebook,
                   radius0=args.radius0,        
                   radiusN=args.radiusN,                  
                   radiuscooling=args.radiuscooling, 
                   scalecooling=args.scalecooling,
                   scale0=args.scale0,          
                   scaleN=args.scaleN,
                   initialization=args.initialization,
                   gridtype=args.gridtype,
                   label=args.label
                   )

# %%
# Args
args.output_folder = str(MODEL_FOLDER) + "/" + "exports"                             # Folder to save som dictionary and cluster dictionary
check_path(args.output_folder)

args.output_file_somspace = args.output_folder + "/" + "result_som.txt"              # Txt file for: som_x som_y b_data1 b_data2 b_dataN umatrix cluster, geospace. DO NOT CHANGE!
args.outgeofile = args.output_folder + "/" + "result_geo.txt"                        # DO NOT CHANGE!
args.output_file_geospace = args.outgeofile                                          # Text file for {X Y Z} data1 data2 dataN som_x som_y cluster b_data1 b_data2 b_dataN, geospace.
#args.label_geotiff_file = args.output_folder + "/" + "input_file_list.txt"           # GeoTiff_input file (None)

# %%
args.input_file = args.create_list_from_file(file_path)
args.geotiff_input=args.input_file                                # Geotiff_input files, separated by komma, to write GeoTIF out 
                                                                  # (only first line is used to get the geotransform and projection information 
                                                                  # to set output GeoFIT geotransform and projection)
args.label_geotiff_file = args.create_list_from_file(label_data_file_path)
# Out:
# Number of files added: 28
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\seismic\LAB.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\seismic\LAB_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\seismic\LAB_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\seismic\Moho.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\gravity\SatelliteGravity_ShapeIndex.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\gravity\Gravity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\gravity\Gravity_HGM.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\gravity\ShallowGravitySources_Worms_Proximity.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\gravity\Gravity_Up30km.tif
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\gravity\Gravity_Up30km_HGM.tif
# ...
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\PROCESSED\regional_102008_500_upper_midwest_cobalt_nickel\unified_scaled_std\geophysics\radiometric\NAMrad_U.tif
# Number of files added: 1
# Files:
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\data\TRAINING_LABELS\COBALT_NICKEL_UPPER_MIDWEST\EPSG_102008_RES_500_UpperMidwest_ENV_MMS_TA2HM6.tif

# %% [markdown]
# # 4: Run SOM

# %% [markdown]
# Run SOM with parameters specified above and save the results. Uses NxtSomCore package to do the actual work. <p>
# Before running SOM - clean up existing files and move them to a subfolder.

# %%
import beak.methods.som.do_nextsomcore_save_results as dnsr
import beak.methods.som.move_to_subfolder as mts
import warnings

mts.remove_som_results(args.output_folder)                              # move or remove existing SOM output files from previous runs into subfolder
                                                                        # mts.move_som_results(args.output_folder, "old_results")
# Run SOM
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    dnsr.run_SOM(args)
# Out:
# Load data
#     Execution time: 10.736323833465576 seconds
# Run SOM
#     Execution time: 144.24290943145752 seconds
# Save SOM object to file
#     Execution time: 0.015086650848388672 seconds
# Clustering progress:
# 0.00%
# 9.52%
# 19.05%
# 28.57%
# 38.10%
# 47.62%
# 57.14%
# 66.67%
# 76.19%
# 85.71%
# 95.24%
# 100% Clustering completed.
#     Execution time: 14.834916114807129 seconds
# Save SOM space results
#     Execution time: 2.4422194957733154 seconds
# Save geo space results
#          combine data colums for output geo file (for large data arrays memory usage might be a concern)
#          savetxt
#     Execution time: 127.51034355163574 seconds
# Do label analysis and write to file
#     Execution time: 6.818567991256714 seconds
# Write GeoTIFF file
#      read_csv som_data
#      read_csv geo_data
#      Iterate over each geoTIF file:
#           cluster
#           b_LAB
#           b_LAB_HGM
#           b_LAB_Worms_Proximity
#           b_Moho
#           b_SatelliteGravity_ShapeIndex
#           b_Gravity
#           b_Gravity_HGM
#           b_ShallowGravitySources_Worms_Proximity
#           b_Gravity_Up30km
#           b_Gravity_Up30km_HGM
#           b_DeepGravitySources_Worms_Proximity
#           b_IsostaticGravity
#           b_IsostaticGravity_HGM
#           b_IsostaticGravity_Worms_Proximity
#           b_Mag_RTP
#           b_Mag_RTP_HGM
#           b_ShallowMagSources_Worms_Proximity
#           b_Mag_RTP_DeepSources
#           b_Mag_RTP_HGM_DeepSources
#           b_DeepMagSources_Worms_Proximity
#           b_CONUS_MT2023_9km
#           b_CONUS_MT2023_15km
#           b_CONUS_MT2023_30km
#           b_CONUS_MT2023_48km
#           b_CONUS_MT2023_92km
#           b_NAMrad_K
#           b_NAMrad_Th
#           b_NAMrad_U
#           q_error
#           BMU_ID
#           BMU_BMU_label_count
#           BMU_cluster_label_count
#     Execution time: 66.98032402992249 seconds
# Count cluster hit count
#     Execution time: 74.13638544082642 seconds

# %%
import beak.methods.som.plot_som_results as plot

# Load cluster dictionary
loaded_cluster_list = plot.load_cluster_dictionary(args.output_folder)

# Plot and save the Davies-Bouldin Index vs Number of Clusters
plot.plot_davies_bouldin(loaded_cluster_list, args.output_folder)

# %% [markdown]
# # 5: Plot results.

# %% [markdown]
# Specify the parameters to plot the results and create figures. The Python script "plot_som_results.py" creates .png files of the results in som space, geospace and also creates boxplots.

# %% [markdown]
# Move figures into a sub folder. If the destination folder does not exist, it is created here. All file names are stored in a list that is used in the next step to show all output figures.

# %%
import beak.methods.som.argsPlot
import beak.methods.som.plot_som_results as plot
import beak.methods.som.move_to_subfolder as mts

argsP = beak.methods.som.argsPlot.Args()

argsP.outsomfile = args.output_file_somspace            # som calculation somspace output text file
argsP.som_x = args.som_x                                # som x dimension
argsP.som_y = args.som_y                                # som y dimension
argsP.input_file = args.input_file                      # input file (*.lrn)
argsP.dir = args.output_folder                          # input file (*.lrn) or directory where som.dictionary was safed to (/output/som.dictionary)
argsP.grid_type = 'rectangular'                         # grid type (square or hexa), (rectangular or hexagonal)
argsP.redraw = True                                     # True: draw all plots. False: draw only polts required for clustering.
argsP.outgeofile = args.output_file_geospace            # som geospace results txt file
argsP.dataType = 'grid'                                 # data type (scatter or grid)
argsP.noDataValue= ' -9999'                             # nodata value

plot.run_plotting_script(argsP)

subfolder_name = "plots"
images, labels = mts.move_figures(args.output_folder, subfolder_name)
# Out:
# Setup figures
#         Read som data execution time: 0.06800341606140137 seconds
#         Read geo data execution time: 27.013434886932373 seconds
#         Read label annotation data
#     Execution time: 32.54707908630371 seconds
# Plot geo space results
#     geospace plot no. 2 from 30
# s:\projekte\20230082_darpa_criticalmaas_ta3\bearbeitung\github\beak-ta3\src\beak\methods\som\plot_som_results.py:291: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   z[z == noDataValue] = np.nan
#     geospace plot no. 30 from 30
#     q-error plot
#     Execution time: 131.38959860801697 seconds
# Plot Cluster result SOM space
#     Draw som cluster plot
#     Plot Davies Bouldin index
#     Plot cluster hit count
#     Plot cluster label count
#     Execution time: 1.9652988910675049 seconds
# Plot SOM space results
#     somspace plot no. 28 from 28
#     Execution time: 18.844528913497925 seconds
# Move figures geoplot_*.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\cobalt_nickel_upper_midwest\som\models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508/exports/plots/
# Move figures somplot_*.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\cobalt_nickel_upper_midwest\som\models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508/exports/plots/
# Move figures boxplot_*.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\cobalt_nickel_upper_midwest\som\models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508/exports/plots/
# Move figures db_score.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\cobalt_nickel_upper_midwest\som\models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508/exports/plots/
# Move figures cluster*_count.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\cobalt_nickel_upper_midwest\som\models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508/exports/plots/
# Move figures bmu_id_mesh.png to s:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\experiments\hackathon_9m_related\03_cma\cobalt_nickel_upper_midwest\som\models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508/exports/plots/

# %% [markdown]
# Show all figures that were produced by "plot_som_results.py" and moved into a subfolder.
#
# Boxplot:
# > x axis is Cluster ID </br>
# > Z axis is original data value </br>
# > legend: number of data points in each cluster </br>

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import ipyplot

# Clear Matplotlib cache
plt.close('all')

# Clear output
clear_output(wait=True)

# Get the tabs descriptions
tabs = [image.split('_')[-2] for image in labels]

# print(labels)
# print(tabs)

# Plot the images
ipyplot.plot_class_tabs(images, tabs, max_imgs_per_tab=50, img_width=400)
ipyplot.plot_class_representations(images,  labels, img_width=200, show_url=False)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CGpmUiiqPJ6WETWqZYoHzC {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CGpmUiiqPJ6WETWqZYoHzC {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CGpmUiiqPJ6WETWqZYoHzC {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CGpmUiiqPJ6WETWqZYoHzC:checked ~ #ipyplot-html-viewer-textarea-CGpmUiiqPJ6WETWqZYoHzC {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CGpmUiiqPJ6WETWqZYoHzC:checked + #ipyplot-html-viewer-label-CGpmUiiqPJ6WETWqZYoHzC:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-CGpmUiiqPJ6WETWqZYoHzC">
#         <label id="ipyplot-html-viewer-label-CGpmUiiqPJ6WETWqZYoHzC" for="ipyplot-html-viewer-toggle-CGpmUiiqPJ6WETWqZYoHzC">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-CGpmUiiqPJ6WETWqZYoHzC" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf {
#                 display: none;
#             }
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf + label.ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf:checked + label.ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf ~ .tab {
#                 display: none
#             }
#     #taboFnrsSk7sa4MAAwDCFLNCE:checked ~ .tab.contentoFnrsSk7sa4MAAwDCFLNCE,#tabVgjwkb3NBQXrz4rSaRKJyH:checked ~ .tab.contentVgjwkb3NBQXrz4rSaRKJyH,#tabBthEJyrXUZjwcoTQ5iG5v5:checked ~ .tab.contentBthEJyrXUZjwcoTQ5iG5v5,#tabVn8LtwMmzXsLL2FQap237T:checked ~ .tab.contentVn8LtwMmzXsLL2FQap237T,#tab6dbBDrMMzVkWaGGAwULyy6:checked ~ .tab.content6dbBDrMMzVkWaGGAwULyy6,#tab2X73XRRJct7jwwtmzDiznZ:checked ~ .tab.content2X73XRRJct7jwwtmzDiznZ{ display: block; }</style><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="taboFnrsSk7sa4MAAwDCFLNCE" checked /><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="taboFnrsSk7sa4MAAwDCFLNCE">db</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tabVgjwkb3NBQXrz4rSaRKJyH"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tabVgjwkb3NBQXrz4rSaRKJyH">geoplot</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tabBthEJyrXUZjwcoTQ5iG5v5"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tabBthEJyrXUZjwcoTQ5iG5v5">hit</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tabVn8LtwMmzXsLL2FQap237T"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tabVn8LtwMmzXsLL2FQap237T">id</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tab6dbBDrMMzVkWaGGAwULyy6"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tab6dbBDrMMzVkWaGGAwULyy6">label</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tab2X73XRRJct7jwwtmzDiznZ"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tab2X73XRRJct7jwwtmzDiznZ">somplot</label><div class="tab contentoFnrsSk7sa4MAAwDCFLNCE">
#         <style>
#         #ipyplot-imgs-container-div-NiwVivwLY4imhNuZRP3mo8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-NiwVivwLY4imhNuZRP3mo8 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-NiwVivwLY4imhNuZRP3mo8">
#     <div class="ipyplot-placeholder-div-NiwVivwLY4imhNuZRP3mo8">
#         <div id="ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8-8Pp8cuog9NFidnE6X9EtE7" class="ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\db_score.png</h4><img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8-8Pp8cuog9NFidnE6X9EtE7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentVgjwkb3NBQXrz4rSaRKJyH">
#         <style>
#         #ipyplot-imgs-container-div-FN7aY8NW8HRk6FNcxcngNQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FN7aY8NW8HRk6FNcxcngNQ {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ {
#             width: 400px;
#             background: white;
#             display: i
# <div>
#         <style>
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf {
#                 display: none;
#             }
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf + label.ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf:checked + label.ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-kzetwykeZVAccewZ6QPhKf ~ .tab {
#                 display: none
#             }
#     #taboFnrsSk7sa4MAAwDCFLNCE:checked ~ .tab.contentoFnrsSk7sa4MAAwDCFLNCE,#tabVgjwkb3NBQXrz4rSaRKJyH:checked ~ .tab.contentVgjwkb3NBQXrz4rSaRKJyH,#tabBthEJyrXUZjwcoTQ5iG5v5:checked ~ .tab.contentBthEJyrXUZjwcoTQ5iG5v5,#tabVn8LtwMmzXsLL2FQap237T:checked ~ .tab.contentVn8LtwMmzXsLL2FQap237T,#tab6dbBDrMMzVkWaGGAwULyy6:checked ~ .tab.content6dbBDrMMzVkWaGGAwULyy6,#tab2X73XRRJct7jwwtmzDiznZ:checked ~ .tab.content2X73XRRJct7jwwtmzDiznZ{ display: block; }</style><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="taboFnrsSk7sa4MAAwDCFLNCE" checked /><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="taboFnrsSk7sa4MAAwDCFLNCE">db</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tabVgjwkb3NBQXrz4rSaRKJyH"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tabVgjwkb3NBQXrz4rSaRKJyH">geoplot</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tabBthEJyrXUZjwcoTQ5iG5v5"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tabBthEJyrXUZjwcoTQ5iG5v5">hit</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tabVn8LtwMmzXsLL2FQap237T"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tabVn8LtwMmzXsLL2FQap237T">id</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tab6dbBDrMMzVkWaGGAwULyy6"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tab6dbBDrMMzVkWaGGAwULyy6">label</label><input class="ipyplot-tab-kzetwykeZVAccewZ6QPhKf" type="radio" name="tabs-kzetwykeZVAccewZ6QPhKf" id="tab2X73XRRJct7jwwtmzDiznZ"/><label class="ipyplot-tab-label-kzetwykeZVAccewZ6QPhKf" for="tab2X73XRRJct7jwwtmzDiznZ">somplot</label><div class="tab contentoFnrsSk7sa4MAAwDCFLNCE">
#         <style>
#         #ipyplot-imgs-container-div-NiwVivwLY4imhNuZRP3mo8 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-NiwVivwLY4imhNuZRP3mo8 {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-NiwVivwLY4imhNuZRP3mo8">
#     <div class="ipyplot-placeholder-div-NiwVivwLY4imhNuZRP3mo8">
#         <div id="ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8-8Pp8cuog9NFidnE6X9EtE7" class="ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\db_score.png</h4><img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NiwVivwLY4imhNuZRP3mo8-8Pp8cuog9NFidnE6X9EtE7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div><div class="tab contentVgjwkb3NBQXrz4rSaRKJyH">
#         <style>
#         #ipyplot-imgs-container-div-FN7aY8NW8HRk6FNcxcngNQ {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FN7aY8NW8HRk6FNcxcngNQ {
#             width: 400px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ {
#             width: 400px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ img {
#             width: 400px;
#         }
#
#         div.ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FN7aY8NW8HRk6FNcxcngNQ]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FN7aY8NW8HRk6FNcxcngNQ">
#     <div class="ipyplot-placeholder-div-FN7aY8NW8HRk6FNcxcngNQ">
#         <div id="ipyplot-content-div-FN7aY8NW8HR
#     <style>
#         #ipyplot-html-viewer-toggle-65VS6mnNFvCZzHtvSLPLJd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-65VS6mnNFvCZzHtvSLPLJd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-65VS6mnNFvCZzHtvSLPLJd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-65VS6mnNFvCZzHtvSLPLJd:checked ~ #ipyplot-html-viewer-textarea-65VS6mnNFvCZzHtvSLPLJd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-65VS6mnNFvCZzHtvSLPLJd:checked + #ipyplot-html-viewer-label-65VS6mnNFvCZzHtvSLPLJd:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-65VS6mnNFvCZzHtvSLPLJd">
#         <label id="ipyplot-html-viewer-label-65VS6mnNFvCZzHtvSLPLJd" for="ipyplot-html-viewer-toggle-65VS6mnNFvCZzHtvSLPLJd">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-65VS6mnNFvCZzHtvSLPLJd" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-DYmT9PkBCGp9RiLUgyUaCm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-DYmT9PkBCGp9RiLUgyUaCm">
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-FrLGBZRfi9i3CxGAuAVLNz" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bmu_id_mesh.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\bmu_id_mesh.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-FrLGBZRfi9i3CxGAuAVLNz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-RE35kG6JeZXKjeeKAo83qg" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-RE35kG6JeZXKjeeKAo83qg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XizBq7VHcXMYSbuBButR6M" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_label_count.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\cluster_label_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XizBq7VHcXMYSbuBButR6M">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-98nQWWUCViuJ4bHNEnXiRR" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-98nQWWUCViuJ4bHNEnXiRR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XCRsqbsxQsHQSvquxCFdnn" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\geoplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XCRsqbsxQsHQSvquxCFdnn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-mZQQkCtwzJonnvYd8ni8XT" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_10.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\geoplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-mZQQkCtwzJonnvYd8ni8XT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-jt6STWcvUiZhVZh28Gobz4" class="ipyplot-content
#         <style>
#         #ipyplot-imgs-container-div-DYmT9PkBCGp9RiLUgyUaCm {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm {
#             width: 200px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm {
#             width: 200px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm img {
#             width: 200px;
#         }
#
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-DYmT9PkBCGp9RiLUgyUaCm">
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-FrLGBZRfi9i3CxGAuAVLNz" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">bmu_id_mesh.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\bmu_id_mesh.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-FrLGBZRfi9i3CxGAuAVLNz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-RE35kG6JeZXKjeeKAo83qg" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_hit_count.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\cluster_hit_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-RE35kG6JeZXKjeeKAo83qg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XizBq7VHcXMYSbuBButR6M" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">cluster_label_count.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\cluster_label_count.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XizBq7VHcXMYSbuBButR6M">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-98nQWWUCViuJ4bHNEnXiRR" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">db_score.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\db_score.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-98nQWWUCViuJ4bHNEnXiRR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XCRsqbsxQsHQSvquxCFdnn" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_1.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\geoplot_1.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-XCRsqbsxQsHQSvquxCFdnn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-mZQQkCtwzJonnvYd8ni8XT" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_10.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\geoplot_10.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-mZQQkCtwzJonnvYd8ni8XT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-jt6STWcvUiZhVZh28Gobz4" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_11.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\geoplot_11.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-jt6STWcvUiZhVZh28Gobz4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-Y4WqHNrpreyTUDix7zk5Au" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_12.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_X50_Y50_CMAX50_20240615-001508\exports\plots\geoplot_12.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-Y4WqHNrpreyTUDix7zk5Au">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-DYmT9PkBCGp9RiLUgyUaCm">
#         <div id="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm-NkgPBqWPBLDqXoCVJ6LkqV" class="ipyplot-content-div-DYmT9PkBCGp9RiLUgyUaCm">
#             <h4 style="font-size: 12px; word-wrap: break-word;">geoplot_13.png</h4>
#             <img src="models\BASELINE_BISON\SOM_BASELINE_BISON_F28_
