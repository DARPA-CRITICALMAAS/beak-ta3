# %% [markdown]
# # Create Training Labels from the Critical Mineral Deposits Database
# from shapefile to GeoTIFF

# %%
import numpy as np
import geopandas as gpd

from beak.experimental.io import  data_folder, load_raster
from beak.experimental.conversions import create_binary_raster

# %% [markdown]
# # Load data

# %% [markdown]
# **User definitions**

# %%
BASE_PATH = data_folder()
EPSG_CODE = 102008
RESOLUTION = 500

BASE_EXTENT = "tusk_great_basin"
BASE_RASTER = BASE_PATH / "processed" / str(f"regional_{BASE_EXTENT}_{EPSG_CODE}_{RESOLUTION}") / "base_raster" / "template_raster.tif"
CMA_EXTENT = "regional"

# Export
# If some data sets are already **LOG** scaled they need special actions. They will be unified and stored in a separate folder.
PATH_SHAPEFILE = BASE_PATH / "raw" / "mineral_deposits" / "Tungsten_Skarn" / "regional_tusk_great_basin" / "h4_tungsten_sites_0820.gpkg"
OUT_FILE = BASE_PATH / "processed" / str(f"{CMA_EXTENT}_{BASE_EXTENT}_{EPSG_CODE}_{RESOLUTION}") / "labels" / "TA2_merged_dedup_0820.tif"
LAYER = "merged_dedup"

print(f"Input: {PATH_SHAPEFILE}")
print(f"Export: {OUT_FILE}")
# Out:
# Input: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\raw\mineral_deposits\Tungsten_Skarn\regional_tusk_great_basin\h4_tungsten_sites_0820.gpkg
# Export: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\processed\regional_tusk_great_basin_102008_500\labels\TA2_merged_dedup_0820.tif

# %% [markdown]
# # Create Labels

# %% [markdown]
# Reproject to **BASE RASTER** CRS

# %%
from beak.experimental.vector_processing import _reproject_vector_data

base_raster = load_raster(BASE_RASTER)
template_crs = base_raster.crs

gdf = gpd.read_file(PATH_SHAPEFILE, layer="merged_dedup")
gdf = _reproject_vector_data(gdf, crs=template_crs, encoding="utf-8", query=None)

# %% [markdown]
# Create binary label raster

# %%
out_array = create_binary_raster(gdf, base_raster, query=None, all_touched=False, same_shape=True, fill_negatives=True, out_file=OUT_FILE)
print(f"Number of positive training labels: {np.sum(out_array==1)}")
# Out:
# File already exists: TA2_merged_dedup_0820.tif.
# Number of positive training labels: 125
