# %% [markdown]
# # Information
# ## How to
# 1. Set the parameters. **UPPERCASE** letters are user input variables
# 2. Run the reprojection cell

# %% [markdown]
# # Requirements

# %%
# Standard libraries
import sys
import os
from pathlib import Path
from importlib_resources import files

# Insert the path to the root directory of the project
sys.path.insert(0, str(Path(os.getcwd()).parent.parent))

# Custom modules
from beak.experimental.utilities import transformation

# %% [markdown]
# # Scaling

# %% [markdown]
# **Scaling** all numerical folders within a specified model configuration.<br>
# Reads the <code>ROOT_FOLDER</code> and takes the <code>NUMERICAL</code> subfolder for each model configuration.

# %% [markdown]
# **User inputs**

# %%
BASE_PATH = files("beak.data")

# Points to the "beak" data folder
SPATIAL_DEFINITION = "102008_2240"
SPATIAL_EXTENT = "us_cont"
ROOT_FOLDER = BASE_PATH / "PROCESSED" / f"national_{SPATIAL_EXTENT}_{SPATIAL_DEFINITION}" / "unified_lawley"

# Export to current location for testing purposes
EXAMPLE_EXPORT = Path(os.getcwd()) / "EXPORT" / SPATIAL_DEFINITION / SPATIAL_EXTENT
PATH_EXPORT = ROOT_FOLDER

# Select scaling methods
METHODS = ["standard"]

# Print folders/subfolders
print("Potential input folders (please select some in the next cell):\n")
for folder in os.listdir(ROOT_FOLDER):
  if os.path.isdir(os.path.join(ROOT_FOLDER, folder)):
    print(folder)
# Out:
# Potential input folders (please select some in the next cell):
#
# categorical
# ground_truth
# numerical
# numerical_imputed

# %%
SELECTION = ["numerical", "numerical_imputed"]
input_folders = [ROOT_FOLDER / folder for folder in SELECTION]

# %%
for folder in input_folders:
  folder_relative = os.path.relpath(folder, ROOT_FOLDER)
  for method in METHODS:
    print(f"Processing {folder} with {method} method...")
    output_folder = PATH_EXPORT / str(folder_relative + "_SCALED_" + str.upper(method)).lower()
    transformation.scale_raster(folder, output_folder, method)
# Out:
# Processing S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_us_cont_102008_2240\unified_lawley\numerical with standard method...
# Selected folder: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_us_cont_102008_2240\unified_lawley\numerical
# Total of folders found: 1
# Files loaded: 45
# Processing files: 100%|██████████| 45/45 [00:09<00:00,  4.86it/s]
# Processing S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_us_cont_102008_2240\unified_lawley\numerical_imputed with standard method...
# Selected folder: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_us_cont_102008_2240\unified_lawley\numerical_imputed
# Total of folders found: 1
# Files loaded: 45
# Processing files: 100%|██████████| 45/45 [00:09<00:00,  4.80it/s]
