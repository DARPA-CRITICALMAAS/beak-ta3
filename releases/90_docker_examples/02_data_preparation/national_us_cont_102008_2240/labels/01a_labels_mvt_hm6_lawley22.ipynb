# %% [markdown]
# # Create Training Labels from the Critical Mineral Deposits Database
# from shapefile to GeoTIFF

# %%
import numpy as np
import geopandas as gpd

import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

from beak.experimental.utilities.io import load_raster
from beak.experimental.utilities.conversions import create_binary_raster

# %% [markdown]
# # Load data

# %% [markdown]
# **User definitions**

# %%
# Set base paths and files
BASE_PATH = files("beak.data")

EPSG_CODE = 102008
RESOLUTION = 2240
BASE_SPATIAL = str(EPSG_CODE) + "_" + str(RESOLUTION)
BASE_EXTENT = "us_cont"
BASE_RASTER = BASE_PATH / "BASE_RASTERS" / str("EPSG_" + str(EPSG_CODE) + "_RES_" + str(RESOLUTION) + "_" + BASE_EXTENT + ".tif")

# Points file and query to select relevant mineral occurences
PATH_SHAPEFILE = BASE_PATH / "RAW" / "mineral_deposits" / "Mississippi_Valley_Type" / "Lawley_US_Canada" / "Lawley_et_al_2022_H3_Hexagon_Centroids_102008.shp"
SQL_QUERY = None

# Set the output file
PATH_ROOT = BASE_PATH / "PROCESSED" / str("national" + "_" + BASE_EXTENT + "_" + BASE_SPATIAL)
PATH_EXPORT = PATH_ROOT / "labels" / str(BASE_RASTER.stem + "_MVT_HM6_LAWLEY22_HEX" + ".tif")
OUT_FILE = PATH_EXPORT

print(f"Output file: {OUT_FILE}")
# Out:
# Output file: S:\Projekte\20230082_DARPA_CriticalMAAS_TA3\Bearbeitung\GitHub\beak-ta3\src\beak\data\PROCESSED\national_us_cont_102008_2240\labels\EPSG_102008_RES_2240_us_cont_MVT_HM6_LAWLEY22_HEX.tif

# %% [markdown]
# # Create Labels
# ## Complete extent of the dataset
# Not saving the results to file

# %%
gdf = gpd.read_file(PATH_SHAPEFILE)
base_raster = load_raster(BASE_RASTER)
out_array = create_binary_raster(gdf, base_raster, query=SQL_QUERY, all_touched=False, same_shape=True, fill_negatives=True, out_file=None)
print(f"Number of positive training labels: {np.sum(out_array==1)}")
# Out:
# Number of positive training labels: 1390
