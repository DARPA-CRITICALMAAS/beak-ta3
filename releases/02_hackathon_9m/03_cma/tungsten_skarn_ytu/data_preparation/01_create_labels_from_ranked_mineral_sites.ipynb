# %% [markdown]
# # Create Training Labels from the Critical Mineral Deposits Database
# from shapefile to GeoTIFF

# %%
import os
import numpy as np
import geopandas as gpd
from pathlib import Path

import sys
if sys.version_info < (3, 9):
    from importlib_resources import files
else:
    from importlib.resources import files

from beak.experimental.utilities.io import load_raster
from beak.experimental.utilities.conversions import create_binary_raster

# %% [markdown]
# # Load data

# %% [markdown]
# **User definitions**

# %%
# Set base paths and files
BASE_PATH = files("beak.data")
PATH_BASE_RASTER = BASE_PATH / "BASE_RASTERS" / "EPSG_32606_RES_100_ALASKA_YTU.tif"

# Points file and query to select relevant mineral occurences
PATH_SHAPEFILE = BASE_PATH / "RAW" / "mineral_deposits" / "TungstenSkarn_Yukon_Tanana21" / "Shapefiles" / "mineral_sites_ranked_epsg_32606.shp"
SQL_QUERY = "MRAT_ranki >= 3"

# Set the output file
PATH_EXPORT = BASE_PATH / "TRAINING_LABELS" / "TUNGSTEN_SKARN_YTU" / str(PATH_BASE_RASTER.stem + "_MSR3" + ".tif")

# Overwrite the path for testing purposes
CURRENT_DIR = Path(os.getcwd())
OUT_FILE = CURRENT_DIR / PATH_EXPORT.name

# %% [markdown]
# # Create Labels
# ## Complete extent of the dataset
# Not saving the results to file

# %%
gdf = gpd.read_file(PATH_SHAPEFILE)
base_raster = load_raster(PATH_BASE_RASTER)
out_array = create_binary_raster(gdf, base_raster, query=SQL_QUERY, all_touched=False, same_shape=True, fill_negatives=True, out_file=OUT_FILE)
print(f"Number of positive training labels: {np.sum(out_array==1)}")
# Out:
# Number of positive training labels: 25
